# %% [markdown]
# # CNN Based Image Segmentation of DICOM Images - Training
# ### **```Author : BlackViper42```**
# ______

# %% [markdown]
# Overview
# ======
#
# ------
#  - This notebook consists of HeadRest Segmentation of CT Scan DICOM images of head patients downloaded from server of anonymous patients.
#
#
#  - Currently this notebook predicts the segmented image of original `input_image` and this can be further taken to get `output_image` without headrest by multiplying `predicted_outcome` (binary labeled image) with `input_image`.
#
#
#  - Prerequisites for this notebook:
#     - Graphics Card -------------------------------  NVIDIA  Quadro M5000 - 8GB
#     - `CUDA` toolkit 7.0 or above -------------------  installed  CUDA-8.0
#     - `cuDNN` 5.1 or above --------------------------  installed  cuDNN-5.1
#     - `tensorflow-gpu` library
#
#  - [please go through this link for installation of tensorflow-gpu](https://www.tensorflow.org/install/install_linux)
#  - [Tensorflow implementation of Image Segmentation on Python](https://github.com/jakeret/tf_unet)
#
#
#  - If you want to run this notebook without GPUs then install `tensorflow` library and comment these lines:
#
#  ```python
#  config = tf.ConfigProto()
#  config.gpu_options.allow_growth = True```
#   and change
#   ```python
#   tf.Session(config=config)```
#   by
#   ```python
#   tf.Session()```
#  - In order to check whether GPU is correctly called by tensorflow run this line:
#  ```python
#  from tensorflow.python.client import device_lib
# local_device_protos = device_lib.list_local_devices()```
# and check the output you got on `terminal` where you initialized `Jupyter notebook`. If your output shows `(/gpu:0)` in last line then it is correct. If you are using Non-GPU tensorflow then your output should be `(/cpu:0)`.
#
#
# Project Description
# ======
#
# ______
#
# ### Data
#  - Input data consists of 2D dicom format images of ** 512*512 ** pixels of various patients. Input dataset reffered here as **`train_images_input`** contains 2490 images with grayscale values.
#  - Labelled data consists of binary indicated images of **0s** and **1s** where **1s** tells presence of headrest and **0s** tells background without headrest.
#
# ### Model
#  - Model built here is 7 layer Convolutional nueral networks with pooling and upsampling. Below is the structure of network:
#
#  - Parameters which are used in this model:
#
#
# | Parameter        | Value           |
# | ------------- |:-------------:|
# | Filter size   | **`3*3`**   |
# | Pool size    | **`2*2`**   |
# | Zero Padding  | **`1`**  |
# | Padding    | **`VALID`**   |
# | Cost Function      | **`Softmax Cross Entropy`** |
# | Optimizer      |  **`Momentum`**    |
# | Epocs | **`150`**      |
# | Training Iterations     | **`50`** |
# | Learning Rate        |  **`0.2`**  |
# | Decay Rate         |  **`0.95`**   |
#
#
#
#  - Accuracy is calculated on pixel wise correct classification of an image.
#  - Predictions after each epoc is stored in **`prediction_model_50_500_3`** folder.
#  - Model outputs are stored in pickel format in **`unet_trained_50_500_3`** folder.

# %% [markdown]
# ______
# ## ``` Importing Libraries```

# %%
from __future__ import division, print_function,absolute_import, unicode_literals
# %matplotlib inline
import matplotlib.pyplot as plt                                    ##...Plotting libraries
import matplotlib                                                  
import numpy as np                                                 ##...for mathematical operations
import glob                                                        ##...for importing directories and paths
from PIL import Image                                              ##...for saving images
import os
import shutil
from glob import glob
from collections import OrderedDict
import logging                                                     ##...for making logs on progress based on real time
import tensorflow as tf                                            ##...for building Convolutional Neural Networks 
import dicom
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import scipy.ndimage
from skimage import morphology
from skimage import measure
from skimage.transform import resize
from sklearn.cluster import KMeans
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.tools import FigureFactory as FF
from plotly.graph_objs import *
from matplotlib.patches import Ellipse
from skimage import io, color, measure, draw, img_as_bool
from scipy import optimize
import pandas as pd
from skimage import color

# %%
from tensorflow.python.client import device_lib                    ##...to check whether GPU is called properly or not
local_device_protos = device_lib.list_local_devices()

# %%
config = tf.ConfigProto()                                          ##...to allow bfc::Allocator provide more than default 
config.gpu_options.allow_growth = True                             ##...memory  to GPU

# %% [markdown]
# ______
# ## ``` Importing Data :: Preprocessing```

# %% [markdown]
# > This data is preprocessed in **```Segmentation_headrest_label.ipynb```**
#
# > Importing Data stored in numpy arrays using **```np.load()```**
#
# > Offsetting the **```grayscale values```** by **```1024 HU units```** to make all values positive.

# %%
train_images_input = np.load('/home/ctuser/Desktop/Semantic_Seg/datatrain_images_input__big_masked_2.npy')
ground_truth_images = np.load('/home/ctuser/Desktop/Semantic_Seg/datatrain_images_groundtruth_big_masked_2.npy')

# %%
offset = np.ones_like(train_images_input,dtype=np.float32)
offset = offset*1024.

# %%
train_images_input+=offset
#train_images_input = train_images_input.astype('float32')
#ground_truth_images = ground_truth_images.astype('float32')

# %%
offset=1 ## to free up the space

# %% [markdown]
# > Creating Training and testing Sample data for future using **```train_test_split```** function.

# %%
## data_train, data_test, labels_train, labels_test = train_test_split(train_images_input,
##                                                                   ground_truth_images, test_size=0.20,random_state=42)

# %%
## training data and labels = data_train, labels_train
## testing data and labels = data_test, labels_test

# %% [markdown]
# > Creating Class - **```BaseDataProvider```** for importing data and making **```4D Tensors```** and giving batch-wise output when called.
#
# > Parameter here is **```n```** - Number of randomly sample data you want to call in **```4D Tensor```** format.

# %%
class BaseDataProvider(object):
    """
    This class is used to import, preprocessing of data
    before feeding into Convolutional neural networks.
    It also create labels into same fashion.
    """
    
    #channels = 1
    #n_class = 2
    def __init__(self,data,label,a_min=None,a_max=None,channels =1,n_class =2):
        self.a_min = a_min if a_min is not None else -np.inf
        self.a_max = a_max if a_max is not None else np.inf
        self.data = data
        self.label = label
        self.file_count = data.shape[0]
        self.n_class=n_class
        self.channels = channels
    
    def _next_data(self):
        idx = np.random.choice(self.file_count)
        return self.data[idx], self.label[idx]
    
    def _load_data_and_label(self):
        data, label = self._next_data()
        
        train_data = self._process_data(data)
        labels = self._process_labels(label)
        
        train_data, labels = self._postprocess_data(train_data, labels)
        
        nx = data.shape[1]
        ny = data.shape[0]
        
        return train_data.reshape(1, ny, nx, self.channels), labels.reshape(1, ny, nx, self.n_class)
    
    def _process_labels(self, label):
        if self.n_class==2:
            nx = label.shape[1]
            ny = label.shape[0]
            labels = np.zeros((ny,nx,self.n_class),dtype=np.float32)
            one = np.ones_like(labels[...,0],dtype=np.float32)
            labels[...,0] = one - label
            labels[...,1] = label
            return labels
        
        return label
    
    def _process_data(self, data):
        data = np.clip(data, self.a_min, self.a_max)
        data = data-np.amin(data)    
        data = data/np.amax(data)
        return data
    
    def _postprocess_data(self,data,labels):
        """
        Post processing can be done to make it more easier 
        for CNN to work and give better accuracy.
        
        """
        return data, labels
    
    def __call__(self,n):
        train_data, labels = self._load_data_and_label()
        nx = train_data.shape[1]
        ny = train_data.shape[2]
        
        X = np.zeros((n, nx, ny, self.channels))
        Y = np.zeros((n, nx, ny, self.n_class))
        
        X[0] = train_data
        Y[0] = labels
        
        for i in range(1,n):
            train_data, labels = self._load_data_and_label()
            X[i] = train_data
            Y[i] = labels
            
        
        return X, Y

# %%
class BaseDataProvidertest(object):
    """
    This class is used to import, preprocessing of data
    before feeding into Convolutional neural networks.
    It also create labels into same fashion.
    """
    
    #channels = 1
    #n_class = 2
    def __init__(self,data,a_min=None,a_max=None,channels =1,n_class =2):
        self.a_min = a_min if a_min is not None else -np.inf
        self.a_max = a_max if a_max is not None else np.inf
        self.data = data
        self.file_count = data.shape[0]
        self.n_class=n_class
        self.channels = channels
    
    def _next_data(self,i):
        #idx = np.random.choice(self.file_count)
        return self.data[i]
    
    def _load_data_and_label(self,i):
        data = self._next_data(i)
        
        train_data, min_data_i, max_data_i = self._process_data(data)
        
        train_data = self._postprocess_data(train_data)
        
        nx = data.shape[1]
        ny = data.shape[0]
        
        return train_data.reshape(1, ny, nx, self.channels), min_data_i, max_data_i
    
    def _process_data(self, data):
        data = np.clip(data, self.a_min, self.a_max)
        min_val = np.amin(data)
        max_val = np.amax(data)
        data = data-np.amin(data)    
        data = data/np.amax(data)
        return data, min_val, max_val
    
    def _postprocess_data(self,data):
        """
        Post processing can be done to make it more easier 
        for CNN to work and give better accuracy.
        
        """
        return data
    
    def __call__(self,n):
        i=0
        train_data, min_data_i, max_data_i = self._load_data_and_label(i)
        nx = train_data.shape[1]
        ny = train_data.shape[2]
        
        X = np.zeros((n, nx, ny, self.channels))
        Y = np.zeros((n, 2))
        X[0] = train_data
        Y[0, 0] = min_data_i
        Y[0, 1] = max_data_i
        for i in range(1,n):
            train_data, min_data_i, max_data_i = self._load_data_and_label(i)
            X[i] = train_data
            Y[i, 0] = min_data_i
            Y[i, 1] = max_data_i
            
        
        return X, Y

# %%
mydata_test = BaseDataProvidertest(data = train_images_input, channels=1, n_class=2)

# %%
X_test, min_max = mydata_test(5)

# %%
mydata = BaseDataProvider(data=train_images_input, label=ground_truth_images,channels=1,n_class=2)

# %%
## mydata_test = BaseDataProvider(data=data_test, label=labels_test,channels=1,n_class=2)

# %% [markdown]
# > Creating small sample in **```X_test, Y_test```** to check predictions on it once model is trained.

# %%
X_test, Y_test = mydata(50)

# %% [markdown]
# > **```Input image```** and its **```label```** looks like this:

# %%
fig, ax = plt.subplots(1,1, sharey=True, figsize=(8,8))
ax.imshow(X_test[0,...,0], aspect="auto")
#ax[1].imshow(Y_test[0,...,0], aspect="auto")

# %% [markdown]
# > Importing Data from the given **```input_folder```**

# %%
data_path = "/home/ctuser/myData/s438/"              ##... insert the data_path
output_path = working_path = "/home/ctuser/Desktop/Semantic_Seg/data"
g = glob(data_path + "/*")

print("Total no. of CT images are: %d \nFirst 5 elements:" %len(g))
print ('\n'.join(g[:5]))
# Out:
# Total no. of CT images are: 34
# First 5 elements:
# /home/ctuser/myData/s438/i36941.CTDC.20
# /home/ctuser/myData/s438/i36953.CTDC.32
# /home/ctuser/myData/s438/i36940.CTDC.19
# /home/ctuser/myData/s438/i36922.CTDC.1
# /home/ctuser/myData/s438/i36955.CTDC.34

# %% [markdown]
# > Loading CT Scan Images and calculate HU units for each pixels
#
# > **```load_scan```** : loading all the image slices for each patient folder
#
# > **```get_pixels_hu```** : Storing HU_units pixel array in **```numpy```** format for image processing

# %%
def load_scan(path):
    slices = [dicom.read_file(path + '/' + s) for s in os.listdir(path)]
    slices.sort(key = lambda x: int(x.InstanceNumber))
    try:
        slice_thickness = np.abs(slices[0].ImagePositionPatient[2] - slices[1].ImagePositionPatient[2])
    except:
        slice_thickness = np.abs(slices[0].SliceLocation - slices[1].SliceLocation)
    for s in slices:
        s.SliceThickness = slice_thickness
    return slices

def get_pixels_hu(scans):
    image = np.stack([s.pixel_array for s in scans])
    # Convert to int16 (from sometimes int16), 
    # should be possible as values should always be low enough (<32k)
    image = image.astype(np.int16)

    # Set outside-of-scan pixels to 1
    # The intercept is usually -1024, so air is approximately 0
    image[image == -2000] = 0
    
    # Convert to Hounsfield units (HU)
    intercept = scans[0].RescaleIntercept
    slope = scans[0].RescaleSlope
    
    if slope != 1:
        image = slope * image.astype(np.float64)
        image = image.astype(np.int16)
        
    image += np.int16(intercept)
    
    return np.array(image, dtype=np.int16)

id=1000000
patient = load_scan(data_path)
imgs = get_pixels_hu(patient)

# %%
offset = np.ones_like(imgs,dtype=np.float32)
imgs = imgs.astype("float32")
offset = offset*1024.
imgs+=offset
offset=1

# %% [markdown]
# ______
# ## **```Building Convolutional Networks```**

# %% [markdown]
# > Defining some functions which we will use in later part of notebook:
#   - **```plot_prediction```** : takes ```test_data, labels, predictions``` and plot the images; can be used to save the output as well.
#   - **```crop_to_shape```** : crop ```initial_tensor``` to ```final_tensor``` shape
#   - **```to_rgb```** : convert given image to RGB format; not used here
#   - **```error_rate```** : error of prediction in **%** format
#   - **```get_image_summary```** : gives image summary
#   - **```combine_img_prediction ```** : Combines the data, grouth thruth and the prediction into one rgb image; amethod to visualize
#   - **```save_image ```** : to save the image

# %%
def plot_prediction(x_test, y_test, prediction, save=False):
    import matplotlib
    import matplotlib.pyplot as plt
    
    test_size = x_test.shape[0]
    fig, ax = plt.subplots(test_size, 3, figsize=(12,12), sharey=True, sharex=True)
    ax = np.atleast_2d(ax)
    for i in range(test_size):
        cax = ax[i, 0].imshow(x_test[i,...,0])
        plt.colorbar(cax, ax=ax[i,0])
        cax = ax[i, 1].imshow(y_test[i, ..., 1])
        plt.colorbar(cax, ax=ax[i,1])
        pred = prediction[i, ..., 1]
        #pred -= np.amin(pred)                           ## recheck this :: might create some errors later.
        #pred /= np.amax(pred)
        cax = ax[i, 2].imshow(pred)
        plt.colorbar(cax, ax=ax[i,2])
        if i==0:
            ax[i, 0].set_title("x")
            ax[i, 1].set_title("y")
            ax[i, 2].set_title("pred")
    #fig.tight_layout()
    
    if save:
        fig.savefig(save)
    else:
        fig.show()
plt.show()

# %%
def crop_to_shape(data, shape):
    """
    Crops the array to the given image shape by removing the border (expects a tensor of shape [batches, nx, ny, channels].
    
    :param data: the array to crop
    :param shape: the target shape
    """
    offset0 = (data.shape[1] - shape[1])//2
    offset1 = (data.shape[2] - shape[2])//2
    if data.shape[1] == shape[1]:
        return data
    else:
        return data[:, offset0:(-offset0), offset1:(-offset1)]

# %%
def to_rgb(img):
    """
    Converts the given array into a RGB image. If the number of channels is not
    3 the array is tiled such that it has 3 channels. Finally, the values are
    rescaled to [0,255) 
    
    :param img: the array to convert [nx, ny, channels]
    
    :returns img: the rgb image [nx, ny, 3]
    """
    img = np.atleast_3d(img)
    channels = img.shape[2]
    if channels < 3:
        img = np.tile(img, 3)
    
    img[np.isnan(img)] = 0
    img -= np.amin(img)
    img /= np.amax(img)
    img *= 255
    return img

# %%
def error_rate(predictions, labels):
    """
    Return the error rate based on dense predictions and 1-hot labels.
    """
    
    return 100.0 - (100.0 * np.sum(np.argmax(predictions, 3) == np.argmax(labels, 3)) /
                    (predictions.shape[0]*predictions.shape[1]*predictions.shape[2]))

# %%
def get_image_summary(img, idx=0):
    """
    Make an image summary for 4d tensor image with index idx
    """
    
    V = tf.slice(img, (0, 0, 0, idx), (1, -1, -1, 1))
    V -= tf.reduce_min(V)
    V /= tf.reduce_max(V)
    V *= 255
    
    img_w = tf.shape(img)[1]
    img_h = tf.shape(img)[2]
    V = tf.reshape(V, tf.stack((img_w, img_h, 1)))
    V = tf.transpose(V, (2, 0, 1))
    V = tf.reshape(V, tf.stack((-1, img_w, img_h, 1)))
    return V

# %%
def combine_img_prediction(data, gt, pred):
    """
    Combines the data, grouth thruth and the prediction into one rgb image
    
    :param data: the data tensor
    :param gt: the ground thruth tensor
    :param pred: the prediction tensor
    
    :returns img: the concatenated rgb image 
    """
    ny = pred.shape[2]
    ch = data.shape[3]
    img = np.concatenate((to_rgb(crop_to_shape(data, pred.shape).reshape(-1, ny, ch)), 
                          to_rgb(crop_to_shape(gt[..., 1], pred.shape).reshape(-1, ny, 1)), 
                          to_rgb(pred[..., 1].reshape(-1, ny, 1))), axis=1)
    return img

def save_image(img, path):
    """
    Writes the image to disk
    
    :param img: the rgb image to save
    :param path: the target path
    """
    Image.fromarray(img.round().astype(np.uint8)).save(path, 'JPEG', dpi=[300,300], quality=90)

# %% [markdown]
# > **```layers initialization functions```**

# %%
def weight_variable(shape, stddev=0.1):
    initial = tf.truncated_normal(shape, stddev=stddev)
    return tf.Variable(initial)

def weight_variable_devonc(shape, stddev=0.1):
    return tf.Variable(tf.truncated_normal(shape, stddev=stddev))

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

def conv2d(x, W,keep_prob_):
    conv_2d = tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='VALID')
    return tf.nn.dropout(conv_2d, keep_prob_)

def deconv2d(x, W,stride):
    x_shape = tf.shape(x)
    output_shape = tf.stack([x_shape[0], x_shape[1]*2, x_shape[2]*2, x_shape[3]//2])
    return tf.nn.conv2d_transpose(x, W, output_shape, strides=[1, stride, stride, 1], padding='VALID')

def max_pool(x,n):
    return tf.nn.max_pool(x, ksize=[1, n, n, 1], strides=[1, n, n, 1], padding='VALID')

def crop_and_concat(x1,x2):
    x1_shape = tf.shape(x1)
    x2_shape = tf.shape(x2)
    # offsets for the top left corner of the crop
    offsets = [0, (x1_shape[1] - x2_shape[1]) // 2, (x1_shape[2] - x2_shape[2]) // 2, 0]
    size = [-1, x2_shape[1], x2_shape[2], -1]
    x1_crop = tf.slice(x1, offsets, size)
    return tf.concat([x1_crop, x2], 3)   

def pixel_wise_softmax(output_map):
    exponential_map = tf.exp(output_map)
    evidence = tf.add(exponential_map,tf.reverse(exponential_map,[False,False,False,True]))
    return tf.div(exponential_map,evidence, name="pixel_wise_softmax")

def pixel_wise_softmax_2(output_map):
    exponential_map = tf.exp(output_map)
    sum_exp = tf.reduce_sum(exponential_map, 3, keep_dims=True)
    tensor_sum_exp = tf.tile(sum_exp, tf.stack([1, 1, 1, tf.shape(output_map)[3]]))
    return tf.div(exponential_map,tensor_sum_exp)

def cross_entropy(y_,output_map):
    return -tf.reduce_mean(y_*tf.log(tf.clip_by_value(output_map,1e-10,1.0)), name="cross_entropy")
#     return tf.reduce_mean(-tf.reduce_sum(y_ * tf.log(output_map), reduction_indices=[1]))

# %%
logging.basicConfig(level=logging.INFO, format='%(asctime)s %(message)s')  ## to get log of real time and progress

# %% [markdown]
# ______
# ## **```Model Training```**

# %% [markdown]
# >  **```Model_1```** : layers=5 with 2 Convolutional layer each

# %%
def create_conv_net_1(x, keep_prob, channels, n_class, layers=5, features_root=16, filter_size=3, pool_size=2, summaries=False):
    """
    Creates a new convolutional unet for the given parametrization.
    
    :param x: input tensor, shape [?,nx,ny,channels]
    :param keep_prob: dropout probability tensor
    :param channels: number of channels in the input image
    :param n_class: number of output labels
    :param layers: number of layers in the net
    :param features_root: number of features in the first layer
    :param filter_size: size of the convolution filter
    :param pool_size: size of the max pooling operation
    :param summaries: Flag if summaries should be created
    """
    
    logging.info("Layers {layers}, features {features}, filter size {filter_size}x{filter_size},pool size: {pool_size}x{pool_size}".format(layers=layers,
                                                                                                           features=features_root,
                                                                                                           filter_size=filter_size,
                                                                                                           pool_size=pool_size))
    # Placeholder for the input image
    nx = tf.shape(x)[1]
    ny = tf.shape(x)[2]
    x_image = tf.reshape(x, tf.stack([-1,nx,ny,channels]))
    in_node = x_image
    batch_size = tf.shape(x_image)[0]
 
    weights = []
    biases = []
    convs = []
    pools = OrderedDict()
    deconv = OrderedDict()
    dw_h_convs = OrderedDict()
    up_h_convs = OrderedDict()
    paddings=[[0,0],[1,1],[1,1],[0,0]]
    in_size = 1000
    size = in_size
    # down layers
    for layer in range(0, layers):
        features = 2**layer*features_root
        stddev = np.sqrt(2 / (filter_size**2 * features))
        if layer == 0:
            w1 = weight_variable([filter_size, filter_size, channels, features], stddev)
        else:
            w1 = weight_variable([filter_size, filter_size, features//2, features], stddev)
            
        w2 = weight_variable([filter_size, filter_size, features, features], stddev)
        b1 = bias_variable([features])
        b2 = bias_variable([features])
        
        in_node = tf.pad(in_node,paddings,"CONSTANT")
        conv1 = conv2d(in_node, w1, keep_prob)
        tmp_h_conv = tf.nn.relu(conv1 + b1)
        tmp_h_conv = tf.pad(tmp_h_conv,paddings,"CONSTANT")
        conv2 = conv2d(tmp_h_conv, w2, keep_prob)
        dw_h_convs[layer] = tf.nn.relu(conv2 + b2)
        
        weights.append((w1, w2))
        biases.append((b1, b2))
        convs.append((conv1, conv2))
        
        size -= 4
        if layer < layers-1:
            pools[layer] = max_pool(dw_h_convs[layer], pool_size)
            in_node = pools[layer]
            size /= 2
        
    in_node = dw_h_convs[layers-1]
        
    # up layers
    for layer in range(layers-2, -1, -1):
        
        features = 2**(layer+1)*features_root
        stddev = np.sqrt(2 / (filter_size**2 * features))
        
        wd = weight_variable_devonc([pool_size, pool_size, features//2, features], stddev)
        bd = bias_variable([features//2])
        h_deconv = tf.nn.relu(deconv2d(in_node, wd, pool_size) + bd)
        h_deconv_concat = crop_and_concat(dw_h_convs[layer], h_deconv)
        deconv[layer] = h_deconv_concat
        
        w1 = weight_variable([filter_size, filter_size, features, features//2], stddev)
        w2 = weight_variable([filter_size, filter_size, features//2, features//2], stddev)
        b1 = bias_variable([features//2])
        b2 = bias_variable([features//2])
        
        h_deconv_concat = tf.pad(h_deconv_concat,paddings,"CONSTANT")
        conv1 = conv2d(h_deconv_concat, w1, keep_prob)
        h_conv = tf.nn.relu(conv1 + b1)
        h_conv = tf.pad(h_conv,paddings,"CONSTANT")
        conv2 = conv2d(h_conv, w2, keep_prob)
        in_node = tf.nn.relu(conv2 + b2)
        up_h_convs[layer] = in_node

        weights.append((w1, w2))
        biases.append((b1, b2))
        convs.append((conv1, conv2))
        
        size *= 2
        size -= 4

    # Output Map
    weight = weight_variable([1, 1, features_root, n_class], stddev)
    bias = bias_variable([n_class])
    conv = conv2d(in_node, weight, tf.constant(1.0))
    output_map = tf.nn.relu(conv + bias)
    up_h_convs["out"] = output_map
    
    if summaries:
        for i, (c1, c2) in enumerate(convs):
            tf.summary.image('summary_conv_%02d_01'%i, get_image_summary(c1))
            tf.summary.image('summary_conv_%02d_02'%i, get_image_summary(c2))
            
        for k in pools.keys():
            tf.summary.image('summary_pool_%02d'%k, get_image_summary(pools[k]))
        
        for k in deconv.keys():
            tf.summary.image('summary_deconv_concat_%02d'%k, get_image_summary(deconv[k]))
            
        for k in dw_h_convs.keys():
            tf.summary.histogram("dw_convolution_%02d"%k + '/activations', dw_h_convs[k])

        for k in up_h_convs.keys():
            tf.summary.histogram("up_convolution_%s"%k + '/activations', up_h_convs[k])
            
    variables = []
    for w1,w2 in weights:
        variables.append(w1)
        variables.append(w2)
        
    for b1,b2 in biases:
        variables.append(b1)
        variables.append(b2)

    
    return output_map, variables, int(in_size - size)

# %% [markdown]
# > **``` Model_2 ```** : layers=7 with 2 Convolutional layer each

# %%
def create_conv_net_2(x, keep_prob, channels, n_class, layers=7, features_root=16, filter_size=3, pool_size=2, summaries=False):
    """
    Creates a new convolutional unet for the given parametrization.
    
    :param x: input tensor, shape [?,nx,ny,channels]
    :param keep_prob: dropout probability tensor
    :param channels: number of channels in the input image
    :param n_class: number of output labels
    :param layers: number of layers in the net
    :param features_root: number of features in the first layer
    :param filter_size: size of the convolution filter
    :param pool_size: size of the max pooling operation
    :param summaries: Flag if summaries should be created
    """
    
    logging.info("Layers {layers}, features {features}, filter size {filter_size}x{filter_size},pool size: {pool_size}x{pool_size}".format(layers=layers,
                                                                                                           features=features_root,
                                                                                                           filter_size=filter_size,
                                                                                                           pool_size=pool_size))
    # Placeholder for the input image
    nx = tf.shape(x)[1]
    ny = tf.shape(x)[2]
    x_image = tf.reshape(x, tf.stack([-1,nx,ny,channels]))
    in_node = x_image
    batch_size = tf.shape(x_image)[0]
 
    weights = []
    biases = []
    convs = []
    pools = OrderedDict()
    deconv = OrderedDict()
    dw_h_convs = OrderedDict()
    up_h_convs = OrderedDict()
    paddings=[[0,0],[1,1],[1,1],[0,0]]
    in_size = 1000
    size = in_size
    # down layers
    for layer in range(0, layers):
        features = 2**layer*features_root
        stddev = np.sqrt(2 / (filter_size**2 * features))
        if layer == 0:
            w1 = weight_variable([filter_size, filter_size, channels, features], stddev)
        else:
            w1 = weight_variable([filter_size, filter_size, features//2, features], stddev)
            
        w2 = weight_variable([filter_size, filter_size, features, features], stddev)
        b1 = bias_variable([features])
        b2 = bias_variable([features])
        
        in_node = tf.pad(in_node,paddings,"CONSTANT")
        conv1 = conv2d(in_node, w1, keep_prob)
        tmp_h_conv = tf.nn.relu(conv1 + b1)
        tmp_h_conv = tf.pad(tmp_h_conv,paddings,"CONSTANT")
        conv2 = conv2d(tmp_h_conv, w2, keep_prob)
        dw_h_convs[layer] = tf.nn.relu(conv2 + b2)
        
        weights.append((w1, w2))
        biases.append((b1, b2))
        convs.append((conv1, conv2))
        
        size -= 4
        if layer < layers-1:
            pools[layer] = max_pool(dw_h_convs[layer], pool_size)
            in_node = pools[layer]
            size /= 2
        
    in_node = dw_h_convs[layers-1]
        
    # up layers
    for layer in range(layers-2, -1, -1):
        
        features = 2**(layer+1)*features_root
        stddev = np.sqrt(2 / (filter_size**2 * features))
        
        wd = weight_variable_devonc([pool_size, pool_size, features//2, features], stddev)
        bd = bias_variable([features//2])
        h_deconv = tf.nn.relu(deconv2d(in_node, wd, pool_size) + bd)
        h_deconv_concat = crop_and_concat(dw_h_convs[layer], h_deconv)
        deconv[layer] = h_deconv_concat
        
        w1 = weight_variable([filter_size, filter_size, features, features//2], stddev)
        w2 = weight_variable([filter_size, filter_size, features//2, features//2], stddev)
        b1 = bias_variable([features//2])
        b2 = bias_variable([features//2])
        
        h_deconv_concat = tf.pad(h_deconv_concat,paddings,"CONSTANT")
        conv1 = conv2d(h_deconv_concat, w1, keep_prob)
        h_conv = tf.nn.relu(conv1 + b1)
        h_conv = tf.pad(h_conv,paddings,"CONSTANT")
        conv2 = conv2d(h_conv, w2, keep_prob)
        in_node = tf.nn.relu(conv2 + b2)
        up_h_convs[layer] = in_node

        weights.append((w1, w2))
        biases.append((b1, b2))
        convs.append((conv1, conv2))
        
        size *= 2
        size -= 4

    # Output Map
    weight = weight_variable([1, 1, features_root, n_class], stddev)
    bias = bias_variable([n_class])
    conv = conv2d(in_node, weight, tf.constant(1.0))
    output_map = tf.nn.relu(conv + bias)
    up_h_convs["out"] = output_map
    
    if summaries:
        for i, (c1, c2) in enumerate(convs):
            tf.summary.image('summary_conv_%02d_01'%i, get_image_summary(c1))
            tf.summary.image('summary_conv_%02d_02'%i, get_image_summary(c2))
            
        for k in pools.keys():
            tf.summary.image('summary_pool_%02d'%k, get_image_summary(pools[k]))
        
        for k in deconv.keys():
            tf.summary.image('summary_deconv_concat_%02d'%k, get_image_summary(deconv[k]))
            
        for k in dw_h_convs.keys():
            tf.summary.histogram("dw_convolution_%02d"%k + '/activations', dw_h_convs[k])

        for k in up_h_convs.keys():
            tf.summary.histogram("up_convolution_%s"%k + '/activations', up_h_convs[k])
            
    variables = []
    for w1,w2 in weights:
        variables.append(w1)
        variables.append(w2)
        
    for b1,b2 in biases:
        variables.append(b1)
        variables.append(b2)

    
    return output_map, variables, int(in_size - size)

# %% [markdown]
# > **``` Model_3 layer ```** : layers = 7 with convolutional varying : 2,4,8 each 3,3,1 layers

# %%
def create_conv_net_3(x, keep_prob, channels, n_class, layers=7, features_root=16, filter_size=3, pool_size=2, summaries=False):
    """
    Creates a new convolutional unet for the given parametrization.
    
    :param x: input tensor, shape [?,nx,ny,channels]
    :param keep_prob: dropout probability tensor
    :param channels: number of channels in the input image
    :param n_class: number of output labels
    :param layers: number of layers in the net
    :param features_root: number of features in the first layer
    :param filter_size: size of the convolution filter
    :param pool_size: size of the max pooling operation
    :param summaries: Flag if summaries should be created
    """
    
    logging.info("Layers {layers}, features {features}, filter size {filter_size}x{filter_size},pool size: {pool_size}x{pool_size}".format(layers=layers,
                                                                                                           features=features_root,
                                                                                                           filter_size=filter_size,
                                                                                                           pool_size=pool_size))
    # Placeholder for the input image
    nx = tf.shape(x)[1]
    ny = tf.shape(x)[2]
    x_image = tf.reshape(x, tf.stack([-1,nx,ny,channels]))
    in_node = x_image
    batch_size = tf.shape(x_image)[0]
 
    weights1 = []
    weights2= []
    weights3 = []
    biases1 = []
    biases2 = []
    biases3 = []
    convs1 = []
    convs2 = []
    convs3 = []
    pools = OrderedDict()
    deconv = OrderedDict()
    dw_h_convs = OrderedDict()
    up_h_convs = OrderedDict()
    paddings=[[0,0],[1,1],[1,1],[0,0]]
    in_size = 1000
    size = in_size
    # down layers
    for layer in range(0, layers):
        features = 2**layer*features_root
        stddev = np.sqrt(2 / (filter_size**2 * features))
        if layer == 0:
            w1 = weight_variable([filter_size, filter_size, channels, features], stddev)
        else:
            w1 = weight_variable([filter_size, filter_size, features//2, features], stddev)
            
        w2 = weight_variable([filter_size, filter_size, features, features], stddev)
        b1 = bias_variable([features])
        b2 = bias_variable([features])
        
        in_node = tf.pad(in_node,paddings,"CONSTANT")
        conv1 = conv2d(in_node, w1, keep_prob)
        tmp_h_conv = tf.nn.relu(conv1 + b1)
        tmp_h_conv = tf.pad(tmp_h_conv,paddings,"CONSTANT")
        conv2 = conv2d(tmp_h_conv, w2, keep_prob)
        if layer>=3:
            tmp_h_conv2 = tf.nn.relu(conv2 + b2)
        else:
            dw_h_convs[layer] = tf.nn.relu(conv2 + b2)
        
        ####
        if layer>=3:
            w3 = weight_variable([filter_size, filter_size, features, features], stddev)
            b3 = bias_variable([features])
            w4 = weight_variable([filter_size, filter_size, features, features], stddev)
            b4 = bias_variable([features])
            tmp_h_conv2 = tf.pad(tmp_h_conv2,paddings,"CONSTANT")
            conv3 = conv2d(tmp_h_conv2, w3, keep_prob)
            tmp_h_conv3 = tf.nn.relu(conv3 +b3)
            tmp_h_conv3 = tf.pad(tmp_h_conv3,paddings,"CONSTANT")
            conv4 = conv2d(tmp_h_conv3, w4, keep_prob)
            if layer>=6:
                tmp_h_conv4 = tf.nn.relu(conv4 + b4)
            else:
                dw_h_convs[layer] = tf.nn.relu(conv4 + b4)
        ####
        ####
        if layer>=6:
            w5 = weight_variable([filter_size, filter_size, features, features], stddev)
            b5 = bias_variable([features])
            w6 = weight_variable([filter_size, filter_size, features, features], stddev)
            b6 = bias_variable([features])
            w7 = weight_variable([filter_size, filter_size, features, features], stddev)
            b7 = bias_variable([features])
            w8 = weight_variable([filter_size, filter_size, features, features], stddev)
            b8 = bias_variable([features])
            tmp_h_conv4 = tf.pad(tmp_h_conv4,paddings,"CONSTANT")
            conv5 = conv2d(tmp_h_conv4, w5, keep_prob)
            tmp_h_conv5 = tf.nn.relu(conv5 +b5)
            tmp_h_conv5 = tf.pad(tmp_h_conv5,paddings,"CONSTANT")
            conv6 = conv2d(tmp_h_conv5, w6, keep_prob)
            tmp_h_conv6 = tf.nn.relu(conv6 +b6)
            tmp_h_conv6 = tf.pad(tmp_h_conv6,paddings,"CONSTANT")
            conv7 = conv2d(tmp_h_conv6, w7, keep_prob)
            tmp_h_conv7 = tf.nn.relu(conv7 +b7)
            tmp_h_conv7 = tf.pad(tmp_h_conv7,paddings,"CONSTANT")
            conv8 = conv2d(tmp_h_conv7, w8, keep_prob)
            dw_h_convs[layer] = tf.nn.relu(conv8 + b8)
        ####
        if layer<3:
            weights1.append((w1, w2))
            biases1.append((b1, b2))
            convs1.append((conv1, conv2))
        ####
        if layer>=3 and layer<6:
            weights2.append((w1, w2, w3, w4))
            biases2.append((b1, b2, b3, b4))
            convs2.append((conv1, conv2, conv3, conv4))
        ####
        ####
        if layer>=6:
            weights3.append((w1, w2, w3, w4, w5, w6, w7, w8))
            biases3.append((b1, b2, b3, b4, b5, b6, b7,  b8))
            convs3.append((conv1, conv2, conv3, conv4, conv5, conv6, conv7, conv8))
        ####
        
        size -= 4
        if layer < layers-1:
            pools[layer] = max_pool(dw_h_convs[layer], pool_size)
            in_node = pools[layer]
            size /= 2
        
    in_node = dw_h_convs[layers-1]
        
    # up layers
    for layer in range(layers-2, -1, -1):
        
        features = 2**(layer+1)*features_root
        stddev = np.sqrt(2 / (filter_size**2 * features))
        
        wd = weight_variable_devonc([pool_size, pool_size, features//2, features], stddev)
        bd = bias_variable([features//2])
        h_deconv = tf.nn.relu(deconv2d(in_node, wd, pool_size) + bd)
        h_deconv_concat = crop_and_concat(dw_h_convs[layer], h_deconv)
        deconv[layer] = h_deconv_concat
        
        w1 = weight_variable([filter_size, filter_size, features, features//2], stddev)
        w2 = weight_variable([filter_size, filter_size, features//2, features//2], stddev)
        b1 = bias_variable([features//2])
        b2 = bias_variable([features//2])
        
        h_deconv_concat = tf.pad(h_deconv_concat,paddings,"CONSTANT")
        conv1 = conv2d(h_deconv_concat, w1, keep_prob)
        h_conv = tf.nn.relu(conv1 + b1)
        h_conv = tf.pad(h_conv,paddings,"CONSTANT")
        conv2 = conv2d(h_conv, w2, keep_prob)
        if layer>=3:
            w3 = weight_variable([filter_size, filter_size, features//2, features//2], stddev)
            b3 = bias_variable([features//2])
            w4 = weight_variable([filter_size, filter_size, features//2, features//2], stddev)
            b4 = bias_variable([features//2])
            h_conv2 = tf.nn.relu(conv2 + b2)
            h_conv2 = tf.pad(h_conv2,paddings,"CONSTANT")
            conv3 = conv2d(h_conv2, w3, keep_prob)
            h_conv3 = tf.nn.relu(conv3 + b3)
            h_conv3 = tf.pad(h_conv3,paddings,"CONSTANT")
            conv4 = conv2d(h_conv3, w4, keep_prob)
            in_node = tf.nn.relu(conv4 + b4)
            up_h_convs[layer] = in_node
        else:
            in_node = tf.nn.relu(conv2 + b2)
            up_h_convs[layer] = in_node

        ####
        if layer<3:
            weights1.append((w1, w2))
            biases1.append((b1, b2))
            convs1.append((conv1, conv2))
        ####
        if layer>=3:
            weights2.append((w1, w2, w3, w4))
            biases2.append((b1, b2, b3, b4))
            convs2.append((conv1, conv2, conv3, conv4))
        
        size *= 2
        size -= 4

    # Output Map
    weight = weight_variable([1, 1, features_root, n_class], stddev)
    bias = bias_variable([n_class])
    conv = conv2d(in_node, weight, tf.constant(1.0))
    output_map = tf.nn.relu(conv + bias)
    up_h_convs["out"] = output_map
    
    if summaries:
        for i, (c1, c2) in enumerate(convs):
            tf.summary.image('summary_conv_%02d_01'%i, get_image_summary(c1))
            tf.summary.image('summary_conv_%02d_02'%i, get_image_summary(c2))
            
        for k in pools.keys():
            tf.summary.image('summary_pool_%02d'%k, get_image_summary(pools[k]))
        
        for k in deconv.keys():
            tf.summary.image('summary_deconv_concat_%02d'%k, get_image_summary(deconv[k]))
            
        for k in dw_h_convs.keys():
            tf.summary.histogram("dw_convolution_%02d"%k + '/activations', dw_h_convs[k])

        for k in up_h_convs.keys():
            tf.summary.histogram("up_convolution_%s"%k + '/activations', up_h_convs[k])
            
    variables = []
    for w1,w2 in weights1:
        variables.append(w1)
        variables.append(w2)
    
    for w1,w2,w3,w4 in weights2:
        variables.append(w1)
        variables.append(w2)
        variables.append(w3)
        variables.append(w4)
    
    for w1,w2,w3,w4,w5,w6,w7,w8 in weights3:
        variables.append(w1)
        variables.append(w2)
        variables.append(w3)
        variables.append(w4)
        variables.append(w5)
        variables.append(w6)
        variables.append(w7)
        variables.append(w8)
    
    for b1,b2 in biases1:
        variables.append(b1)
        variables.append(b2)
        
    for b1,b2,b3,b4 in biases2:
        variables.append(b1)
        variables.append(b2)
        variables.append(b3)
        variables.append(b4)
    
    for b1,b2,b3,b4,b5,b6,b7,b8 in biases3:
        variables.append(b1)
        variables.append(b2)
        variables.append(b3)
        variables.append(b4)
        variables.append(b5)
        variables.append(b6)
        variables.append(b7)
        variables.append(b8)

    
    return output_map, variables, int(in_size - size)

# %%
class Unet(object):
    """
    A unet implementation
    
    :param channels: (optional) number of channels in the input image
    :param n_class: (optional) number of output labels
    :param cost: (optional) name of the cost function. Default is 'cross_entropy'
    :param cost_kwargs: (optional) kwargs passed to the cost function. See Unet._get_cost for more options
    """
    
    def __init__(self, channels=1, n_class=2, cost="cross_entropy", cost_kwargs={}, **kwargs):
        tf.reset_default_graph()
        
        self.n_class = n_class
        self.summaries = kwargs.get("summaries", True)
        
        self.x = tf.placeholder("float", shape=[None, None, None, channels])
        self.y = tf.placeholder("float", shape=[None, None, None, n_class])
        self.keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)
        
        logits, self.variables, self.offset = create_conv_net_3(self.x, self.keep_prob, channels, n_class, **kwargs)
        
        self.cost = self._get_cost(logits, cost, cost_kwargs)
        
        self.gradients_node = tf.gradients(self.cost, self.variables)
         
        self.cross_entropy = tf.reduce_mean(cross_entropy(tf.reshape(self.y, [-1, n_class]),
                                                          tf.reshape(pixel_wise_softmax_2(logits), [-1, n_class])))
        
        self.predicter = pixel_wise_softmax_2(logits)
        self.correct_pred = tf.equal(tf.argmax(self.predicter, 3), tf.argmax(self.y, 3))
        self.accuracy = tf.reduce_mean(tf.cast(self.correct_pred, tf.float32))
        
    def _get_cost(self, logits, cost_name, cost_kwargs):
        """
        Constructs the cost function, either cross_entropy, weighted cross_entropy or dice_coefficient.
        Optional arguments are: 
        class_weights: weights for the different classes in case of multi-class imbalance
        regularizer: power of the L2 regularizers added to the loss function
        """
        
        flat_logits = tf.reshape(logits, [-1, self.n_class])
        flat_labels = tf.reshape(self.y, [-1, self.n_class])
        if cost_name == "cross_entropy":
            class_weights = cost_kwargs.pop("class_weights", None)
            
            if class_weights is not None:
                class_weights = tf.constant(np.array(class_weights, dtype=np.float32))
        
                weight_map = tf.multiply(flat_labels, class_weights)
                weight_map = tf.reduce_sum(weight_map, axis=1)
        
                loss_map = tf.nn.softmax_cross_entropy_with_logits(flat_logits, flat_labels)
                weighted_loss = tf.multiply(loss_map, weight_map)
        
                loss = tf.reduce_mean(weighted_loss)
                
            else:
                loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=flat_logits, 
                                                                              labels=flat_labels))
        elif cost_name == "dice_coefficient":
            eps = 1e-5
            prediction = pixel_wise_softmax_2(logits)
            intersection = tf.reduce_sum(prediction * self.y)
            union =  eps + tf.reduce_sum(prediction) + tf.reduce_sum(self.y)
            loss = -(2 * intersection/ (union))
            
        else:
            raise ValueError("Unknown cost function: "%cost_name)

        regularizer = cost_kwargs.pop("regularizer", None)
        if regularizer is not None:
            regularizers = sum([tf.nn.l2_loss(variable) for variable in self.variables])
            loss += (regularizer * regularizers)
            
        return loss

    def predict(self, model_path, x_test):
        """
        Uses the model to create a prediction for the given data
        
        :param model_path: path to the model checkpoint to restore
        :param x_test: Data to predict on. Shape [n, nx, ny, channels]
        :returns prediction: The unet prediction Shape [n, px, py, labels] (px=nx-self.offset/2) 
        """
        
        init = tf.global_variables_initializer()
        with tf.Session(config=config) as sess:
            # Initialize variables
            sess.run(init)
        
            # Restore model weights from previously saved model
            self.restore(sess, model_path)
            
            y_dummy = np.empty((x_test.shape[0], x_test.shape[1], x_test.shape[2], self.n_class))
            prediction = sess.run(self.predicter, feed_dict={self.x: x_test, self.y: y_dummy, self.keep_prob: 1.})
            
        return prediction
    
    def save(self, sess, model_path):
        """
        Saves the current session to a checkpoint
        
        :param sess: current session
        :param model_path: path to file system location
        """
        
        saver = tf.train.Saver()
        save_path = saver.save(sess, model_path)
        return save_path
    
    def restore(self, sess, model_path):
        """
        Restores a session from a checkpoint
        
        :param sess: current session instance
        :param model_path: path to file system checkpoint location
        """
        
        saver = tf.train.Saver()
        saver.restore(sess, model_path)
        logging.info("Model restored from file: %s" % model_path)

# %%
class Trainer(object):
    """
    Trains a unet instance
    
    :param net: the unet instance to train
    :param batch_size: size of training batch
    :param optimizer: (optional) name of the optimizer to use (momentum or adam)
    :param opt_kwargs: (optional) kwargs passed to the learning rate (momentum opt) and to the optimizer
    """
    
    prediction_path = "prediction_model_50_80_3"    ### to channge this before running......give number at the end.
    verification_batch_size = 10
    
    def __init__(self, net, batch_size=1, optimizer="momentum", opt_kwargs={}):
        self.net = net
        self.batch_size = batch_size
        self.optimizer = optimizer
        self.opt_kwargs = opt_kwargs
        
    def _get_optimizer(self, training_iters, global_step):
        if self.optimizer == "momentum":
            learning_rate = self.opt_kwargs.pop("learning_rate", 0.2)
            decay_rate = self.opt_kwargs.pop("decay_rate", 0.95)
            momentum = self.opt_kwargs.pop("momentum", 0.2)
            
            self.learning_rate_node = tf.train.exponential_decay(learning_rate=learning_rate, 
                                                        global_step=global_step, 
                                                        decay_steps=training_iters,  
                                                        decay_rate=decay_rate, 
                                                        staircase=True)
            
            optimizer = tf.train.MomentumOptimizer(learning_rate=self.learning_rate_node, momentum=momentum,
                                                   **self.opt_kwargs).minimize(self.net.cost, 
                                                                                global_step=global_step)
        elif self.optimizer == "adam":
            learning_rate = self.opt_kwargs.pop("learning_rate", 0.001)
            self.learning_rate_node = tf.Variable(learning_rate)
            
            optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate_node, 
                                               **self.opt_kwargs).minimize(self.net.cost,
                                                                     global_step=global_step)
        
        return optimizer
        
    def _initialize(self, training_iters, output_path, restore):
        global_step = tf.Variable(0)
        
        self.norm_gradients_node = tf.Variable(tf.constant(0.0, shape=[len(self.net.gradients_node)]))
        
        if self.net.summaries:
            tf.summary.histogram('norm_grads', self.norm_gradients_node)

        tf.summary.scalar('loss', self.net.cost)
        tf.summary.scalar('cross_entropy', self.net.cross_entropy)
        tf.summary.scalar('accuracy', self.net.accuracy)

        self.optimizer = self._get_optimizer(training_iters, global_step)
        tf.summary.scalar('learning_rate', self.learning_rate_node)

        self.summary_op = tf.summary.merge_all()        
        init = tf.global_variables_initializer()
        
        prediction_path = os.path.abspath(self.prediction_path)
        output_path = os.path.abspath(output_path)
        
        if not restore:
            logging.info("Removing '{:}'".format(prediction_path))
            shutil.rmtree(prediction_path, ignore_errors=True)
            logging.info("Removing '{:}'".format(output_path))
            shutil.rmtree(output_path, ignore_errors=True)
        
        if not os.path.exists(prediction_path):
            logging.info("Allocating '{:}'".format(prediction_path))
            os.makedirs(prediction_path)
        
        if not os.path.exists(output_path):
            logging.info("Allocating '{:}'".format(output_path))
            os.makedirs(output_path)
        
        return init

    def train(self, data_provider, output_path, training_iters=10, epochs=100, dropout=0.75, display_step=1, restore=False, write_graph=False):
        """
        Lauches the training process
        
        :param data_provider: callable returning training and verification data
        :param output_path: path where to store checkpoints
        :param training_iters: number of training mini batch iteration
        :param epochs: number of epochs
        :param dropout: dropout probability
        :param display_step: number of steps till outputting stats
        :param restore: Flag if previous model should be restored 
        :param write_graph: Flag if the computation graph should be written as protobuf file to the output path
        """
        save_path = os.path.join(output_path, "model_50_80_3.cpkt")  ## ////..change the save path before running if you want to be in same path..////
        if epochs == 0:
            return save_path
        
        init = self._initialize(training_iters, output_path, restore)
        
        with tf.Session(config=config) as sess:
            if write_graph:
                tf.train.write_graph(sess.graph_def, output_path, "graph.pb", False)
            
            sess.run(init)
            
            if restore:
                ckpt = tf.train.get_checkpoint_state(output_path)
                if ckpt and ckpt.model_checkpoint_path:
                    self.net.restore(sess, ckpt.model_checkpoint_path)
            
            test_x, test_y = data_provider(self.verification_batch_size)
            pred_shape = self.store_prediction(sess, test_x, test_y, "_init")
            nuksaan =[]
            
            summary_writer = tf.summary.FileWriter(output_path, graph=sess.graph)
            logging.info("Start optimization")
            
            avg_gradients = None
            for epoch in range(epochs):
                total_loss = 0
                for step in range((epoch*training_iters), ((epoch+1)*training_iters)):
                    batch_x, batch_y = data_provider(self.batch_size)
                     
                    # Run optimization op (backprop)
                    _, loss, lr, gradients = sess.run((self.optimizer, self.net.cost, self.learning_rate_node, self.net.gradients_node), 
                                                      feed_dict={self.net.x: batch_x,
                                                                 self.net.y: crop_to_shape(batch_y, pred_shape),
                                                                 self.net.keep_prob: dropout})

                    if avg_gradients is None:
                        avg_gradients = [np.zeros_like(gradient) for gradient in gradients]
                    for i in range(len(gradients)):
                        avg_gradients[i] = (avg_gradients[i] * (1.0 - (1.0 / (step+1)))) + (gradients[i] / (step+1))
                        
                    norm_gradients = [np.linalg.norm(gradient) for gradient in avg_gradients]
                    self.norm_gradients_node.assign(norm_gradients).eval()
                    
                    if step % display_step == 0:
                        self.output_minibatch_stats(sess, summary_writer, step, batch_x, crop_to_shape(batch_y, pred_shape))
                        
                    total_loss += loss
                    

                self.output_epoch_stats(epoch, total_loss, training_iters, lr)
                self.store_prediction(sess, test_x, test_y, "epoch_%s"%epoch)
                nuksaan.append(total_loss / training_iters)    
                save_path = self.net.save(sess, save_path)
            logging.info("Optimization Finished!")
            
            return save_path, nuksaan
        
    def store_prediction(self, sess, batch_x, batch_y, name):
        prediction = sess.run(self.net.predicter, feed_dict={self.net.x: batch_x,self.net.y: batch_y,self.net.keep_prob:1.})
        pred_shape = prediction.shape
        
        loss = sess.run(self.net.cost, feed_dict={self.net.x: batch_x, 
                                                       self.net.y: crop_to_shape(batch_y, pred_shape), 
                                                       self.net.keep_prob: 1.})
        
        logging.info("Verification error= {:.1f}%, loss= {:.4f}".format(error_rate(prediction,
                                                                          crop_to_shape(batch_y,
                                                                                             prediction.shape)),
                                                                          loss))
              
        img = combine_img_prediction(batch_x, batch_y, prediction)
        save_image(img, "%s/%s.jpg"%(self.prediction_path, name))
        
        return pred_shape
    
    def output_epoch_stats(self, epoch, total_loss, training_iters, lr):
        logging.info("Epoch {:}, Average loss: {:.4f}, learning rate: {:.4f}".format(epoch, (total_loss / training_iters), lr))
    
    def output_minibatch_stats(self, sess, summary_writer, step, batch_x, batch_y):
        # Calculate batch loss and accuracy
        summary_str, loss, acc, predictions = sess.run([self.summary_op, 
                                                            self.net.cost, 
                                                            self.net.accuracy, 
                                                            self.net.predicter], 
                                                           feed_dict={self.net.x: batch_x,
                                                                      self.net.y: batch_y,
                                                                      self.net.keep_prob: 1.})
        summary_writer.add_summary(summary_str, step)
        summary_writer.flush()
        logging.info("Iter {:}, Minibatch Loss= {:.4f}, Training Accuracy= {:.4f}, Minibatch error= {:.1f}%".format(step,
                                                                                                            loss,
                                                                                                            acc,
                                                                                                            error_rate(predictions, batch_y)))

# %%
net = Unet(channels=mydata_test.channels, n_class=mydata_test.n_class, layers=7, features_root=16)
# Out:
# 2017-07-26 11:32:36,153 Layers 7, features 16, filter size 3x3,pool size: 2x2

# %%
trainer = Trainer(net, optimizer="momentum", opt_kwargs=dict(momentum=0.2))

# %%
output_path = "./unet_trained_50_80_3"                         ## output path to store the model and predictions of epocs

# %%
path, nuksaan3 = trainer.train(mydata, output_path=output_path, training_iters=50, epochs=150, display_step=10)
# Out:
# 2017-07-14 17:08:43,536 Removing '/home/ctuser/Desktop/Image_Seg/prediction_model_50_500_3'
# 2017-07-14 17:08:43,551 Removing '/home/ctuser/Desktop/Image_Seg/unet_trained_50_500_3'
# 2017-07-14 17:08:43,552 Allocating '/home/ctuser/Desktop/Image_Seg/prediction_model_50_500_3'
# 2017-07-14 17:08:43,553 Allocating '/home/ctuser/Desktop/Image_Seg/unet_trained_50_500_3'
# 2017-07-14 17:08:55,767 Verification error= 50.7%, loss= 0.6933
# 2017-07-14 17:08:58,210 Start optimization
# 2017-07-14 17:09:03,385 Iter 0, Minibatch Loss= 0.5564, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2017-07-14 17:09:21,521 Iter 10, Minibatch Loss= 0.1207, Training Accuracy= 0.9760, Minibatch error= 2.4%
# 2017-07-14 17:09:33,226 Iter 20, Minibatch Loss= 0.0310, Training Accuracy= 0.9958, Minibatch error= 0.4%
# 2017-07-14 17:09:45,005 Iter 30, Minibatch Loss= 0.0664, Training Accuracy= 0.9873, Minibatch error= 1.3%
# 2017-07-14 17:10:16,554 Iter 40, Minibatch Loss= 0.0358, Training Accuracy= 0.9941, Minibatch error= 0.6%
# 2017-07-14 17:10:29,645 Epoch 0, Average loss: 0.1257, learning rate: 0.2000
# 2017-07-14 17:10:30,635 Verification error= 1.7%, loss= 0.0782
# 2017-07-14 17:10:50,332 Iter 50, Minibatch Loss= 0.1067, Training Accuracy= 0.9760, Minibatch error= 2.4%
# 2017-07-14 17:11:06,164 Iter 60, Minibatch Loss= 0.1032, Training Accuracy= 0.9767, Minibatch error= 2.3%
# 2017-07-14 17:11:17,990 Iter 70, Minibatch Loss= 0.0234, Training Accuracy= 0.9963, Minibatch error= 0.4%
# 2017-07-14 17:11:30,278 Iter 80, Minibatch Loss= 0.0466, Training Accuracy= 0.9915, Minibatch error= 0.9%
# 2017-07-14 17:11:42,524 Iter 90, Minibatch Loss= 0.1219, Training Accuracy= 0.9701, Minibatch error= 3.0%
# 2017-07-14 17:11:52,636 Epoch 1, Average loss: 0.0734, learning rate: 0.1900
# 2017-07-14 17:11:53,596 Verification error= 1.7%, loss= 0.0720
# 2017-07-14 17:12:07,927 Iter 100, Minibatch Loss= 0.0161, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2017-07-14 17:12:26,090 Iter 110, Minibatch Loss= 0.0975, Training Accuracy= 0.9755, Minibatch error= 2.4%
# 2017-07-14 17:12:39,669 Iter 120, Minibatch Loss= 0.0304, Training Accuracy= 0.9928, Minibatch error= 0.7%
# 2017-07-14 17:12:52,285 Iter 130, Minibatch Loss= 0.0567, Training Accuracy= 0.9880, Minibatch error= 1.2%
# 2017-07-14 17:13:05,723 Iter 140, Minibatch Loss= 0.0906, Training Accuracy= 0.9761, Minibatch error= 2.4%
# 2017-07-14 17:13:17,669 Epoch 2, Average loss: 0.0678, learning rate: 0.1805
# 2017-07-14 17:13:18,639 Verification error= 1.7%, loss= 0.0700
# 2017-07-14 17:13:30,762 Iter 150, Minibatch Loss= 0.0729, Training Accuracy= 0.9757, Minibatch error= 2.4%
# 2017-07-14 17:13:43,331 Iter 160, Minibatch Loss= 0.0664, Training Accuracy= 0.9852, Minibatch error= 1.5%
# 2017-07-14 17:14:02,702 Iter 170, Minibatch Loss= 0.0813, Training Accuracy= 0.9827, Minibatch error= 1.7%
# 2017-07-14 17:14:15,168 Iter 180, Minibatch Loss= 0.0639, Training Accuracy= 0.9851, Minibatch error= 1.5%
# 2017-07-14 17:14:29,265 Iter 190, Minibatch Loss= 0.0511, Training Accuracy= 0.9894, Minibatch error= 1.1%
# 2017-07-14 17:14:41,075 Epoch 3, Average loss: 0.0679, learning rate: 0.1715
# 2017-07-14 17:14:42,040 Verification error= 1.7%, loss= 0.0690
# 2017-07-14 17:14:51,731 Iter 200, Minibatch Loss= 0.0431, Training Accuracy= 0.9916, Minibatch error= 0.8%
# 2017-07-14 17:15:03,689 Iter 210, Minibatch Loss= 0.0673, Training Accuracy= 0.9848, Minibatch error= 1.5%
# 2017-07-14 17:15:16,726 Iter 220, Minibatch Loss= 0.0353, Training Accuracy= 0.9958, Minibatch error= 0.4%
# 2017-07-14 17:15:33,547 Iter 230, Minibatch Loss= 0.0901, Training Accuracy= 0.9771, Minibatch error= 2.3%
# 2017-07-14 17:15:48,105 Iter 240, Minibatch Loss= 0.0322, Training Accuracy= 0.9957, Minibatch error= 0.4%
# 2017-07-14 17:15:59,516 Epoch 4, Average loss: 0.0662, learning rate: 0.1629
# 2017-07-14 17:16:00,488 Verification error= 1.7%, loss= 0.0686
# 2017-07-14 17:16:11,640 Iter 250, Minibatch Loss= 0.0323, Training Accuracy= 0.9956, Minibatch error= 0.4%
# 2017-07-14 17:16:24,792 Iter 260, Minibatch Loss= 0.0441, Training Accuracy= 0.9929, Minibatch error= 0.7%
# 2017-07-14 17:16:39,104 Iter 270, Minibatch Loss= 0.0638, Training Accuracy= 0.9864, Minibatch error= 1.4%
# 2017-07-14 17:16:51,565 Iter 280, Minibatch Loss= 0.0646, Training Accuracy= 0.9855, Minibatch error= 1.5%
# 2017-07-14 17:17:03,596 Iter 290, Minibatch Loss= 0.0373, Training Accuracy= 0.9900, Minibatch error= 1.0%
# 2017-07-14 17:17:14,694 Epoch 5, Average loss: 0.0701, learning rate: 0.1548
# 2017-07-14 17:17:15,652 Verification error= 1.7%, loss= 0.0672
# 2017-07-14 17:17:30,666 Iter 300, Minibatch Loss= 0.0442, Training Accuracy= 0.9938, Minibatch error= 0.6%
# 2017-07-14 17:17:44,065 Iter 310, Minibatch Loss= 0.0319, Training Accuracy= 0.9971, Minibatch error= 0.3%
# 2017-07-14 17:17:57,495 Iter 320, Minibatch Loss= 0.0641, Training Accuracy= 0.9863, Minibatch error= 1.4%
# 2017-07-14 17:18:10,139 Iter 330, Minibatch Loss= 0.0422, Training Accuracy= 0.9886, Minibatch error= 1.1%
# 2017-07-14 17:18:23,899 Iter 340, Minibatch Loss= 0.0900, Training Accuracy= 0.9755, Minibatch error= 2.5%
# 2017-07-14 17:18:35,228 Epoch 6, Average loss: 0.0655, learning rate: 0.1470
# 2017-07-14 17:18:36,208 Verification error= 1.7%, loss= 0.0657
# 2017-07-14 17:18:48,385 Iter 350, Minibatch Loss= 0.0820, Training Accuracy= 0.9783, Minibatch error= 2.2%
# 2017-07-14 17:19:00,937 Iter 360, Minibatch Loss= 0.0612, Training Accuracy= 0.9854, Minibatch error= 1.5%
# 2017-07-14 17:19:14,548 Iter 370, Minibatch Loss= 0.0483, Training Accuracy= 0.9874, Minibatch error= 1.3%
# 2017-07-14 17:19:45,286 Iter 380, Minibatch Loss= 0.0633, Training Accuracy= 0.9849, Minibatch error= 1.5%
# 2017-07-14 17:20:04,333 Iter 390, Minibatch Loss= 0.0602, Training Accuracy= 0.9857, Minibatch error= 1.4%
# 2017-07-14 17:20:17,387 Epoch 7, Average loss: 0.0656, learning rate: 0.1397
# 2017-07-14 17:20:18,355 Verification error= 1.7%, loss= 0.0639
# 2017-07-14 17:20:30,707 Iter 400, Minibatch Loss= 0.0607, Training Accuracy= 0.9855, Minibatch error= 1.4%
# 2017-07-14 17:20:49,916 Iter 410, Minibatch Loss= 0.0830, Training Accuracy= 0.9766, Minibatch error= 2.3%
# 2017-07-14 17:21:02,858 Iter 420, Minibatch Loss= 0.0772, Training Accuracy= 0.9776, Minibatch error= 2.2%
# 2017-07-14 17:21:16,451 Iter 430, Minibatch Loss= 0.0755, Training Accuracy= 0.9775, Minibatch error= 2.2%
# 2017-07-14 17:21:30,675 Iter 440, Minibatch Loss= 0.0439, Training Accuracy= 0.9882, Minibatch error= 1.2%
# 2017-07-14 17:21:42,898 Epoch 8, Average loss: 0.0632, learning rate: 0.1327
# 2017-07-14 17:21:43,874 Verification error= 1.7%, loss= 0.0579
# 2017-07-14 17:21:57,527 Iter 450, Minibatch Loss= 0.0342, Training Accuracy= 0.9879, Minibatch error= 1.2%
# 2017-07-14 17:22:13,796 Iter 460, Minibatch Loss= 0.0269, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2017-07-14 17:22:27,153 Iter 470, Minibatch Loss= 0.0497, Training Accuracy= 0.9849, Minibatch error= 1.5%
# 2017-07-14 17:22:41,178 Iter 480, Minibatch Loss= 0.0379, Training Accuracy= 0.9867, Minibatch error= 1.3%
# 2017-07-14 17:22:54,573 Iter 490, Minibatch Loss= 0.0479, Training Accuracy= 0.9765, Minibatch error= 2.3%
# 2017-07-14 17:23:06,368 Epoch 9, Average loss: 0.0581, learning rate: 0.1260
# 2017-07-14 17:23:07,339 Verification error= 1.7%, loss= 0.0401
# 2017-07-14 17:23:18,684 Iter 500, Minibatch Loss= 0.0358, Training Accuracy= 0.9854, Minibatch error= 1.5%
# 2017-07-14 17:23:32,345 Iter 510, Minibatch Loss= 0.0316, Training Accuracy= 0.9866, Minibatch error= 1.3%
# 2017-07-14 17:23:53,017 Iter 520, Minibatch Loss= 0.0445, Training Accuracy= 0.9762, Minibatch error= 2.4%
# 2017-07-14 17:24:06,596 Iter 530, Minibatch Loss= 0.0079, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2017-07-14 17:24:21,306 Iter 540, Minibatch Loss= 0.0135, Training Accuracy= 0.9969, Minibatch error= 0.3%
# 2017-07-14 17:24:33,680 Epoch 10, Average loss: 0.0385, learning rate: 0.1197
# 2017-07-14 17:24:34,658 Verification error= 1.7%, loss= 0.0311
# 2017-07-14 17:24:46,867 Iter 550, Minibatch Loss= 0.0421, Training Accuracy= 0.9774, Minibatch error= 2.3%
# 2017-07-14 17:25:03,422 Iter 560, Minibatch Loss= 0.0509, Training Accuracy= 0.9728, Minibatch error= 2.7%
# 2017-07-14 17:25:19,794 Iter 570, Minibatch Loss= 0.0258, Training Accuracy= 0.9851, Minibatch error= 1.5%
# 2017-07-14 17:25:33,689 Iter 580, Minibatch Loss= 0.0224, Training Accuracy= 0.9868, Minibatch error= 1.3%
# 2017-07-14 17:25:48,566 Iter 590, Minibatch Loss= 0.0437, Training Accuracy= 0.9737, Minibatch error= 2.6%
# 2017-07-14 17:26:02,728 Epoch 11, Average loss: 0.0330, learning rate: 0.1138
# 2017-07-14 17:26:03,690 Verification error= 1.7%, loss= 0.0285
# 2017-07-14 17:26:31,543 Iter 600, Minibatch Loss= 0.0357, Training Accuracy= 0.9773, Minibatch error= 2.3%
# 2017-07-14 17:26:46,673 Iter 610, Minibatch Loss= 0.0145, Training Accuracy= 0.9917, Minibatch error= 0.8%
# 2017-07-14 17:27:00,557 Iter 620, Minibatch Loss= 0.0204, Training Accuracy= 0.9886, Minibatch error= 1.1%
# 2017-07-14 17:27:15,884 Iter 630, Minibatch Loss= 0.0231, Training Accuracy= 0.9864, Minibatch error= 1.4%
# 2017-07-14 17:27:29,904 Iter 640, Minibatch Loss= 0.0338, Training Accuracy= 0.9770, Minibatch error= 2.3%
# 2017-07-14 17:27:43,053 Epoch 12, Average loss: 0.0302, learning rate: 0.1081
# 2017-07-14 17:27:44,014 Verification error= 1.7%, loss= 0.0263
# 2017-07-14 17:28:03,296 Iter 650, Minibatch Loss= 0.0192, Training Accuracy= 0.9888, Minibatch error= 1.1%
# 2017-07-14 17:28:18,988 Iter 660, Minibatch Loss= 0.0075, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-14 17:28:34,067 Iter 670, Minibatch Loss= 0.0139, Training Accuracy= 0.9932, Minibatch error= 0.7%
# 2017-07-14 17:28:49,353 Iter 680, Minibatch Loss= 0.0331, Training Accuracy= 0.9774, Minibatch error= 2.3%
# 2017-07-14 17:29:04,900 Iter 690, Minibatch Loss= 0.0201, Training Accuracy= 0.9853, Minibatch error= 1.5%
# 2017-07-14 17:29:19,055 Epoch 13, Average loss: 0.0277, learning rate: 0.1027
# 2017-07-14 17:29:20,029 Verification error= 1.7%, loss= 0.0246
# 2017-07-14 17:29:41,668 Iter 700, Minibatch Loss= 0.0082, Training Accuracy= 0.9967, Minibatch error= 0.3%
# 2017-07-14 17:30:00,304 Iter 710, Minibatch Loss= 0.0301, Training Accuracy= 0.9772, Minibatch error= 2.3%
# 2017-07-14 17:30:16,450 Iter 720, Minibatch Loss= 0.0159, Training Accuracy= 0.9938, Minibatch error= 0.6%
# 2017-07-14 17:30:31,636 Iter 730, Minibatch Loss= 0.0069, Training Accuracy= 0.9957, Minibatch error= 0.4%
# 2017-07-14 17:30:48,749 Iter 740, Minibatch Loss= 0.0148, Training Accuracy= 0.9890, Minibatch error= 1.1%
# 2017-07-14 17:31:02,708 Epoch 14, Average loss: 0.0249, learning rate: 0.0975
# 2017-07-14 17:31:03,665 Verification error= 1.7%, loss= 0.0230
# 2017-07-14 17:31:30,924 Iter 750, Minibatch Loss= 0.0176, Training Accuracy= 0.9881, Minibatch error= 1.2%
# 2017-07-14 17:31:46,283 Iter 760, Minibatch Loss= 0.0199, Training Accuracy= 0.9853, Minibatch error= 1.5%
# 2017-07-14 17:32:01,713 Iter 770, Minibatch Loss= 0.0355, Training Accuracy= 0.9734, Minibatch error= 2.7%
# 2017-07-14 17:32:18,062 Iter 780, Minibatch Loss= 0.0189, Training Accuracy= 0.9852, Minibatch error= 1.5%
# 2017-07-14 17:32:36,721 Iter 790, Minibatch Loss= 0.0260, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2017-07-14 17:32:50,805 Epoch 15, Average loss: 0.0242, learning rate: 0.0927
# 2017-07-14 17:32:51,770 Verification error= 1.7%, loss= 0.0218
# 2017-07-14 17:33:11,038 Iter 800, Minibatch Loss= 0.0191, Training Accuracy= 0.9856, Minibatch error= 1.4%
# 2017-07-14 17:33:26,903 Iter 810, Minibatch Loss= 0.0292, Training Accuracy= 0.9759, Minibatch error= 2.4%
# 2017-07-14 17:33:42,825 Iter 820, Minibatch Loss= 0.0287, Training Accuracy= 0.9764, Minibatch error= 2.4%
# 2017-07-14 17:34:01,425 Iter 830, Minibatch Loss= 0.0237, Training Accuracy= 0.9813, Minibatch error= 1.9%
# 2017-07-14 17:34:17,031 Iter 840, Minibatch Loss= 0.0105, Training Accuracy= 0.9916, Minibatch error= 0.8%
# 2017-07-14 17:34:31,743 Epoch 16, Average loss: 0.0209, learning rate: 0.0880
# 2017-07-14 17:34:32,702 Verification error= 1.7%, loss= 0.0200
# 2017-07-14 17:34:55,948 Iter 850, Minibatch Loss= 0.0263, Training Accuracy= 0.9794, Minibatch error= 2.1%
# 2017-07-14 17:35:15,845 Iter 860, Minibatch Loss= 0.0160, Training Accuracy= 0.9851, Minibatch error= 1.5%
# 2017-07-14 17:35:33,493 Iter 870, Minibatch Loss= 0.0249, Training Accuracy= 0.9765, Minibatch error= 2.4%
# 2017-07-14 17:35:49,646 Iter 880, Minibatch Loss= 0.0058, Training Accuracy= 0.9960, Minibatch error= 0.4%
# 2017-07-14 17:36:05,930 Iter 890, Minibatch Loss= 0.0155, Training Accuracy= 0.9852, Minibatch error= 1.5%
# 2017-07-14 17:36:20,218 Epoch 17, Average loss: 0.0186, learning rate: 0.0836
# 2017-07-14 17:36:21,173 Verification error= 1.7%, loss= 0.0190
# 2017-07-14 17:36:51,902 Iter 900, Minibatch Loss= 0.0527, Training Accuracy= 0.9676, Minibatch error= 3.2%
# 2017-07-14 17:37:09,950 Iter 910, Minibatch Loss= 0.0165, Training Accuracy= 0.9845, Minibatch error= 1.5%
# 2017-07-14 17:37:29,048 Iter 920, Minibatch Loss= 0.0178, Training Accuracy= 0.9854, Minibatch error= 1.5%
# 2017-07-14 17:37:46,007 Iter 930, Minibatch Loss= 0.0141, Training Accuracy= 0.9883, Minibatch error= 1.2%
# 2017-07-14 17:38:02,518 Iter 940, Minibatch Loss= 0.0236, Training Accuracy= 0.9769, Minibatch error= 2.3%
# 2017-07-14 17:38:16,736 Epoch 18, Average loss: 0.0236, learning rate: 0.0794
# 2017-07-14 17:38:17,695 Verification error= 1.7%, loss= 0.0186
# 2017-07-14 17:38:36,141 Iter 950, Minibatch Loss= 0.0251, Training Accuracy= 0.9766, Minibatch error= 2.3%
# 2017-07-14 17:38:53,070 Iter 960, Minibatch Loss= 0.0227, Training Accuracy= 0.9767, Minibatch error= 2.3%
# 2017-07-14 17:39:12,940 Iter 970, Minibatch Loss= 0.0061, Training Accuracy= 0.9945, Minibatch error= 0.6%
# 2017-07-14 17:39:29,406 Iter 980, Minibatch Loss= 0.0061, Training Accuracy= 0.9945, Minibatch error= 0.5%
# 2017-07-14 17:39:45,744 Iter 990, Minibatch Loss= 0.0143, Training Accuracy= 0.9857, Minibatch error= 1.4%
# 2017-07-14 17:40:00,600 Epoch 19, Average loss: 0.0168, learning rate: 0.0755
# 2017-07-14 17:40:01,556 Verification error= 1.7%, loss= 0.0171
# 2017-07-14 17:40:27,227 Iter 1000, Minibatch Loss= 0.0106, Training Accuracy= 0.9889, Minibatch error= 1.1%
# 2017-07-14 17:40:44,761 Iter 1010, Minibatch Loss= 0.0121, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2017-07-14 17:41:02,382 Iter 1020, Minibatch Loss= 0.0061, Training Accuracy= 0.9967, Minibatch error= 0.3%
# 2017-07-14 17:41:20,172 Iter 1030, Minibatch Loss= 0.0229, Training Accuracy= 0.9810, Minibatch error= 1.9%
# 2017-07-14 17:41:37,003 Iter 1040, Minibatch Loss= 0.0235, Training Accuracy= 0.9775, Minibatch error= 2.3%
# 2017-07-14 17:41:52,097 Epoch 20, Average loss: 0.0236, learning rate: 0.0717
# 2017-07-14 17:41:53,052 Verification error= 1.7%, loss= 0.0172
# 2017-07-14 17:42:16,753 Iter 1050, Minibatch Loss= 0.0122, Training Accuracy= 0.9886, Minibatch error= 1.1%
# 2017-07-14 17:42:33,896 Iter 1060, Minibatch Loss= 0.0080, Training Accuracy= 0.9934, Minibatch error= 0.7%
# 2017-07-14 17:42:50,449 Iter 1070, Minibatch Loss= 0.0132, Training Accuracy= 0.9852, Minibatch error= 1.5%
# 2017-07-14 17:43:07,422 Iter 1080, Minibatch Loss= 0.0082, Training Accuracy= 0.9915, Minibatch error= 0.9%
# 2017-07-14 17:43:24,692 Iter 1090, Minibatch Loss= 0.0161, Training Accuracy= 0.9843, Minibatch error= 1.6%
# 2017-07-14 17:43:40,367 Epoch 21, Average loss: 0.0157, learning rate: 0.0681
# 2017-07-14 17:43:41,320 Verification error= 1.7%, loss= 0.0157
# 2017-07-14 17:44:16,655 Iter 1100, Minibatch Loss= 0.0218, Training Accuracy= 0.9753, Minibatch error= 2.5%
# 2017-07-14 17:44:34,247 Iter 1110, Minibatch Loss= 0.0187, Training Accuracy= 0.9787, Minibatch error= 2.1%
# 2017-07-14 17:44:51,644 Iter 1120, Minibatch Loss= 0.0241, Training Accuracy= 0.9748, Minibatch error= 2.5%
# 2017-07-14 17:45:10,156 Iter 1130, Minibatch Loss= 0.0193, Training Accuracy= 0.9774, Minibatch error= 2.3%
# 2017-07-14 17:45:27,959 Iter 1140, Minibatch Loss= 0.0089, Training Accuracy= 0.9939, Minibatch error= 0.6%
# 2017-07-14 17:45:43,732 Epoch 22, Average loss: 0.0168, learning rate: 0.0647
# 2017-07-14 17:45:44,684 Verification error= 1.7%, loss= 0.0151
# 2017-07-14 17:46:20,976 Iter 1150, Minibatch Loss= 0.0189, Training Accuracy= 0.9775, Minibatch error= 2.3%
# 2017-07-14 17:46:38,808 Iter 1160, Minibatch Loss= 0.0185, Training Accuracy= 0.9775, Minibatch error= 2.3%
# 2017-07-14 17:46:56,005 Iter 1170, Minibatch Loss= 0.0136, Training Accuracy= 0.9851, Minibatch error= 1.5%
# 2017-07-14 17:47:13,782 Iter 1180, Minibatch Loss= 0.0123, Training Accuracy= 0.9865, Minibatch error= 1.4%
# 2017-07-14 17:47:31,101 Iter 1190, Minibatch Loss= 0.0211, Training Accuracy= 0.9760, Minibatch error= 2.4%
# 2017-07-14 17:47:47,031 Epoch 23, Average loss: 0.0147, learning rate: 0.0615
# 2017-07-14 17:47:47,989 Verification error= 1.7%, loss= 0.0146
# 2017-07-14 17:48:37,229 Iter 1200, Minibatch Loss= 0.0047, Training Accuracy= 0.9955, Minibatch error= 0.4%
# 2017-07-14 17:48:57,780 Iter 1210, Minibatch Loss= 0.0096, Training Accuracy= 0.9881, Minibatch error= 1.2%
# 2017-07-14 17:49:15,933 Iter 1220, Minibatch Loss= 0.0166, Training Accuracy= 0.9824, Minibatch error= 1.8%
# 2017-07-14 17:49:34,117 Iter 1230, Minibatch Loss= 0.0061, Training Accuracy= 0.9982, Minibatch error= 0.2%
# 2017-07-14 17:49:52,091 Iter 1240, Minibatch Loss= 0.0124, Training Accuracy= 0.9851, Minibatch error= 1.5%
# 2017-07-14 17:50:07,876 Epoch 24, Average loss: 0.0143, learning rate: 0.0584
# 2017-07-14 17:50:08,827 Verification error= 1.7%, loss= 0.0142
# 2017-07-14 17:50:48,190 Iter 1250, Minibatch Loss= 0.0116, Training Accuracy= 0.9856, Minibatch error= 1.4%
# 2017-07-14 17:51:06,740 Iter 1260, Minibatch Loss= 0.0180, Training Accuracy= 0.9830, Minibatch error= 1.7%
# 2017-07-14 17:51:25,658 Iter 1270, Minibatch Loss= 0.0194, Training Accuracy= 0.9756, Minibatch error= 2.4%
# 2017-07-14 17:51:44,241 Iter 1280, Minibatch Loss= 0.0091, Training Accuracy= 0.9884, Minibatch error= 1.2%
# 2017-07-14 17:52:02,070 Iter 1290, Minibatch Loss= 0.0163, Training Accuracy= 0.9827, Minibatch error= 1.7%
# 2017-07-14 17:52:18,681 Epoch 25, Average loss: 0.0158, learning rate: 0.0555
# 2017-07-14 17:52:19,638 Verification error= 1.7%, loss= 0.0141
# 2017-07-14 17:53:07,057 Iter 1300, Minibatch Loss= 0.0168, Training Accuracy= 0.9789, Minibatch error= 2.1%
# 2017-07-14 17:53:25,823 Iter 1310, Minibatch Loss= 0.0081, Training Accuracy= 0.9964, Minibatch error= 0.4%
# 2017-07-14 17:53:44,068 Iter 1320, Minibatch Loss= 0.0175, Training Accuracy= 0.9771, Minibatch error= 2.3%
# 2017-07-14 17:54:02,125 Iter 1330, Minibatch Loss= 0.0136, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2017-07-14 17:54:20,443 Iter 1340, Minibatch Loss= 0.0197, Training Accuracy= 0.9753, Minibatch error= 2.5%
# 2017-07-14 17:54:36,545 Epoch 26, Average loss: 0.0134, learning rate: 0.0527
# 2017-07-14 17:54:37,516 Verification error= 1.7%, loss= 0.0140
# 2017-07-14 17:55:10,328 Iter 1350, Minibatch Loss= 0.0104, Training Accuracy= 0.9879, Minibatch error= 1.2%
# 2017-07-14 17:55:46,936 Iter 1360, Minibatch Loss= 0.0064, Training Accuracy= 0.9939, Minibatch error= 0.6%
# 2017-07-14 17:56:05,809 Iter 1370, Minibatch Loss= 0.0049, Training Accuracy= 0.9958, Minibatch error= 0.4%
# 2017-07-14 17:56:24,049 Iter 1380, Minibatch Loss= 0.0131, Training Accuracy= 0.9847, Minibatch error= 1.5%
# 2017-07-14 17:56:42,523 Iter 1390, Minibatch Loss= 0.0116, Training Accuracy= 0.9858, Minibatch error= 1.4%
# 2017-07-14 17:56:59,916 Epoch 27, Average loss: 0.0148, learning rate: 0.0501
# 2017-07-14 17:57:00,866 Verification error= 1.7%, loss= 0.0139
# 2017-07-14 17:57:55,046 Iter 1400, Minibatch Loss= 0.0111, Training Accuracy= 0.9854, Minibatch error= 1.5%
# 2017-07-14 17:58:15,104 Iter 1410, Minibatch Loss= 0.0097, Training Accuracy= 0.9887, Minibatch error= 1.1%
# 2017-07-14 17:58:34,598 Iter 1420, Minibatch Loss= 0.0191, Training Accuracy= 0.9767, Minibatch error= 2.3%
# 2017-07-14 17:58:53,193 Iter 1430, Minibatch Loss= 0.0207, Training Accuracy= 0.9737, Minibatch error= 2.6%
# 2017-07-14 17:59:12,400 Iter 1440, Minibatch Loss= 0.0091, Training Accuracy= 0.9883, Minibatch error= 1.2%
# 2017-07-14 17:59:29,353 Epoch 28, Average loss: 0.0134, learning rate: 0.0476
# 2017-07-14 17:59:30,308 Verification error= 1.7%, loss= 0.0139
# 2017-07-14 18:00:10,861 Iter 1450, Minibatch Loss= 0.0202, Training Accuracy= 0.9756, Minibatch error= 2.4%
# 2017-07-14 18:00:30,209 Iter 1460, Minibatch Loss= 0.0034, Training Accuracy= 0.9971, Minibatch error= 0.3%
# 2017-07-14 18:00:49,722 Iter 1470, Minibatch Loss= 0.0133, Training Accuracy= 0.9856, Minibatch error= 1.4%
# 2017-07-14 18:01:09,472 Iter 1480, Minibatch Loss= 0.0172, Training Accuracy= 0.9787, Minibatch error= 2.1%
# 2017-07-14 18:01:29,176 Iter 1490, Minibatch Loss= 0.0119, Training Accuracy= 0.9850, Minibatch error= 1.5%
# 2017-07-14 18:01:46,226 Epoch 29, Average loss: 0.0134, learning rate: 0.0452
# 2017-07-14 18:01:47,184 Verification error= 1.7%, loss= 0.0139
# 2017-07-14 18:02:14,236 Iter 1500, Minibatch Loss= 0.0193, Training Accuracy= 0.9765, Minibatch error= 2.4%
# 2017-07-14 18:02:33,201 Iter 1510, Minibatch Loss= 0.0137, Training Accuracy= 0.9854, Minibatch error= 1.5%
# 2017-07-14 18:02:52,356 Iter 1520, Minibatch Loss= 0.0109, Training Accuracy= 0.9858, Minibatch error= 1.4%
# 2017-07-14 18:03:11,944 Iter 1530, Minibatch Loss= 0.0111, Training Accuracy= 0.9854, Minibatch error= 1.5%
# 2017-07-14 18:03:31,163 Iter 1540, Minibatch Loss= 0.0153, Training Accuracy= 0.9850, Minibatch error= 1.5%
# 2017-07-14 18:03:48,687 Epoch 30, Average loss: 0.0140, learning rate: 0.0429
# 2017-07-14 18:03:49,647 Verification error= 1.7%, loss= 0.0139
# 2017-07-14 18:04:48,131 Iter 1550, Minibatch Loss= 0.0196, Training Accuracy= 0.9760, Minibatch error= 2.4%
# 2017-07-14 18:05:09,066 Iter 1560, Minibatch Loss= 0.0123, Training Accuracy= 0.9933, Minibatch error= 0.7%
# 2017-07-14 18:05:28,300 Iter 1570, Minibatch Loss= 0.0101, Training Accuracy= 0.9869, Minibatch error= 1.3%
# 2017-07-14 18:05:47,783 Iter 1580, Minibatch Loss= 0.0176, Training Accuracy= 0.9778, Minibatch error= 2.2%
# 2017-07-14 18:06:06,998 Iter 1590, Minibatch Loss= 0.0174, Training Accuracy= 0.9772, Minibatch error= 2.3%
# 2017-07-14 18:06:24,657 Epoch 31, Average loss: 0.0143, learning rate: 0.0408
# 2017-07-14 18:06:25,605 Verification error= 1.7%, loss= 0.0139
# 2017-07-14 18:07:13,428 Iter 1600, Minibatch Loss= 0.0086, Training Accuracy= 0.9933, Minibatch error= 0.7%
# 2017-07-14 18:07:33,323 Iter 1610, Minibatch Loss= 0.0113, Training Accuracy= 0.9853, Minibatch error= 1.5%
# 2017-07-14 18:07:53,973 Iter 1620, Minibatch Loss= 0.0173, Training Accuracy= 0.9773, Minibatch error= 2.3%
# 2017-07-14 18:08:13,440 Iter 1630, Minibatch Loss= 0.0172, Training Accuracy= 0.9790, Minibatch error= 2.1%
# 2017-07-14 18:08:32,874 Iter 1640, Minibatch Loss= 0.0180, Training Accuracy= 0.9783, Minibatch error= 2.2%
# 2017-07-14 18:08:50,651 Epoch 32, Average loss: 0.0169, learning rate: 0.0387
# 2017-07-14 18:08:51,607 Verification error= 1.7%, loss= 0.0138
# 2017-07-14 18:09:41,723 Iter 1650, Minibatch Loss= 0.0115, Training Accuracy= 0.9850, Minibatch error= 1.5%
# 2017-07-14 18:10:01,469 Iter 1660, Minibatch Loss= 0.0109, Training Accuracy= 0.9877, Minibatch error= 1.2%
# 2017-07-14 18:10:22,339 Iter 1670, Minibatch Loss= 0.0096, Training Accuracy= 0.9881, Minibatch error= 1.2%
# 2017-07-14 18:10:42,832 Iter 1680, Minibatch Loss= 0.0063, Training Accuracy= 0.9937, Minibatch error= 0.6%
# 2017-07-14 18:11:03,161 Iter 1690, Minibatch Loss= 0.0179, Training Accuracy= 0.9774, Minibatch error= 2.3%
# 2017-07-14 18:11:20,907 Epoch 33, Average loss: 0.0142, learning rate: 0.0368
# 2017-07-14 18:11:21,855 Verification error= 1.7%, loss= 0.0137
# 2017-07-14 18:12:16,174 Iter 1700, Minibatch Loss= 0.0180, Training Accuracy= 0.9761, Minibatch error= 2.4%
# 2017-07-14 18:12:36,541 Iter 1710, Minibatch Loss= 0.0085, Training Accuracy= 0.9897, Minibatch error= 1.0%
# 2017-07-14 18:12:56,835 Iter 1720, Minibatch Loss= 0.0135, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2017-07-14 18:13:17,241 Iter 1730, Minibatch Loss= 0.0115, Training Accuracy= 0.9856, Minibatch error= 1.4%
# 2017-07-14 18:13:37,210 Iter 1740, Minibatch Loss= 0.0110, Training Accuracy= 0.9854, Minibatch error= 1.5%
# 2017-07-14 18:13:55,395 Epoch 34, Average loss: 0.0129, learning rate: 0.0350
# 2017-07-14 18:13:56,347 Verification error= 1.7%, loss= 0.0137
# 2017-07-14 18:14:27,863 Iter 1750, Minibatch Loss= 0.0111, Training Accuracy= 0.9878, Minibatch error= 1.2%
# 2017-07-14 18:14:48,720 Iter 1760, Minibatch Loss= 0.0109, Training Accuracy= 0.9855, Minibatch error= 1.4%
# 2017-07-14 18:15:09,165 Iter 1770, Minibatch Loss= 0.0131, Training Accuracy= 0.9839, Minibatch error= 1.6%
# 2017-07-14 18:15:29,729 Iter 1780, Minibatch Loss= 0.0085, Training Accuracy= 0.9896, Minibatch error= 1.0%
# 2017-07-14 18:15:50,387 Iter 1790, Minibatch Loss= 0.0116, Training Accuracy= 0.9850, Minibatch error= 1.5%
# 2017-07-14 18:16:08,935 Epoch 35, Average loss: 0.0134, learning rate: 0.0332
# 2017-07-14 18:16:09,887 Verification error= 1.7%, loss= 0.0138
# 2017-07-14 18:17:17,476 Iter 1800, Minibatch Loss= 0.0118, Training Accuracy= 0.9850, Minibatch error= 1.5%
# 2017-07-14 18:17:39,872 Iter 1810, Minibatch Loss= 0.0181, Training Accuracy= 0.9774, Minibatch error= 2.3%
# 2017-07-14 18:18:01,040 Iter 1820, Minibatch Loss= 0.0137, Training Accuracy= 0.9855, Minibatch error= 1.5%
# 2017-07-14 18:18:21,841 Iter 1830, Minibatch Loss= 0.0114, Training Accuracy= 0.9869, Minibatch error= 1.3%
# 2017-07-14 18:18:42,275 Iter 1840, Minibatch Loss= 0.0044, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2017-07-14 18:19:00,751 Epoch 36, Average loss: 0.0137, learning rate: 0.0316
# 2017-07-14 18:19:01,709 Verification error= 1.7%, loss= 0.0138
# 2017-07-14 18:20:20,955 Iter 1850, Minibatch Loss= 0.0004, Training Accuracy= 0.9995, Minibatch error= 0.0%
# 2017-07-14 18:20:42,599 Iter 1860, Minibatch Loss= 0.0115, Training Accuracy= 0.9863, Minibatch error= 1.4%
# 2017-07-14 18:21:03,613 Iter 1870, Minibatch Loss= 0.0130, Training Accuracy= 0.9851, Minibatch error= 1.5%
# 2017-07-14 18:21:24,665 Iter 1880, Minibatch Loss= 0.0095, Training Accuracy= 0.9881, Minibatch error= 1.2%
# 2017-07-14 18:21:45,881 Iter 1890, Minibatch Loss= 0.0118, Training Accuracy= 0.9850, Minibatch error= 1.5%
# 2017-07-14 18:22:04,748 Epoch 37, Average loss: 0.0140, learning rate: 0.0300
# 2017-07-14 18:22:05,715 Verification error= 1.7%, loss= 0.0137
# 2017-07-14 18:23:04,637 Iter 1900, Minibatch Loss= 0.0068, Training Accuracy= 0.9938, Minibatch error= 0.6%
# 2017-07-14 18:23:27,721 Iter 1910, Minibatch Loss= 0.0114, Training Accuracy= 0.9855, Minibatch error= 1.4%
# 2017-07-14 18:23:49,604 Iter 1920, Minibatch Loss= 0.0121, Training Accuracy= 0.9848, Minibatch error= 1.5%
# 2017-07-14 18:24:10,712 Iter 1930, Minibatch Loss= 0.0113, Training Accuracy= 0.9854, Minibatch error= 1.5%
# 2017-07-14 18:24:32,248 Iter 1940, Minibatch Loss= 0.0183, Training Accuracy= 0.9778, Minibatch error= 2.2%
# 2017-07-14 18:24:51,234 Epoch 38, Average loss: 0.0138, learning rate: 0.0285
# 2017-07-14 18:24:52,186 Verification error= 1.7%, loss= 0.0201
# 2017-07-14 18:25:55,482 Iter 1950, Minibatch Loss= 0.0153, Training Accuracy= 0.9869, Minibatch error= 1.3%
# 2017-07-14 18:26:18,669 Iter 1960, Minibatch Loss= 0.0125, Training Accuracy= 0.9849, Minibatch error= 1.5%
# 2017-07-14 18:26:40,132 Iter 1970, Minibatch Loss= 0.0149, Training Accuracy= 0.9854, Minibatch error= 1.5%
# 2017-07-14 18:27:01,950 Iter 1980, Minibatch Loss= 0.0199, Training Accuracy= 0.9767, Minibatch error= 2.3%
# 2017-07-14 18:27:23,691 Iter 1990, Minibatch Loss= 0.0041, Training Accuracy= 0.9956, Minibatch error= 0.4%
# 2017-07-14 18:27:43,497 Epoch 39, Average loss: 0.0144, learning rate: 0.0271
# 2017-07-14 18:27:44,455 Verification error= 1.7%, loss= 0.0136
# 2017-07-14 18:29:01,652 Iter 2000, Minibatch Loss= 0.0186, Training Accuracy= 0.9782, Minibatch error= 2.2%
# 2017-07-14 18:29:25,035 Iter 2010, Minibatch Loss= 0.0155, Training Accuracy= 0.9838, Minibatch error= 1.6%
# 2017-07-14 18:29:46,907 Iter 2020, Minibatch Loss= 0.0174, Training Accuracy= 0.9767, Minibatch error= 2.3%
# 2017-07-14 18:30:08,722 Iter 2030, Minibatch Loss= 0.0199, Training Accuracy= 0.9767, Minibatch error= 2.3%
# 2017-07-14 18:30:30,238 Iter 2040, Minibatch Loss= 0.0107, Training Accuracy= 0.9865, Minibatch error= 1.4%
# 2017-07-14 18:30:49,739 Epoch 40, Average loss: 0.0141, learning rate: 0.0257
# 2017-07-14 18:30:50,705 Verification error= 1.7%, loss= 0.0136
# 2017-07-14 18:32:06,472 Iter 2050, Minibatch Loss= 0.0190, Training Accuracy= 0.9767, Minibatch error= 2.3%
# 2017-07-14 18:32:29,616 Iter 2060, Minibatch Loss= 0.0133, Training Accuracy= 0.9827, Minibatch error= 1.7%
# 2017-07-14 18:32:51,659 Iter 2070, Minibatch Loss= 0.0113, Training Accuracy= 0.9857, Minibatch error= 1.4%
# 2017-07-14 18:33:13,411 Iter 2080, Minibatch Loss= 0.0108, Training Accuracy= 0.9858, Minibatch error= 1.4%
# 2017-07-14 18:33:35,160 Iter 2090, Minibatch Loss= 0.0123, Training Accuracy= 0.9852, Minibatch error= 1.5%
# 2017-07-14 18:33:55,160 Epoch 41, Average loss: 0.0140, learning rate: 0.0244
# 2017-07-14 18:33:56,113 Verification error= 1.7%, loss= 0.0136
# 2017-07-14 18:34:38,845 Iter 2100, Minibatch Loss= 0.0058, Training Accuracy= 0.9938, Minibatch error= 0.6%
# 2017-07-14 18:35:02,356 Iter 2110, Minibatch Loss= 0.0170, Training Accuracy= 0.9775, Minibatch error= 2.2%
# 2017-07-14 18:35:24,788 Iter 2120, Minibatch Loss= 0.0113, Training Accuracy= 0.9852, Minibatch error= 1.5%
# 2017-07-14 18:35:47,187 Iter 2130, Minibatch Loss= 0.0122, Training Accuracy= 0.9928, Minibatch error= 0.7%
# 2017-07-14 18:36:09,877 Iter 2140, Minibatch Loss= 0.0115, Training Accuracy= 0.9849, Minibatch error= 1.5%
# 2017-07-14 18:36:30,190 Epoch 42, Average loss: 0.0129, learning rate: 0.0232
# 2017-07-14 18:36:31,156 Verification error= 1.7%, loss= 0.0137
# 2017-07-14 18:37:31,425 Iter 2150, Minibatch Loss= 0.0112, Training Accuracy= 0.9850, Minibatch error= 1.5%
# 2017-07-14 18:37:54,081 Iter 2160, Minibatch Loss= 0.0034, Training Accuracy= 0.9957, Minibatch error= 0.4%
# 2017-07-14 18:38:18,865 Iter 2170, Minibatch Loss= 0.0060, Training Accuracy= 0.9942, Minibatch error= 0.6%
# 2017-07-14 18:38:41,597 Iter 2180, Minibatch Loss= 0.0102, Training Accuracy= 0.9878, Minibatch error= 1.2%
# 2017-07-14 18:39:04,654 Iter 2190, Minibatch Loss= 0.0133, Training Accuracy= 0.9833, Minibatch error= 1.7%
# 2017-07-14 18:39:25,132 Epoch 43, Average loss: 0.0136, learning rate: 0.0220
# 2017-07-14 18:39:26,099 Verification error= 1.7%, loss= 0.0136
# 2017-07-14 18:40:14,159 Iter 2200, Minibatch Loss= 0.0117, Training Accuracy= 0.9845, Minibatch error= 1.6%
# 2017-07-14 18:40:37,897 Iter 2210, Minibatch Loss= 0.0111, Training Accuracy= 0.9855, Minibatch error= 1.4%
# 2017-07-14 18:41:00,738 Iter 2220, Minibatch Loss= 0.0112, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2017-07-14 18:41:24,467 Iter 2230, Minibatch Loss= 0.0104, Training Accuracy= 0.9865, Minibatch error= 1.3%
# 2017-07-14 18:41:47,491 Iter 2240, Minibatch Loss= 0.0112, Training Accuracy= 0.9854, Minibatch error= 1.5%
# 2017-07-14 18:42:08,465 Epoch 44, Average loss: 0.0134, learning rate: 0.0209
# 2017-07-14 18:42:09,424 Verification error= 1.7%, loss= 0.0137
# 2017-07-14 18:43:16,886 Iter 2250, Minibatch Loss= 0.0168, Training Accuracy= 0.9783, Minibatch error= 2.2%
# 2017-07-14 18:43:42,702 Iter 2260, Minibatch Loss= 0.0286, Training Accuracy= 0.9718, Minibatch error= 2.8%
# 2017-07-14 18:44:06,329 Iter 2270, Minibatch Loss= 0.0185, Training Accuracy= 0.9775, Minibatch error= 2.2%
# 2017-07-14 18:44:29,433 Iter 2280, Minibatch Loss= 0.0106, Training Accuracy= 0.9858, Minibatch error= 1.4%
# 2017-07-14 18:44:51,730 Iter 2290, Minibatch Loss= 0.0117, Training Accuracy= 0.9855, Minibatch error= 1.5%
# 2017-07-14 18:45:11,834 Epoch 45, Average loss: 0.0136, learning rate: 0.0199
# 2017-07-14 18:45:12,781 Verification error= 1.7%, loss= 0.0136
# 2017-07-14 18:45:39,726 Iter 2300, Minibatch Loss= 0.0179, Training Accuracy= 0.9797, Minibatch error= 2.0%
# 2017-07-14 18:46:05,133 Iter 2310, Minibatch Loss= 0.0071, Training Accuracy= 0.9940, Minibatch error= 0.6%
# 2017-07-14 18:46:29,059 Iter 2320, Minibatch Loss= 0.0113, Training Accuracy= 0.9853, Minibatch error= 1.5%
# 2017-07-14 18:46:52,921 Iter 2330, Minibatch Loss= 0.0016, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-14 18:47:17,020 Iter 2340, Minibatch Loss= 0.0111, Training Accuracy= 0.9854, Minibatch error= 1.5%
# 2017-07-14 18:47:38,371 Epoch 46, Average loss: 0.0129, learning rate: 0.0189
# 2017-07-14 18:47:39,322 Verification error= 1.7%, loss= 0.0136
# 2017-07-14 18:48:18,743 Iter 2350, Minibatch Loss= 0.0161, Training Accuracy= 0.9804, Minibatch error= 2.0%
# 2017-07-14 18:48:45,510 Iter 2360, Minibatch Loss= 0.0183, Training Accuracy= 0.9773, Minibatch error= 2.3%
# 2017-07-14 18:49:10,324 Iter 2370, Minibatch Loss= 0.0079, Training Accuracy= 0.9917, Minibatch error= 0.8%
# 2017-07-14 18:49:34,506 Iter 2380, Minibatch Loss= 0.0180, Training Accuracy= 0.9765, Minibatch error= 2.3%
# 2017-07-14 18:49:59,368 Iter 2390, Minibatch Loss= 0.0218, Training Accuracy= 0.9721, Minibatch error= 2.8%
# 2017-07-14 18:50:21,805 Epoch 47, Average loss: 0.0150, learning rate: 0.0179
# 2017-07-14 18:50:22,758 Verification error= 1.7%, loss= 0.0136
# 2017-07-14 18:50:57,046 Iter 2400, Minibatch Loss= 0.0205, Training Accuracy= 0.9751, Minibatch error= 2.5%
# 2017-07-14 18:51:22,031 Iter 2410, Minibatch Loss= 0.0046, Training Accuracy= 0.9943, Minibatch error= 0.6%
# 2017-07-14 18:51:47,923 Iter 2420, Minibatch Loss= 0.0180, Training Accuracy= 0.9770, Minibatch error= 2.3%
# 2017-07-14 18:52:12,398 Iter 2430, Minibatch Loss= 0.0112, Training Accuracy= 0.9851, Minibatch error= 1.5%
# 2017-07-14 18:52:36,967 Iter 2440, Minibatch Loss= 0.0121, Training Accuracy= 0.9855, Minibatch error= 1.5%
# 2017-07-14 18:52:59,192 Epoch 48, Average loss: 0.0126, learning rate: 0.0171
# 2017-07-14 18:53:00,149 Verification error= 1.6%, loss= 0.0136
# 2017-07-14 18:54:34,661 Iter 2450, Minibatch Loss= 0.0062, Training Accuracy= 0.9939, Minibatch error= 0.6%
# 2017-07-14 18:55:00,911 Iter 2460, Minibatch Loss= 0.0181, Training Accuracy= 0.9782, Minibatch error= 2.2%
# 2017-07-14 18:55:24,852 Iter 2470, Minibatch Loss= 0.0137, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2017-07-14 18:55:49,395 Iter 2480, Minibatch Loss= 0.0046, Training Accuracy= 0.9945, Minibatch error= 0.6%
# 2017-07-14 18:56:13,417 Iter 2490, Minibatch Loss= 0.0140, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-14 18:56:35,282 Epoch 49, Average loss: 0.0151, learning rate: 0.0162
# 2017-07-14 18:56:36,237 Verification error= 1.5%, loss= 0.0136
# 2017-07-14 18:57:08,115 Iter 2500, Minibatch Loss= 0.0166, Training Accuracy= 0.9798, Minibatch error= 2.0%
# 2017-07-14 18:57:32,572 Iter 2510, Minibatch Loss= 0.0112, Training Accuracy= 0.9861, Minibatch error= 1.4%
# 2017-07-14 18:57:58,522 Iter 2520, Minibatch Loss= 0.0101, Training Accuracy= 0.9904, Minibatch error= 1.0%
# 2017-07-14 18:58:22,941 Iter 2530, Minibatch Loss= 0.0101, Training Accuracy= 0.9922, Minibatch error= 0.8%
# 2017-07-14 18:58:47,586 Iter 2540, Minibatch Loss= 0.0165, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2017-07-14 18:59:10,274 Epoch 50, Average loss: 0.0129, learning rate: 0.0154
# 2017-07-14 18:59:11,279 Verification error= 0.9%, loss= 0.0136
# 2017-07-14 18:59:49,582 Iter 2550, Minibatch Loss= 0.0269, Training Accuracy= 0.9871, Minibatch error= 1.3%
# 2017-07-14 19:00:14,928 Iter 2560, Minibatch Loss= 0.0172, Training Accuracy= 0.9916, Minibatch error= 0.8%
# 2017-07-14 19:00:39,607 Iter 2570, Minibatch Loss= 0.0123, Training Accuracy= 0.9939, Minibatch error= 0.6%
# 2017-07-14 19:01:04,306 Iter 2580, Minibatch Loss= 0.0216, Training Accuracy= 0.9909, Minibatch error= 0.9%
# 2017-07-14 19:01:28,986 Iter 2590, Minibatch Loss= 0.0136, Training Accuracy= 0.9943, Minibatch error= 0.6%
# 2017-07-14 19:01:51,012 Epoch 51, Average loss: 0.0147, learning rate: 0.0146
# 2017-07-14 19:01:51,969 Verification error= 0.4%, loss= 0.0136
# 2017-07-14 19:02:22,594 Iter 2600, Minibatch Loss= 0.0189, Training Accuracy= 0.9951, Minibatch error= 0.5%
# 2017-07-14 19:02:51,235 Iter 2610, Minibatch Loss= 0.0091, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2017-07-14 19:03:17,904 Iter 2620, Minibatch Loss= 0.0141, Training Accuracy= 0.9967, Minibatch error= 0.3%
# 2017-07-14 19:03:44,874 Iter 2630, Minibatch Loss= 0.0189, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2017-07-14 19:04:10,803 Iter 2640, Minibatch Loss= 0.0247, Training Accuracy= 0.9926, Minibatch error= 0.7%
# 2017-07-14 19:04:33,824 Epoch 52, Average loss: 0.0140, learning rate: 0.0139
# 2017-07-14 19:04:34,982 Verification error= 0.3%, loss= 0.0135
# 2017-07-14 19:05:21,368 Iter 2650, Minibatch Loss= 0.0177, Training Accuracy= 0.9970, Minibatch error= 0.3%
# 2017-07-14 19:05:49,156 Iter 2660, Minibatch Loss= 0.0173, Training Accuracy= 0.9978, Minibatch error= 0.2%
# 2017-07-14 19:06:15,023 Iter 2670, Minibatch Loss= 0.0081, Training Accuracy= 0.9982, Minibatch error= 0.2%
# 2017-07-14 19:06:40,387 Iter 2680, Minibatch Loss= 0.0110, Training Accuracy= 0.9985, Minibatch error= 0.1%
# 2017-07-14 19:07:05,539 Iter 2690, Minibatch Loss= 0.0212, Training Accuracy= 0.9937, Minibatch error= 0.6%
# 2017-07-14 19:07:30,269 Epoch 53, Average loss: 0.0125, learning rate: 0.0132
# 2017-07-14 19:07:31,263 Verification error= 0.2%, loss= 0.0134
# 2017-07-14 19:08:03,989 Iter 2700, Minibatch Loss= 0.0251, Training Accuracy= 0.9932, Minibatch error= 0.7%
# 2017-07-14 19:08:30,354 Iter 2710, Minibatch Loss= 0.0106, Training Accuracy= 0.9950, Minibatch error= 0.5%
# 2017-07-14 19:08:58,695 Iter 2720, Minibatch Loss= 0.0110, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-14 19:09:24,379 Iter 2730, Minibatch Loss= 0.0114, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-14 19:09:52,170 Iter 2740, Minibatch Loss= 0.0037, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-14 19:10:15,742 Epoch 54, Average loss: 0.0144, learning rate: 0.0125
# 2017-07-14 19:10:16,697 Verification error= 0.2%, loss= 0.0134
# 2017-07-14 19:10:56,388 Iter 2750, Minibatch Loss= 0.0097, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-14 19:11:24,475 Iter 2760, Minibatch Loss= 0.0112, Training Accuracy= 0.9985, Minibatch error= 0.2%
# 2017-07-14 19:11:51,454 Iter 2770, Minibatch Loss= 0.0196, Training Accuracy= 0.9961, Minibatch error= 0.4%
# 2017-07-14 19:12:18,193 Iter 2780, Minibatch Loss= 0.0066, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-14 19:12:44,397 Iter 2790, Minibatch Loss= 0.0161, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2017-07-14 19:13:08,398 Epoch 55, Average loss: 0.0131, learning rate: 0.0119
# 2017-07-14 19:13:09,349 Verification error= 0.2%, loss= 0.0133
# 2017-07-14 19:13:53,209 Iter 2800, Minibatch Loss= 0.0167, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-14 19:14:22,736 Iter 2810, Minibatch Loss= 0.0180, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-14 19:14:48,946 Iter 2820, Minibatch Loss= 0.0045, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2017-07-14 19:15:14,888 Iter 2830, Minibatch Loss= 0.0168, Training Accuracy= 0.9978, Minibatch error= 0.2%
# 2017-07-14 19:15:41,613 Iter 2840, Minibatch Loss= 0.0223, Training Accuracy= 0.9925, Minibatch error= 0.7%
# 2017-07-14 19:16:05,282 Epoch 56, Average loss: 0.0125, learning rate: 0.0113
# 2017-07-14 19:16:06,233 Verification error= 0.2%, loss= 0.0133
# 2017-07-14 19:17:13,001 Iter 2850, Minibatch Loss= 0.0170, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2017-07-14 19:17:40,845 Iter 2860, Minibatch Loss= 0.0186, Training Accuracy= 0.9976, Minibatch error= 0.2%
# 2017-07-14 19:18:07,182 Iter 2870, Minibatch Loss= 0.0068, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-14 19:18:34,367 Iter 2880, Minibatch Loss= 0.0097, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-14 19:19:01,290 Iter 2890, Minibatch Loss= 0.0150, Training Accuracy= 0.9972, Minibatch error= 0.3%
# 2017-07-14 19:19:25,720 Epoch 57, Average loss: 0.0142, learning rate: 0.0107
# 2017-07-14 19:19:26,673 Verification error= 0.2%, loss= 0.0132
# 2017-07-14 19:20:02,885 Iter 2900, Minibatch Loss= 0.0393, Training Accuracy= 0.9924, Minibatch error= 0.8%
# 2017-07-14 19:20:31,333 Iter 2910, Minibatch Loss= 0.0130, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-14 19:20:58,192 Iter 2920, Minibatch Loss= 0.0179, Training Accuracy= 0.9982, Minibatch error= 0.2%
# 2017-07-14 19:21:24,653 Iter 2930, Minibatch Loss= 0.0115, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-14 19:21:51,698 Iter 2940, Minibatch Loss= 0.0109, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-14 19:22:15,929 Epoch 58, Average loss: 0.0142, learning rate: 0.0102
# 2017-07-14 19:22:16,891 Verification error= 0.2%, loss= 0.0132
# 2017-07-14 19:23:23,086 Iter 2950, Minibatch Loss= 0.0135, Training Accuracy= 0.9977, Minibatch error= 0.2%
# 2017-07-14 19:23:51,707 Iter 2960, Minibatch Loss= 0.0108, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-14 19:24:18,649 Iter 2970, Minibatch Loss= 0.0158, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-14 19:24:45,163 Iter 2980, Minibatch Loss= 0.0116, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2017-07-14 19:25:11,421 Iter 2990, Minibatch Loss= 0.0169, Training Accuracy= 0.9969, Minibatch error= 0.3%
# 2017-07-14 19:25:36,429 Epoch 59, Average loss: 0.0128, learning rate: 0.0097
# 2017-07-14 19:25:37,438 Verification error= 0.2%, loss= 0.0131
# 2017-07-14 19:26:13,645 Iter 3000, Minibatch Loss= 0.0113, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-14 19:26:43,619 Iter 3010, Minibatch Loss= 0.0154, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2017-07-14 19:27:12,126 Iter 3020, Minibatch Loss= 0.0103, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-14 19:27:39,627 Iter 3030, Minibatch Loss= 0.0108, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-14 19:28:06,010 Iter 3040, Minibatch Loss= 0.0243, Training Accuracy= 0.9939, Minibatch error= 0.6%
# 2017-07-14 19:28:31,063 Epoch 60, Average loss: 0.0127, learning rate: 0.0092
# 2017-07-14 19:28:32,040 Verification error= 0.2%, loss= 0.0131
# 2017-07-14 19:29:15,316 Iter 3050, Minibatch Loss= 0.0100, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-14 19:29:44,231 Iter 3060, Minibatch Loss= 0.0242, Training Accuracy= 0.9937, Minibatch error= 0.6%
# 2017-07-14 19:30:11,598 Iter 3070, Minibatch Loss= 0.0108, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-14 19:30:38,986 Iter 3080, Minibatch Loss= 0.0071, Training Accuracy= 0.9946, Minibatch error= 0.5%
# 2017-07-14 19:31:06,726 Iter 3090, Minibatch Loss= 0.0102, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-14 19:31:31,279 Epoch 61, Average loss: 0.0134, learning rate: 0.0088
# 2017-07-14 19:31:32,237 Verification error= 0.2%, loss= 0.0130
# 2017-07-14 19:32:38,937 Iter 3100, Minibatch Loss= 0.0054, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-14 19:33:07,857 Iter 3110, Minibatch Loss= 0.0103, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-14 19:33:35,349 Iter 3120, Minibatch Loss= 0.0032, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-14 19:34:03,235 Iter 3130, Minibatch Loss= 0.0175, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2017-07-14 19:34:31,745 Iter 3140, Minibatch Loss= 0.0180, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-14 19:34:56,111 Epoch 62, Average loss: 0.0117, learning rate: 0.0083
# 2017-07-14 19:34:57,076 Verification error= 0.2%, loss= 0.0130
# 2017-07-14 19:35:38,686 Iter 3150, Minibatch Loss= 0.0042, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-14 19:36:07,506 Iter 3160, Minibatch Loss= 0.0175, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-14 19:36:36,823 Iter 3170, Minibatch Loss= 0.0027, Training Accuracy= 0.9997, Minibatch error= 0.0%
# 2017-07-14 19:37:04,760 Iter 3180, Minibatch Loss= 0.0124, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-14 19:37:33,086 Iter 3190, Minibatch Loss= 0.0097, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2017-07-14 19:37:58,223 Epoch 63, Average loss: 0.0134, learning rate: 0.0079
# 2017-07-14 19:37:59,188 Verification error= 0.2%, loss= 0.0129
# 2017-07-14 19:39:08,076 Iter 3200, Minibatch Loss= 0.0105, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-14 19:39:38,725 Iter 3210, Minibatch Loss= 0.0161, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-14 19:40:07,502 Iter 3220, Minibatch Loss= 0.0173, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2017-07-14 19:40:35,709 Iter 3230, Minibatch Loss= 0.0175, Training Accuracy= 0.9975, Minibatch error= 0.3%
# 2017-07-14 19:41:03,399 Iter 3240, Minibatch Loss= 0.0102, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2017-07-14 19:41:28,637 Epoch 64, Average loss: 0.0130, learning rate: 0.0075
# 2017-07-14 19:41:29,589 Verification error= 0.2%, loss= 0.0129
# 2017-07-14 19:43:10,812 Iter 3250, Minibatch Loss= 0.0064, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-14 19:44:29,035 Iter 3260, Minibatch Loss= 0.0144, Training Accuracy= 0.9846, Minibatch error= 1.5%
# 2017-07-14 19:44:57,284 Iter 3270, Minibatch Loss= 0.0186, Training Accuracy= 0.9978, Minibatch error= 0.2%
# 2017-07-14 19:45:26,214 Iter 3280, Minibatch Loss= 0.0107, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-14 19:45:54,564 Iter 3290, Minibatch Loss= 0.0132, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-14 19:46:20,014 Epoch 65, Average loss: 0.0136, learning rate: 0.0071
# 2017-07-14 19:46:20,969 Verification error= 0.2%, loss= 0.0128
# 2017-07-14 19:47:29,447 Iter 3300, Minibatch Loss= 0.0108, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-14 19:48:00,186 Iter 3310, Minibatch Loss= 0.0187, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-14 19:48:28,719 Iter 3320, Minibatch Loss= 0.0114, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-14 19:48:58,726 Iter 3330, Minibatch Loss= 0.0032, Training Accuracy= 0.9995, Minibatch error= 0.0%
# 2017-07-14 19:49:27,735 Iter 3340, Minibatch Loss= 0.0126, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-14 19:49:52,506 Epoch 66, Average loss: 0.0113, learning rate: 0.0068
# 2017-07-14 19:49:53,454 Verification error= 0.2%, loss= 0.0128
# 2017-07-14 19:50:27,137 Iter 3350, Minibatch Loss= 0.0101, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-14 19:51:44,108 Iter 3360, Minibatch Loss= 0.0101, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-14 19:52:12,881 Iter 3370, Minibatch Loss= 0.0159, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-14 19:52:44,339 Iter 3380, Minibatch Loss= 0.0113, Training Accuracy= 0.9985, Minibatch error= 0.1%
# 2017-07-14 19:53:12,323 Iter 3390, Minibatch Loss= 0.0085, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-14 19:53:37,649 Epoch 67, Average loss: 0.0133, learning rate: 0.0064
# 2017-07-14 19:53:38,604 Verification error= 0.2%, loss= 0.0127
# 2017-07-14 19:54:17,000 Iter 3400, Minibatch Loss= 0.0114, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-14 19:54:46,203 Iter 3410, Minibatch Loss= 0.0177, Training Accuracy= 0.9972, Minibatch error= 0.3%
# 2017-07-14 19:55:50,699 Iter 3420, Minibatch Loss= 0.0054, Training Accuracy= 0.9984, Minibatch error= 0.2%
# 2017-07-14 19:56:18,937 Iter 3430, Minibatch Loss= 0.0102, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-14 19:56:46,360 Iter 3440, Minibatch Loss= 0.0078, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-14 19:57:11,465 Epoch 68, Average loss: 0.0127, learning rate: 0.0061
# 2017-07-14 19:57:13,207 Verification error= 0.2%, loss= 0.0127
# 2017-07-14 19:57:51,170 Iter 3450, Minibatch Loss= 0.0102, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-14 19:58:20,419 Iter 3460, Minibatch Loss= 0.0042, Training Accuracy= 0.9997, Minibatch error= 0.0%
# 2017-07-14 19:58:49,563 Iter 3470, Minibatch Loss= 0.0137, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2017-07-14 19:59:17,378 Iter 3480, Minibatch Loss= 0.0103, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-14 19:59:46,681 Iter 3490, Minibatch Loss= 0.0043, Training Accuracy= 0.9962, Minibatch error= 0.4%
# 2017-07-14 20:00:12,349 Epoch 69, Average loss: 0.0117, learning rate: 0.0058
# ...
# 2017-07-15 00:32:52,687 Iter 6340, Minibatch Loss= 0.0098, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-15 00:33:35,127 Epoch 126, Average loss: 0.0115, learning rate: 0.0003
# 2017-07-15 00:33:36,446 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 00:35:27,191 Iter 6350, Minibatch Loss= 0.0117, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-15 00:36:12,900 Iter 6360, Minibatch Loss= 0.0016, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-15 00:36:57,770 Iter 6370, Minibatch Loss= 0.0041, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-15 00:37:53,227 Iter 6380, Minibatch Loss= 0.0140, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-15 00:38:41,710 Iter 6390, Minibatch Loss= 0.0108, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-15 00:39:26,800 Epoch 127, Average loss: 0.0123, learning rate: 0.0003
# 2017-07-15 00:39:29,544 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 00:41:27,462 Iter 6400, Minibatch Loss= 0.0100, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-15 00:42:16,232 Iter 6410, Minibatch Loss= 0.0149, Training Accuracy= 0.9966, Minibatch error= 0.3%
# 2017-07-15 00:43:03,559 Iter 6420, Minibatch Loss= 0.0135, Training Accuracy= 0.9978, Minibatch error= 0.2%
# 2017-07-15 00:43:47,685 Iter 6430, Minibatch Loss= 0.0141, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-15 00:44:31,759 Iter 6440, Minibatch Loss= 0.0146, Training Accuracy= 0.9970, Minibatch error= 0.3%
# 2017-07-15 00:45:11,000 Epoch 128, Average loss: 0.0115, learning rate: 0.0003
# 2017-07-15 00:45:12,125 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 00:46:53,578 Iter 6450, Minibatch Loss= 0.0176, Training Accuracy= 0.9976, Minibatch error= 0.2%
# 2017-07-15 00:47:41,819 Iter 6460, Minibatch Loss= 0.0040, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-15 00:48:27,515 Iter 6470, Minibatch Loss= 0.0104, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-15 00:49:14,522 Iter 6480, Minibatch Loss= 0.0132, Training Accuracy= 0.9959, Minibatch error= 0.4%
# 2017-07-15 00:50:00,353 Iter 6490, Minibatch Loss= 0.0116, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2017-07-15 00:50:42,903 Epoch 129, Average loss: 0.0120, learning rate: 0.0003
# 2017-07-15 00:50:43,959 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 00:53:15,105 Iter 6500, Minibatch Loss= 0.0012, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-15 00:54:05,772 Iter 6510, Minibatch Loss= 0.0112, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-15 00:54:53,107 Iter 6520, Minibatch Loss= 0.0087, Training Accuracy= 0.9995, Minibatch error= 0.0%
# 2017-07-15 00:55:40,157 Iter 6530, Minibatch Loss= 0.0130, Training Accuracy= 0.9982, Minibatch error= 0.2%
# 2017-07-15 00:56:27,155 Iter 6540, Minibatch Loss= 0.0148, Training Accuracy= 0.9847, Minibatch error= 1.5%
# 2017-07-15 00:57:08,052 Epoch 130, Average loss: 0.0119, learning rate: 0.0003
# 2017-07-15 00:57:09,020 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 00:58:50,362 Iter 6550, Minibatch Loss= 0.0115, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2017-07-15 00:59:39,579 Iter 6560, Minibatch Loss= 0.0086, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2017-07-15 01:00:25,557 Iter 6570, Minibatch Loss= 0.0092, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2017-07-15 01:01:13,246 Iter 6580, Minibatch Loss= 0.0097, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-15 01:02:00,620 Iter 6590, Minibatch Loss= 0.0030, Training Accuracy= 0.9997, Minibatch error= 0.0%
# 2017-07-15 01:02:42,029 Epoch 131, Average loss: 0.0108, learning rate: 0.0002
# 2017-07-15 01:02:43,010 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 01:05:02,587 Iter 6600, Minibatch Loss= 0.0163, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2017-07-15 01:05:47,375 Iter 6610, Minibatch Loss= 0.0072, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-15 01:06:32,261 Iter 6620, Minibatch Loss= 0.0102, Training Accuracy= 0.9977, Minibatch error= 0.2%
# 2017-07-15 01:07:21,367 Iter 6630, Minibatch Loss= 0.0108, Training Accuracy= 0.9985, Minibatch error= 0.2%
# 2017-07-15 01:08:07,593 Iter 6640, Minibatch Loss= 0.0119, Training Accuracy= 0.9972, Minibatch error= 0.3%
# 2017-07-15 01:08:51,695 Epoch 132, Average loss: 0.0115, learning rate: 0.0002
# 2017-07-15 01:08:52,992 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 01:10:34,868 Iter 6650, Minibatch Loss= 0.0031, Training Accuracy= 0.9997, Minibatch error= 0.0%
# 2017-07-15 01:11:23,420 Iter 6660, Minibatch Loss= 0.0218, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-15 01:12:11,373 Iter 6670, Minibatch Loss= 0.0100, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-15 01:13:00,479 Iter 6680, Minibatch Loss= 0.0147, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-15 01:13:47,428 Iter 6690, Minibatch Loss= 0.0046, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-15 01:14:33,196 Epoch 133, Average loss: 0.0118, learning rate: 0.0002
# 2017-07-15 01:14:36,503 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 01:16:34,441 Iter 6700, Minibatch Loss= 0.0057, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2017-07-15 01:17:25,810 Iter 6710, Minibatch Loss= 0.0035, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-15 01:18:13,530 Iter 6720, Minibatch Loss= 0.0092, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-15 01:19:03,009 Iter 6730, Minibatch Loss= 0.0078, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-15 01:19:50,920 Iter 6740, Minibatch Loss= 0.0078, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-15 01:20:37,030 Epoch 134, Average loss: 0.0119, learning rate: 0.0002
# 2017-07-15 01:20:38,030 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 01:22:28,627 Iter 6750, Minibatch Loss= 0.0157, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-15 01:23:15,950 Iter 6760, Minibatch Loss= 0.0161, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-15 01:24:05,077 Iter 6770, Minibatch Loss= 0.0089, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-15 01:24:54,217 Iter 6780, Minibatch Loss= 0.0155, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-15 01:25:41,989 Iter 6790, Minibatch Loss= 0.0036, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-15 01:26:30,599 Epoch 135, Average loss: 0.0124, learning rate: 0.0002
# 2017-07-15 01:26:31,646 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 01:27:39,623 Iter 6800, Minibatch Loss= 0.0110, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-15 01:28:29,712 Iter 6810, Minibatch Loss= 0.0098, Training Accuracy= 0.9977, Minibatch error= 0.2%
# 2017-07-15 01:29:17,911 Iter 6820, Minibatch Loss= 0.0099, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-15 01:30:30,207 Iter 6830, Minibatch Loss= 0.0149, Training Accuracy= 0.9966, Minibatch error= 0.3%
# 2017-07-15 01:32:01,715 Iter 6840, Minibatch Loss= 0.0097, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-15 01:33:20,295 Epoch 136, Average loss: 0.0115, learning rate: 0.0002
# 2017-07-15 01:33:26,402 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 01:35:15,489 Iter 6850, Minibatch Loss= 0.0081, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2017-07-15 01:36:09,433 Iter 6860, Minibatch Loss= 0.0127, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-15 01:36:59,131 Iter 6870, Minibatch Loss= 0.0165, Training Accuracy= 0.9961, Minibatch error= 0.4%
# 2017-07-15 01:37:49,603 Iter 6880, Minibatch Loss= 0.0095, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-15 01:39:04,859 Iter 6890, Minibatch Loss= 0.0155, Training Accuracy= 0.9842, Minibatch error= 1.6%
# 2017-07-15 01:40:20,239 Epoch 137, Average loss: 0.0119, learning rate: 0.0002
# 2017-07-15 01:40:21,274 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 01:42:32,830 Iter 6900, Minibatch Loss= 0.0041, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-15 01:43:22,688 Iter 6910, Minibatch Loss= 0.0097, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2017-07-15 01:44:11,645 Iter 6920, Minibatch Loss= 0.0113, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-15 01:45:01,702 Iter 6930, Minibatch Loss= 0.0153, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-15 01:46:58,971 Iter 6940, Minibatch Loss= 0.0090, Training Accuracy= 0.9972, Minibatch error= 0.3%
# 2017-07-15 01:48:00,967 Epoch 138, Average loss: 0.0133, learning rate: 0.0002
# 2017-07-15 01:48:01,997 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 01:49:13,659 Iter 6950, Minibatch Loss= 0.0165, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2017-07-15 01:50:02,804 Iter 6960, Minibatch Loss= 0.0185, Training Accuracy= 0.9956, Minibatch error= 0.4%
# 2017-07-15 01:51:01,158 Iter 6970, Minibatch Loss= 0.0160, Training Accuracy= 0.9967, Minibatch error= 0.3%
# 2017-07-15 01:52:29,881 Iter 6980, Minibatch Loss= 0.0141, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-15 01:53:17,655 Iter 6990, Minibatch Loss= 0.0157, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-15 01:53:59,491 Epoch 139, Average loss: 0.0120, learning rate: 0.0002
# 2017-07-15 01:54:01,050 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 01:55:18,639 Iter 7000, Minibatch Loss= 0.0128, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-15 01:56:43,374 Iter 7010, Minibatch Loss= 0.0170, Training Accuracy= 0.9977, Minibatch error= 0.2%
# 2017-07-15 01:57:42,411 Iter 7020, Minibatch Loss= 0.0098, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-15 02:00:42,206 Iter 7030, Minibatch Loss= 0.0177, Training Accuracy= 0.9978, Minibatch error= 0.2%
# 2017-07-15 02:01:33,051 Iter 7040, Minibatch Loss= 0.0133, Training Accuracy= 0.9857, Minibatch error= 1.4%
# 2017-07-15 02:02:20,456 Epoch 140, Average loss: 0.0115, learning rate: 0.0002
# 2017-07-15 02:02:21,714 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 02:05:02,056 Iter 7050, Minibatch Loss= 0.0139, Training Accuracy= 0.9985, Minibatch error= 0.2%
# 2017-07-15 02:06:10,458 Iter 7060, Minibatch Loss= 0.0141, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2017-07-15 02:07:00,264 Iter 7070, Minibatch Loss= 0.0155, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-15 02:07:59,831 Iter 7080, Minibatch Loss= 0.0163, Training Accuracy= 0.9829, Minibatch error= 1.7%
# 2017-07-15 02:10:05,375 Iter 7090, Minibatch Loss= 0.0117, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-15 02:10:51,085 Epoch 141, Average loss: 0.0127, learning rate: 0.0001
# 2017-07-15 02:10:53,375 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 02:13:45,790 Iter 7100, Minibatch Loss= 0.0157, Training Accuracy= 0.9839, Minibatch error= 1.6%
# 2017-07-15 02:15:08,900 Iter 7110, Minibatch Loss= 0.0087, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-15 02:15:58,247 Iter 7120, Minibatch Loss= 0.0150, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-15 02:16:48,404 Iter 7130, Minibatch Loss= 0.0086, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-15 02:17:40,637 Iter 7140, Minibatch Loss= 0.0092, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2017-07-15 02:18:46,294 Epoch 142, Average loss: 0.0112, learning rate: 0.0001
# 2017-07-15 02:18:47,641 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 02:22:52,726 Iter 7150, Minibatch Loss= 0.0104, Training Accuracy= 0.9984, Minibatch error= 0.2%
# 2017-07-15 02:24:26,469 Iter 7160, Minibatch Loss= 0.0104, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2017-07-15 02:25:16,147 Iter 7170, Minibatch Loss= 0.0079, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-15 02:26:07,807 Iter 7180, Minibatch Loss= 0.0161, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2017-07-15 02:26:57,755 Iter 7190, Minibatch Loss= 0.0126, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-15 02:27:45,180 Epoch 143, Average loss: 0.0122, learning rate: 0.0001
# 2017-07-15 02:27:46,307 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 02:29:57,017 Iter 7200, Minibatch Loss= 0.0159, Training Accuracy= 0.9833, Minibatch error= 1.7%
# 2017-07-15 02:32:29,246 Iter 7210, Minibatch Loss= 0.0110, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-15 02:33:20,111 Iter 7220, Minibatch Loss= 0.0143, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-15 02:34:11,831 Iter 7230, Minibatch Loss= 0.0103, Training Accuracy= 0.9974, Minibatch error= 0.3%
# 2017-07-15 02:35:01,106 Iter 7240, Minibatch Loss= 0.0165, Training Accuracy= 0.9975, Minibatch error= 0.2%
# 2017-07-15 02:35:49,712 Epoch 144, Average loss: 0.0134, learning rate: 0.0001
# 2017-07-15 02:35:51,339 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 02:37:34,276 Iter 7250, Minibatch Loss= 0.0168, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-15 02:38:26,527 Iter 7260, Minibatch Loss= 0.0154, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-15 02:39:16,681 Iter 7270, Minibatch Loss= 0.0054, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-15 02:40:06,956 Iter 7280, Minibatch Loss= 0.0193, Training Accuracy= 0.9949, Minibatch error= 0.5%
# 2017-07-15 02:40:58,113 Iter 7290, Minibatch Loss= 0.0153, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2017-07-15 02:41:45,278 Epoch 145, Average loss: 0.0119, learning rate: 0.0001
# 2017-07-15 02:41:46,482 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 02:44:43,994 Iter 7300, Minibatch Loss= 0.0154, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-15 02:45:36,859 Iter 7310, Minibatch Loss= 0.0088, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-15 02:46:26,457 Iter 7320, Minibatch Loss= 0.0092, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-15 02:47:45,773 Iter 7330, Minibatch Loss= 0.0149, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-15 02:49:15,628 Iter 7340, Minibatch Loss= 0.0105, Training Accuracy= 0.9976, Minibatch error= 0.2%
# 2017-07-15 02:50:06,973 Epoch 146, Average loss: 0.0118, learning rate: 0.0001
# 2017-07-15 02:50:08,101 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 02:52:20,377 Iter 7350, Minibatch Loss= 0.0091, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-15 02:53:14,680 Iter 7360, Minibatch Loss= 0.0047, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-15 02:54:07,884 Iter 7370, Minibatch Loss= 0.0104, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-15 02:55:20,766 Iter 7380, Minibatch Loss= 0.0084, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2017-07-15 02:56:11,973 Iter 7390, Minibatch Loss= 0.0192, Training Accuracy= 0.9957, Minibatch error= 0.4%
# 2017-07-15 02:57:21,960 Epoch 147, Average loss: 0.0115, learning rate: 0.0001
# 2017-07-15 02:57:23,289 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 03:00:41,396 Iter 7400, Minibatch Loss= 0.0188, Training Accuracy= 0.9967, Minibatch error= 0.3%
# 2017-07-15 03:02:41,630 Iter 7410, Minibatch Loss= 0.0155, Training Accuracy= 0.9842, Minibatch error= 1.6%
# 2017-07-15 03:05:23,449 Iter 7420, Minibatch Loss= 0.0112, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-15 03:06:31,665 Iter 7430, Minibatch Loss= 0.0045, Training Accuracy= 0.9984, Minibatch error= 0.2%
# 2017-07-15 03:07:27,503 Iter 7440, Minibatch Loss= 0.0111, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-15 03:08:14,851 Epoch 148, Average loss: 0.0135, learning rate: 0.0001
# 2017-07-15 03:08:23,497 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 03:13:01,916 Iter 7450, Minibatch Loss= 0.0108, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-15 03:14:13,950 Iter 7460, Minibatch Loss= 0.0157, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-15 03:15:09,147 Iter 7470, Minibatch Loss= 0.0078, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-15 03:16:03,884 Iter 7480, Minibatch Loss= 0.0040, Training Accuracy= 0.9982, Minibatch error= 0.2%
# 2017-07-15 03:16:57,461 Iter 7490, Minibatch Loss= 0.0057, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-15 03:17:46,711 Epoch 149, Average loss: 0.0112, learning rate: 0.0001
# 2017-07-15 03:17:49,854 Verification error= 0.2%, loss= 0.0119
# 2017-07-15 03:20:36,588 Optimization Finished!

# %% [markdown]
# >  Making predictions on **```K```** data samples using saved model

# %%
prediction = net.predict("./unet_trained_50_500_3/model_50_500_3.cpkt", X_test)
# Out:
# INFO:tensorflow:Restoring parameters from ./unet_trained_50_500_3/model_50_500_3.cpkt
# 2017-07-26 11:33:15,997 Restoring parameters from ./unet_trained_50_500_3/model_50_500_3.cpkt
# 2017-07-26 11:33:16,401 Model restored from file: ./unet_trained_50_500_3/model_50_500_3.cpkt

# %% [markdown]
# > Storing **```errors```** in an array of different models

# %%
errors = []                                                        ## an array to store the error values of models

# %%
err1 = error_rate(prediction1,Y_test)
errors.append(err1)

# %%
err1                                                               ## error on layer 7 convolutional CNNs
# Out:
# 0.20687103271484375

# %% [markdown]
# > Plotting results here:

# %%
fig, ax = plt.subplots(1, 2, sharex=True, sharey=True, figsize=(12,5))
ax[0].imshow(X_test[0,...,0], aspect="auto")
#ax[1].imshow(Y_test[0,...,1], aspect="auto")
mask = np.zeros_like(prediction[0,...,1],dtype="float32")
mask[prediction[0,...,1] > 0.55]=1.0
ax[1].imshow(mask, aspect="auto")
ax[0].set_title("Input")
#ax[1].set_title("Ground truth")
ax[1].set_title("Prediction")
fig.tight_layout()
#fig.savefig("../Image_Seg/prediction_model_50_500_3/output_test_5.png")

# %%
plot_prediction(x_test=X_test,y_test=Y_test,prediction=prediction,save=False)

# %% [markdown]
# > Other models which can be tried in future

# %%
def create_conv_net_2(x, keep_prob, channels, n_class, layers=7, features_root=16, filter_size=3, pool_size=2, summaries=False):
    """
    Creates a new convolutional unet for the given parametrization.
    
    :param x: input tensor, shape [?,nx,ny,channels]
    :param keep_prob: dropout probability tensor
    :param channels: number of channels in the input image
    :param n_class: number of output labels
    :param layers: number of layers in the net
    :param features_root: number of features in the first layer
    :param filter_size: size of the convolution filter
    :param pool_size: size of the max pooling operation
    :param summaries: Flag if summaries should be created
    """
    
    logging.info("Layers {layers}, features {features}, filter size {filter_size}x{filter_size},pool size: {pool_size}x{pool_size}".format(layers=layers,
                                                                                                           features=features_root,
                                                                                                           filter_size=filter_size,
                                                                                                           pool_size=pool_size))
    # Placeholder for the input image
    nx = tf.shape(x)[1]
    ny = tf.shape(x)[2]
    x_image = tf.reshape(x, tf.stack([-1,nx,ny,channels]))
    in_node = x_image
    batch_size = tf.shape(x_image)[0]
 
    weights = []
    biases = []
    convs = []
    pools = OrderedDict()
    deconv = OrderedDict()
    dw_h_convs = OrderedDict()
    up_h_convs = OrderedDict()
    paddings=[[0,0],[1,1],[1,1],[0,0]]
    in_size = 1000
    size = in_size
    # down layers
    for layer in range(0, layers):
        features = 2**layer*features_root
        stddev = np.sqrt(2 / (filter_size**2 * features))
        if layer == 0:
            w1 = weight_variable([filter_size, filter_size, channels, features], stddev)
        else:
            w1 = weight_variable([filter_size, filter_size, features//2, features], stddev)
            
        w2 = weight_variable([filter_size, filter_size, features, features], stddev)
        b1 = bias_variable([features])
        b2 = bias_variable([features])
        
        in_node = tf.pad(in_node,paddings,"CONSTANT")
        conv1 = conv2d(in_node, w1, keep_prob)
        tmp_h_conv = tf.nn.relu(conv1 + b1)
        tmp_h_conv = tf.pad(tmp_h_conv,paddings,"CONSTANT")
        conv2 = conv2d(tmp_h_conv, w2, keep_prob)
        dw_h_convs[layer] = tf.nn.relu(conv2 + b2)
        
        weights.append((w1, w2))
        biases.append((b1, b2))
        convs.append((conv1, conv2))
        
        size -= 4
        if layer < layers-1:
            pools[layer] = max_pool(dw_h_convs[layer], pool_size)
            in_node = pools[layer]
            size /= 2
        
    in_node = dw_h_convs[layers-1]
        
    # up layers
    for layer in range(layers-2, -1, -1):
        
        features = 2**(layer+1)*features_root
        stddev = np.sqrt(2 / (filter_size**2 * features))
        
        wd = weight_variable_devonc([pool_size, pool_size, features//2, features], stddev)
        bd = bias_variable([features//2])
        h_deconv = tf.nn.relu(deconv2d(in_node, wd, pool_size) + bd)
        h_deconv_concat = crop_and_concat(dw_h_convs[layer], h_deconv)
        deconv[layer] = h_deconv_concat
        
        w1 = weight_variable([filter_size, filter_size, features, features//2], stddev)
        w2 = weight_variable([filter_size, filter_size, features//2, features//2], stddev)
        b1 = bias_variable([features//2])
        b2 = bias_variable([features//2])
        
        h_deconv_concat = tf.pad(h_deconv_concat,paddings,"CONSTANT")
        conv1 = conv2d(h_deconv_concat, w1, keep_prob)
        h_conv = tf.nn.relu(conv1 + b1)
        h_conv = tf.pad(h_conv,paddings,"CONSTANT")
        conv2 = conv2d(h_conv, w2, keep_prob)
        in_node = tf.nn.relu(conv2 + b2)
        up_h_convs[layer] = in_node

        weights.append((w1, w2))
        biases.append((b1, b2))
        convs.append((conv1, conv2))
        
        size *= 2
        size -= 4

    # Output Map
    weight = weight_variable([1, 1, features_root, n_class], stddev)
    bias = bias_variable([n_class])
    conv = conv2d(in_node, weight, tf.constant(1.0))
    output_map = tf.nn.relu(conv + bias)
    up_h_convs["out"] = output_map
    
    if summaries:
        for i, (c1, c2) in enumerate(convs):
            tf.summary.image('summary_conv_%02d_01'%i, get_image_summary(c1))
            tf.summary.image('summary_conv_%02d_02'%i, get_image_summary(c2))
            
        for k in pools.keys():
            tf.summary.image('summary_pool_%02d'%k, get_image_summary(pools[k]))
        
        for k in deconv.keys():
            tf.summary.image('summary_deconv_concat_%02d'%k, get_image_summary(deconv[k]))
            
        for k in dw_h_convs.keys():
            tf.summary.histogram("dw_convolution_%02d"%k + '/activations', dw_h_convs[k])

        for k in up_h_convs.keys():
            tf.summary.histogram("up_convolution_%s"%k + '/activations', up_h_convs[k])
            
    variables = []
    for w1,w2 in weights:
        variables.append(w1)
        variables.append(w2)
        
    for b1,b2 in biases:
        variables.append(b1)
        variables.append(b2)

    
    return output_map, variables, int(in_size - size)

# %%
class Unet(object):
    """
    A unet implementation
    
    :param channels: (optional) number of channels in the input image
    :param n_class: (optional) number of output labels
    :param cost: (optional) name of the cost function. Default is 'cross_entropy'
    :param cost_kwargs: (optional) kwargs passed to the cost function. See Unet._get_cost for more options
    """
    
    def __init__(self, channels=1, n_class=2, cost="cross_entropy", cost_kwargs={}, **kwargs):
        tf.reset_default_graph()
        
        self.n_class = n_class
        self.summaries = kwargs.get("summaries", True)
        
        self.x = tf.placeholder("float", shape=[None, None, None, channels])
        self.y = tf.placeholder("float", shape=[None, None, None, n_class])
        self.keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)
        
        logits, self.variables, self.offset = create_conv_net_2(self.x, self.keep_prob, channels, n_class, **kwargs)
        
        self.cost = self._get_cost(logits, cost, cost_kwargs)
        
        self.gradients_node = tf.gradients(self.cost, self.variables)
         
        self.cross_entropy = tf.reduce_mean(cross_entropy(tf.reshape(self.y, [-1, n_class]),
                                                          tf.reshape(pixel_wise_softmax_2(logits), [-1, n_class])))
        
        self.predicter = pixel_wise_softmax_2(logits)
        self.correct_pred = tf.equal(tf.argmax(self.predicter, 3), tf.argmax(self.y, 3))
        self.accuracy = tf.reduce_mean(tf.cast(self.correct_pred, tf.float32))
        
    def _get_cost(self, logits, cost_name, cost_kwargs):
        """
        Constructs the cost function, either cross_entropy, weighted cross_entropy or dice_coefficient.
        Optional arguments are: 
        class_weights: weights for the different classes in case of multi-class imbalance
        regularizer: power of the L2 regularizers added to the loss function
        """
        
        flat_logits = tf.reshape(logits, [-1, self.n_class])
        flat_labels = tf.reshape(self.y, [-1, self.n_class])
        if cost_name == "cross_entropy":
            class_weights = cost_kwargs.pop("class_weights", None)
            
            if class_weights is not None:
                class_weights = tf.constant(np.array(class_weights, dtype=np.float32))
        
                weight_map = tf.multiply(flat_labels, class_weights)
                weight_map = tf.reduce_sum(weight_map, axis=1)
        
                loss_map = tf.nn.softmax_cross_entropy_with_logits(flat_logits, flat_labels)
                weighted_loss = tf.multiply(loss_map, weight_map)
        
                loss = tf.reduce_mean(weighted_loss)
                
            else:
                loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=flat_logits, 
                                                                              labels=flat_labels))
        elif cost_name == "dice_coefficient":
            eps = 1e-5
            prediction = pixel_wise_softmax_2(logits)
            intersection = tf.reduce_sum(prediction * self.y)
            union =  eps + tf.reduce_sum(prediction) + tf.reduce_sum(self.y)
            loss = -(2 * intersection/ (union))
            
        else:
            raise ValueError("Unknown cost function: "%cost_name)

        regularizer = cost_kwargs.pop("regularizer", None)
        if regularizer is not None:
            regularizers = sum([tf.nn.l2_loss(variable) for variable in self.variables])
            loss += (regularizer * regularizers)
            
        return loss

    def predict(self, model_path, x_test):
        """
        Uses the model to create a prediction for the given data
        
        :param model_path: path to the model checkpoint to restore
        :param x_test: Data to predict on. Shape [n, nx, ny, channels]
        :returns prediction: The unet prediction Shape [n, px, py, labels] (px=nx-self.offset/2) 
        """
        
        init = tf.global_variables_initializer()
        with tf.Session(config=config) as sess:
            # Initialize variables
            sess.run(init)
        
            # Restore model weights from previously saved model
            self.restore(sess, model_path)
            
            y_dummy = np.empty((x_test.shape[0], x_test.shape[1], x_test.shape[2], self.n_class))
            prediction = sess.run(self.predicter, feed_dict={self.x: x_test, self.y: y_dummy, self.keep_prob: 1.})
            
        return prediction
    
    def save(self, sess, model_path):
        """
        Saves the current session to a checkpoint
        
        :param sess: current session
        :param model_path: path to file system location
        """
        
        saver = tf.train.Saver()
        save_path = saver.save(sess, model_path)
        return save_path
    
    def restore(self, sess, model_path):
        """
        Restores a session from a checkpoint
        
        :param sess: current session instance
        :param model_path: path to file system checkpoint location
        """
        
        saver = tf.train.Saver()
        saver.restore(sess, model_path)
        logging.info("Model restored from file: %s" % model_path)

# %%
class Trainer(object):
    """
    Trains a unet instance
    
    :param net: the unet instance to train
    :param batch_size: size of training batch
    :param optimizer: (optional) name of the optimizer to use (momentum or adam)
    :param opt_kwargs: (optional) kwargs passed to the learning rate (momentum opt) and to the optimizer
    """
    
    prediction_path = "prediction_model2"    ### to channge this before running......give number at the end.
    verification_batch_size = 4
    
    def __init__(self, net, batch_size=1, optimizer="momentum", opt_kwargs={}):
        self.net = net
        self.batch_size = batch_size
        self.optimizer = optimizer
        self.opt_kwargs = opt_kwargs
        
    def _get_optimizer(self, training_iters, global_step):
        if self.optimizer == "momentum":
            learning_rate = self.opt_kwargs.pop("learning_rate", 0.2)
            decay_rate = self.opt_kwargs.pop("decay_rate", 0.95)
            momentum = self.opt_kwargs.pop("momentum", 0.2)
            
            self.learning_rate_node = tf.train.exponential_decay(learning_rate=learning_rate, 
                                                        global_step=global_step, 
                                                        decay_steps=training_iters,  
                                                        decay_rate=decay_rate, 
                                                        staircase=True)
            
            optimizer = tf.train.MomentumOptimizer(learning_rate=self.learning_rate_node, momentum=momentum,
                                                   **self.opt_kwargs).minimize(self.net.cost, 
                                                                                global_step=global_step)
        elif self.optimizer == "adam":
            learning_rate = self.opt_kwargs.pop("learning_rate", 0.001)
            self.learning_rate_node = tf.Variable(learning_rate)
            
            optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate_node, 
                                               **self.opt_kwargs).minimize(self.net.cost,
                                                                     global_step=global_step)
        
        return optimizer
        
    def _initialize(self, training_iters, output_path, restore):
        global_step = tf.Variable(0)
        
        self.norm_gradients_node = tf.Variable(tf.constant(0.0, shape=[len(self.net.gradients_node)]))
        
        if self.net.summaries:
            tf.summary.histogram('norm_grads', self.norm_gradients_node)

        tf.summary.scalar('loss', self.net.cost)
        tf.summary.scalar('cross_entropy', self.net.cross_entropy)
        tf.summary.scalar('accuracy', self.net.accuracy)

        self.optimizer = self._get_optimizer(training_iters, global_step)
        tf.summary.scalar('learning_rate', self.learning_rate_node)

        self.summary_op = tf.summary.merge_all()        
        init = tf.global_variables_initializer()
        
        prediction_path = os.path.abspath(self.prediction_path)
        output_path = os.path.abspath(output_path)
        
        if not restore:
            logging.info("Removing '{:}'".format(prediction_path))
            shutil.rmtree(prediction_path, ignore_errors=True)
            logging.info("Removing '{:}'".format(output_path))
            shutil.rmtree(output_path, ignore_errors=True)
        
        if not os.path.exists(prediction_path):
            logging.info("Allocating '{:}'".format(prediction_path))
            os.makedirs(prediction_path)
        
        if not os.path.exists(output_path):
            logging.info("Allocating '{:}'".format(output_path))
            os.makedirs(output_path)
        
        return init

    def train(self, data_provider, output_path, training_iters=10, epochs=100, dropout=0.75, display_step=1, restore=False, write_graph=False):
        """
        Lauches the training process
        
        :param data_provider: callable returning training and verification data
        :param output_path: path where to store checkpoints
        :param training_iters: number of training mini batch iteration
        :param epochs: number of epochs
        :param dropout: dropout probability
        :param display_step: number of steps till outputting stats
        :param restore: Flag if previous model should be restored 
        :param write_graph: Flag if the computation graph should be written as protobuf file to the output path
        """
        save_path = os.path.join(output_path, "model_2.cpkt")  ## ////..change the save path before running if you want to be in same path..////
        if epochs == 0:
            return save_path
        
        init = self._initialize(training_iters, output_path, restore)
        
        with tf.Session(config=config) as sess:
            if write_graph:
                tf.train.write_graph(sess.graph_def, output_path, "graph.pb", False)
            
            sess.run(init)
            
            if restore:
                ckpt = tf.train.get_checkpoint_state(output_path)
                if ckpt and ckpt.model_checkpoint_path:
                    self.net.restore(sess, ckpt.model_checkpoint_path)
            
            test_x, test_y = data_provider(self.verification_batch_size)
            pred_shape = self.store_prediction(sess, test_x, test_y, "_init")
            nuksaan =[]
            
            summary_writer = tf.summary.FileWriter(output_path, graph=sess.graph)
            logging.info("Start optimization")
            
            avg_gradients = None
            for epoch in range(epochs):
                total_loss = 0
                for step in range((epoch*training_iters), ((epoch+1)*training_iters)):
                    batch_x, batch_y = data_provider(self.batch_size)
                     
                    # Run optimization op (backprop)
                    _, loss, lr, gradients = sess.run((self.optimizer, self.net.cost, self.learning_rate_node, self.net.gradients_node), 
                                                      feed_dict={self.net.x: batch_x,
                                                                 self.net.y: crop_to_shape(batch_y, pred_shape),
                                                                 self.net.keep_prob: dropout})

                    if avg_gradients is None:
                        avg_gradients = [np.zeros_like(gradient) for gradient in gradients]
                    for i in range(len(gradients)):
                        avg_gradients[i] = (avg_gradients[i] * (1.0 - (1.0 / (step+1)))) + (gradients[i] / (step+1))
                        
                    norm_gradients = [np.linalg.norm(gradient) for gradient in avg_gradients]
                    self.norm_gradients_node.assign(norm_gradients).eval()
                    
                    if step % display_step == 0:
                        self.output_minibatch_stats(sess, summary_writer, step, batch_x, crop_to_shape(batch_y, pred_shape))
                        
                    total_loss += loss
                    nuksaan.append(total_loss)

                self.output_epoch_stats(epoch, total_loss, training_iters, lr)
                self.store_prediction(sess, test_x, test_y, "epoch_%s"%epoch)
                    
                save_path = self.net.save(sess, save_path)
            logging.info("Optimization Finished!")
            
            return save_path, nuksaan
        
    def store_prediction(self, sess, batch_x, batch_y, name):
        prediction = sess.run(self.net.predicter, feed_dict={self.net.x: batch_x,self.net.y: batch_y,self.net.keep_prob:1.})
        pred_shape = prediction.shape
        
        loss = sess.run(self.net.cost, feed_dict={self.net.x: batch_x, 
                                                       self.net.y: crop_to_shape(batch_y, pred_shape), 
                                                       self.net.keep_prob: 1.})
        
        logging.info("Verification error= {:.1f}%, loss= {:.4f}".format(error_rate(prediction,
                                                                          crop_to_shape(batch_y,
                                                                                             prediction.shape)),
                                                                          loss))
              
        img = combine_img_prediction(batch_x, batch_y, prediction)
        save_image(img, "%s/%s.jpg"%(self.prediction_path, name))
        
        return pred_shape
    
    def output_epoch_stats(self, epoch, total_loss, training_iters, lr):
        logging.info("Epoch {:}, Average loss: {:.4f}, learning rate: {:.4f}".format(epoch, (total_loss / training_iters), lr))
    
    def output_minibatch_stats(self, sess, summary_writer, step, batch_x, batch_y):
        # Calculate batch loss and accuracy
        summary_str, loss, acc, predictions = sess.run([self.summary_op, 
                                                            self.net.cost, 
                                                            self.net.accuracy, 
                                                            self.net.predicter], 
                                                           feed_dict={self.net.x: batch_x,
                                                                      self.net.y: batch_y,
                                                                      self.net.keep_prob: 1.})
        summary_writer.add_summary(summary_str, step)
        summary_writer.flush()
        logging.info("Iter {:}, Minibatch Loss= {:.4f}, Training Accuracy= {:.4f}, Minibatch error= {:.1f}%".format(step,
                                                                                                            loss,
                                                                                                            acc,
                                                                                                            error_rate(predictions, batch_y)))

# %%
net = Unet(channels=mydata_test.channels, n_class=mydata_test.n_class, layers=7, features_root=16)
# Out:
# 2017-07-26 11:35:07,017 Layers 7, features 16, filter size 3x3,pool size: 2x2

# %%
trainer = Trainer(net, optimizer="momentum", opt_kwargs=dict(momentum=0.2))

# %%
output_path = "./unet_trained_2"

# %%
path, nuksaan2 = trainer.train(mydata, output_path=output_path, training_iters=50, epochs=150, display_step=10)
# Out:
# 2017-07-17 18:02:51,825 Removing '/home/ctuser/Desktop/Image_Seg/prediction_model2'
# 2017-07-17 18:02:51,827 Removing '/home/ctuser/Desktop/Image_Seg/unet_trained_2'
# 2017-07-17 18:02:51,859 Allocating '/home/ctuser/Desktop/Image_Seg/prediction_model2'
# 2017-07-17 18:02:51,860 Allocating '/home/ctuser/Desktop/Image_Seg/unet_trained_2'
# 2017-07-17 18:02:52,994 Verification error= 60.9%, loss= 0.6948
# 2017-07-17 18:02:54,246 Start optimization
# 2017-07-17 18:02:55,135 Iter 0, Minibatch Loss= 0.5051, Training Accuracy= 0.9759, Minibatch error= 2.4%
# 2017-07-17 18:03:00,470 Iter 10, Minibatch Loss= 0.1054, Training Accuracy= 0.9781, Minibatch error= 2.2%
# 2017-07-17 18:03:05,825 Iter 20, Minibatch Loss= 0.1117, Training Accuracy= 0.9755, Minibatch error= 2.5%
# 2017-07-17 18:03:11,070 Iter 30, Minibatch Loss= 0.0275, Training Accuracy= 0.9961, Minibatch error= 0.4%
# 2017-07-17 18:03:16,378 Iter 40, Minibatch Loss= 0.0430, Training Accuracy= 0.9919, Minibatch error= 0.8%
# 2017-07-17 18:03:21,180 Epoch 0, Average loss: 0.1112, learning rate: 0.2000
# 2017-07-17 18:03:21,515 Verification error= 1.2%, loss= 0.0590
# 2017-07-17 18:03:26,730 Iter 50, Minibatch Loss= 0.0421, Training Accuracy= 0.9937, Minibatch error= 0.6%
# 2017-07-17 18:03:33,983 Iter 60, Minibatch Loss= 0.0327, Training Accuracy= 0.9958, Minibatch error= 0.4%
# 2017-07-17 18:03:40,533 Iter 70, Minibatch Loss= 0.0601, Training Accuracy= 0.9868, Minibatch error= 1.3%
# 2017-07-17 18:03:45,931 Iter 80, Minibatch Loss= 0.0198, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2017-07-17 18:03:51,358 Iter 90, Minibatch Loss= 0.0834, Training Accuracy= 0.9756, Minibatch error= 2.4%
# 2017-07-17 18:03:56,563 Epoch 1, Average loss: 0.0707, learning rate: 0.1900
# 2017-07-17 18:03:56,920 Verification error= 1.2%, loss= 0.0575
# 2017-07-17 18:04:02,176 Iter 100, Minibatch Loss= 0.0661, Training Accuracy= 0.9857, Minibatch error= 1.4%
# 2017-07-17 18:04:08,059 Iter 110, Minibatch Loss= 0.0684, Training Accuracy= 0.9848, Minibatch error= 1.5%
# 2017-07-17 18:04:13,897 Iter 120, Minibatch Loss= 0.0935, Training Accuracy= 0.9766, Minibatch error= 2.3%
# 2017-07-17 18:04:19,536 Iter 130, Minibatch Loss= 0.0907, Training Accuracy= 0.9765, Minibatch error= 2.3%
# 2017-07-17 18:04:25,100 Iter 140, Minibatch Loss= 0.0560, Training Accuracy= 0.9896, Minibatch error= 1.0%
# 2017-07-17 18:04:30,090 Epoch 2, Average loss: 0.0699, learning rate: 0.1805
# 2017-07-17 18:04:30,414 Verification error= 1.2%, loss= 0.0565
# 2017-07-17 18:04:35,977 Iter 150, Minibatch Loss= 0.0649, Training Accuracy= 0.9804, Minibatch error= 2.0%
# 2017-07-17 18:04:42,453 Iter 160, Minibatch Loss= 0.0361, Training Accuracy= 0.9954, Minibatch error= 0.5%
# 2017-07-17 18:04:48,395 Iter 170, Minibatch Loss= 0.0825, Training Accuracy= 0.9829, Minibatch error= 1.7%
# 2017-07-17 18:04:54,177 Iter 180, Minibatch Loss= 0.0505, Training Accuracy= 0.9872, Minibatch error= 1.3%
# 2017-07-17 18:05:00,170 Iter 190, Minibatch Loss= 0.0676, Training Accuracy= 0.9841, Minibatch error= 1.6%
# 2017-07-17 18:05:05,678 Epoch 3, Average loss: 0.0683, learning rate: 0.1715
# 2017-07-17 18:05:06,020 Verification error= 1.2%, loss= 0.0563
# 2017-07-17 18:05:09,698 Iter 200, Minibatch Loss= 0.0856, Training Accuracy= 0.9765, Minibatch error= 2.3%
# 2017-07-17 18:05:16,201 Iter 210, Minibatch Loss= 0.0702, Training Accuracy= 0.9848, Minibatch error= 1.5%
# 2017-07-17 18:05:22,158 Iter 220, Minibatch Loss= 0.0821, Training Accuracy= 0.9766, Minibatch error= 2.3%
# 2017-07-17 18:05:28,058 Iter 230, Minibatch Loss= 0.0351, Training Accuracy= 0.9945, Minibatch error= 0.5%
# 2017-07-17 18:05:33,991 Iter 240, Minibatch Loss= 0.0579, Training Accuracy= 0.9863, Minibatch error= 1.4%
# 2017-07-17 18:05:39,288 Epoch 4, Average loss: 0.0670, learning rate: 0.1629
# 2017-07-17 18:05:39,609 Verification error= 1.2%, loss= 0.0552
# 2017-07-17 18:05:44,818 Iter 250, Minibatch Loss= 0.0319, Training Accuracy= 0.9955, Minibatch error= 0.4%
# 2017-07-17 18:05:51,670 Iter 260, Minibatch Loss= 0.0575, Training Accuracy= 0.9849, Minibatch error= 1.5%
# 2017-07-17 18:05:57,931 Iter 270, Minibatch Loss= 0.0344, Training Accuracy= 0.9939, Minibatch error= 0.6%
# 2017-07-17 18:06:04,125 Iter 280, Minibatch Loss= 0.0582, Training Accuracy= 0.9812, Minibatch error= 1.9%
# 2017-07-17 18:06:10,411 Iter 290, Minibatch Loss= 0.0435, Training Accuracy= 0.9783, Minibatch error= 2.2%
# 2017-07-17 18:06:16,101 Epoch 5, Average loss: 0.0564, learning rate: 0.1548
# 2017-07-17 18:06:16,428 Verification error= 1.2%, loss= 0.0306
# 2017-07-17 18:06:21,553 Iter 300, Minibatch Loss= 0.0451, Training Accuracy= 0.9784, Minibatch error= 2.2%
# 2017-07-17 18:06:28,043 Iter 310, Minibatch Loss= 0.0314, Training Accuracy= 0.9843, Minibatch error= 1.6%
# 2017-07-17 18:06:34,979 Iter 320, Minibatch Loss= 0.0438, Training Accuracy= 0.9755, Minibatch error= 2.4%
# 2017-07-17 18:06:42,375 Iter 330, Minibatch Loss= 0.0096, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2017-07-17 18:06:49,437 Iter 340, Minibatch Loss= 0.0252, Training Accuracy= 0.9855, Minibatch error= 1.5%
# 2017-07-17 18:06:55,230 Epoch 6, Average loss: 0.0360, learning rate: 0.1470
# 2017-07-17 18:06:55,558 Verification error= 1.2%, loss= 0.0227
# 2017-07-17 18:07:00,695 Iter 350, Minibatch Loss= 0.0087, Training Accuracy= 0.9956, Minibatch error= 0.4%
# 2017-07-17 18:07:08,949 Iter 360, Minibatch Loss= 0.0235, Training Accuracy= 0.9852, Minibatch error= 1.5%
# 2017-07-17 18:07:15,605 Iter 370, Minibatch Loss= 0.0225, Training Accuracy= 0.9858, Minibatch error= 1.4%
# 2017-07-17 18:07:22,457 Iter 380, Minibatch Loss= 0.0130, Training Accuracy= 0.9945, Minibatch error= 0.6%
# 2017-07-17 18:07:29,662 Iter 390, Minibatch Loss= 0.0271, Training Accuracy= 0.9779, Minibatch error= 2.2%
# 2017-07-17 18:07:35,566 Epoch 7, Average loss: 0.0293, learning rate: 0.1397
# 2017-07-17 18:07:35,899 Verification error= 1.2%, loss= 0.0184
# 2017-07-17 18:07:41,320 Iter 400, Minibatch Loss= 0.0342, Training Accuracy= 0.9759, Minibatch error= 2.4%
# 2017-07-17 18:07:48,192 Iter 410, Minibatch Loss= 0.0238, Training Accuracy= 0.9852, Minibatch error= 1.5%
# 2017-07-17 18:07:54,637 Iter 420, Minibatch Loss= 0.0188, Training Accuracy= 0.9880, Minibatch error= 1.2%
# 2017-07-17 18:08:01,210 Iter 430, Minibatch Loss= 0.0218, Training Accuracy= 0.9857, Minibatch error= 1.4%
# 2017-07-17 18:08:07,695 Iter 440, Minibatch Loss= 0.0188, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2017-07-17 18:08:13,536 Epoch 8, Average loss: 0.0255, learning rate: 0.1327
# 2017-07-17 18:08:13,864 Verification error= 1.2%, loss= 0.0168
# 2017-07-17 18:08:19,369 Iter 450, Minibatch Loss= 0.0252, Training Accuracy= 0.9775, Minibatch error= 2.2%
# 2017-07-17 18:08:26,243 Iter 460, Minibatch Loss= 0.0224, Training Accuracy= 0.9840, Minibatch error= 1.6%
# 2017-07-17 18:08:33,143 Iter 470, Minibatch Loss= 0.0200, Training Accuracy= 0.9854, Minibatch error= 1.5%
# 2017-07-17 18:08:39,937 Iter 480, Minibatch Loss= 0.0297, Training Accuracy= 0.9767, Minibatch error= 2.3%
# 2017-07-17 18:08:46,706 Iter 490, Minibatch Loss= 0.0239, Training Accuracy= 0.9773, Minibatch error= 2.3%
# 2017-07-17 18:08:52,762 Epoch 9, Average loss: 0.0244, learning rate: 0.1260
# 2017-07-17 18:08:53,092 Verification error= 1.2%, loss= 0.0156
# 2017-07-17 18:08:58,141 Iter 500, Minibatch Loss= 0.0201, Training Accuracy= 0.9848, Minibatch error= 1.5%
# 2017-07-17 18:09:05,621 Iter 510, Minibatch Loss= 0.0203, Training Accuracy= 0.9835, Minibatch error= 1.7%
# 2017-07-17 18:09:12,479 Iter 520, Minibatch Loss= 0.0179, Training Accuracy= 0.9899, Minibatch error= 1.0%
# 2017-07-17 18:09:19,403 Iter 530, Minibatch Loss= 0.0153, Training Accuracy= 1.0000, Minibatch error= 0.0%
# 2017-07-17 18:09:26,321 Iter 540, Minibatch Loss= 0.0157, Training Accuracy= 0.9871, Minibatch error= 1.3%
# 2017-07-17 18:09:32,813 Epoch 10, Average loss: 0.0198, learning rate: 0.1197
# 2017-07-17 18:09:33,143 Verification error= 1.2%, loss= 0.0138
# 2017-07-17 18:09:41,705 Iter 550, Minibatch Loss= 0.0224, Training Accuracy= 0.9776, Minibatch error= 2.2%
# 2017-07-17 18:09:50,133 Iter 560, Minibatch Loss= 0.0200, Training Accuracy= 0.9850, Minibatch error= 1.5%
# 2017-07-17 18:09:57,246 Iter 570, Minibatch Loss= 0.0222, Training Accuracy= 0.9773, Minibatch error= 2.3%
# 2017-07-17 18:10:04,384 Iter 580, Minibatch Loss= 0.0199, Training Accuracy= 0.9829, Minibatch error= 1.7%
# 2017-07-17 18:10:11,319 Iter 590, Minibatch Loss= 0.0122, Training Accuracy= 0.9869, Minibatch error= 1.3%
# 2017-07-17 18:10:17,432 Epoch 11, Average loss: 0.0197, learning rate: 0.1138
# 2017-07-17 18:10:17,761 Verification error= 1.0%, loss= 0.0133
# 2017-07-17 18:10:24,495 Iter 600, Minibatch Loss= 0.0164, Training Accuracy= 0.9867, Minibatch error= 1.3%
# 2017-07-17 18:10:32,111 Iter 610, Minibatch Loss= 0.0144, Training Accuracy= 0.9956, Minibatch error= 0.4%
# 2017-07-17 18:10:39,340 Iter 620, Minibatch Loss= 0.0193, Training Accuracy= 0.9942, Minibatch error= 0.6%
# 2017-07-17 18:10:46,540 Iter 630, Minibatch Loss= 0.0292, Training Accuracy= 0.9932, Minibatch error= 0.7%
# 2017-07-17 18:10:54,155 Iter 640, Minibatch Loss= 0.0166, Training Accuracy= 0.9969, Minibatch error= 0.3%
# 2017-07-17 18:11:00,670 Epoch 12, Average loss: 0.0183, learning rate: 0.1081
# 2017-07-17 18:11:00,999 Verification error= 0.3%, loss= 0.0137
# 2017-07-17 18:11:07,302 Iter 650, Minibatch Loss= 0.0198, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-17 18:11:15,147 Iter 660, Minibatch Loss= 0.0167, Training Accuracy= 0.9970, Minibatch error= 0.3%
# 2017-07-17 18:11:22,536 Iter 670, Minibatch Loss= 0.0124, Training Accuracy= 0.9985, Minibatch error= 0.1%
# 2017-07-17 18:11:30,033 Iter 680, Minibatch Loss= 0.0204, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2017-07-17 18:11:37,364 Iter 690, Minibatch Loss= 0.0130, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-17 18:11:44,833 Epoch 13, Average loss: 0.0150, learning rate: 0.1027
# 2017-07-17 18:11:45,159 Verification error= 0.2%, loss= 0.0097
# 2017-07-17 18:11:54,196 Iter 700, Minibatch Loss= 0.0088, Training Accuracy= 0.9950, Minibatch error= 0.5%
# 2017-07-17 18:12:02,254 Iter 710, Minibatch Loss= 0.0078, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2017-07-17 18:12:10,013 Iter 720, Minibatch Loss= 0.0071, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-17 18:12:23,148 Iter 730, Minibatch Loss= 0.0159, Training Accuracy= 0.9903, Minibatch error= 1.0%
# 2017-07-17 18:12:32,578 Iter 740, Minibatch Loss= 0.0121, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-17 18:12:39,951 Epoch 14, Average loss: 0.0151, learning rate: 0.0975
# 2017-07-17 18:12:40,286 Verification error= 0.2%, loss= 0.0107
# 2017-07-17 18:12:46,360 Iter 750, Minibatch Loss= 0.0220, Training Accuracy= 0.9913, Minibatch error= 0.9%
# 2017-07-17 18:12:54,803 Iter 760, Minibatch Loss= 0.0172, Training Accuracy= 0.9966, Minibatch error= 0.3%
# 2017-07-17 18:13:02,636 Iter 770, Minibatch Loss= 0.0114, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2017-07-17 18:13:10,306 Iter 780, Minibatch Loss= 0.0108, Training Accuracy= 0.9974, Minibatch error= 0.3%
# 2017-07-17 18:13:17,986 Iter 790, Minibatch Loss= 0.0087, Training Accuracy= 0.9979, Minibatch error= 0.2%
# 2017-07-17 18:13:25,148 Epoch 15, Average loss: 0.0134, learning rate: 0.0927
# 2017-07-17 18:13:25,465 Verification error= 0.5%, loss= 0.0142
# 2017-07-17 18:13:33,109 Iter 800, Minibatch Loss= 0.0113, Training Accuracy= 0.9979, Minibatch error= 0.2%
# 2017-07-17 18:13:44,856 Iter 810, Minibatch Loss= 0.0238, Training Accuracy= 0.9924, Minibatch error= 0.8%
# 2017-07-17 18:13:53,381 Iter 820, Minibatch Loss= 0.0096, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2017-07-17 18:14:01,240 Iter 830, Minibatch Loss= 0.0046, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-17 18:14:09,072 Iter 840, Minibatch Loss= 0.0148, Training Accuracy= 0.9948, Minibatch error= 0.5%
# 2017-07-17 18:14:16,325 Epoch 16, Average loss: 0.0120, learning rate: 0.0880
# 2017-07-17 18:14:16,645 Verification error= 0.2%, loss= 0.0078
# 2017-07-17 18:14:22,678 Iter 850, Minibatch Loss= 0.0131, Training Accuracy= 0.9982, Minibatch error= 0.2%
# 2017-07-17 18:14:33,237 Iter 860, Minibatch Loss= 0.0064, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-17 18:14:42,651 Iter 870, Minibatch Loss= 0.0217, Training Accuracy= 0.9850, Minibatch error= 1.5%
# 2017-07-17 18:14:52,593 Iter 880, Minibatch Loss= 0.0811, Training Accuracy= 0.9859, Minibatch error= 1.4%
# 2017-07-17 18:15:01,814 Iter 890, Minibatch Loss= 0.0930, Training Accuracy= 0.9770, Minibatch error= 2.3%
# 2017-07-17 18:15:09,888 Epoch 17, Average loss: 0.0562, learning rate: 0.0836
# 2017-07-17 18:15:10,209 Verification error= 0.6%, loss= 0.0151
# 2017-07-17 18:15:19,184 Iter 900, Minibatch Loss= 0.0177, Training Accuracy= 0.9924, Minibatch error= 0.8%
# 2017-07-17 18:15:28,311 Iter 910, Minibatch Loss= 0.0123, Training Accuracy= 0.9962, Minibatch error= 0.4%
# 2017-07-17 18:15:37,125 Iter 920, Minibatch Loss= 0.0167, Training Accuracy= 0.9982, Minibatch error= 0.2%
# 2017-07-17 18:15:45,287 Iter 930, Minibatch Loss= 0.0074, Training Accuracy= 0.9984, Minibatch error= 0.2%
# 2017-07-17 18:15:53,435 Iter 940, Minibatch Loss= 0.0081, Training Accuracy= 0.9968, Minibatch error= 0.3%
# 2017-07-17 18:16:00,930 Epoch 18, Average loss: 0.0171, learning rate: 0.0794
# 2017-07-17 18:16:01,248 Verification error= 0.2%, loss= 0.0093
# 2017-07-17 18:16:06,230 Iter 950, Minibatch Loss= 0.0190, Training Accuracy= 0.9941, Minibatch error= 0.6%
# 2017-07-17 18:16:15,273 Iter 960, Minibatch Loss= 0.0086, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 18:16:23,731 Iter 970, Minibatch Loss= 0.0080, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-17 18:16:32,096 Iter 980, Minibatch Loss= 0.0081, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-17 18:16:40,369 Iter 990, Minibatch Loss= 0.0134, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-17 18:16:47,887 Epoch 19, Average loss: 0.0127, learning rate: 0.0755
# 2017-07-17 18:16:48,205 Verification error= 0.2%, loss= 0.0092
# 2017-07-17 18:16:53,733 Iter 1000, Minibatch Loss= 0.0128, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-17 18:17:03,406 Iter 1010, Minibatch Loss= 0.0162, Training Accuracy= 0.9959, Minibatch error= 0.4%
# 2017-07-17 18:17:12,564 Iter 1020, Minibatch Loss= 0.0065, Training Accuracy= 0.9969, Minibatch error= 0.3%
# 2017-07-17 18:17:21,330 Iter 1030, Minibatch Loss= 0.0068, Training Accuracy= 0.9997, Minibatch error= 0.0%
# 2017-07-17 18:17:30,119 Iter 1040, Minibatch Loss= 0.0046, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2017-07-17 18:17:37,911 Epoch 20, Average loss: 0.0123, learning rate: 0.0717
# 2017-07-17 18:17:38,230 Verification error= 0.2%, loss= 0.0074
# 2017-07-17 18:17:45,014 Iter 1050, Minibatch Loss= 0.0023, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-17 18:17:54,147 Iter 1060, Minibatch Loss= 0.0067, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-17 18:18:03,499 Iter 1070, Minibatch Loss= 0.0066, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-17 18:18:12,241 Iter 1080, Minibatch Loss= 0.0105, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-17 18:18:20,895 Iter 1090, Minibatch Loss= 0.0126, Training Accuracy= 0.9976, Minibatch error= 0.2%
# 2017-07-17 18:18:29,116 Epoch 21, Average loss: 0.0097, learning rate: 0.0681
# 2017-07-17 18:18:29,435 Verification error= 0.2%, loss= 0.0071
# 2017-07-17 18:18:35,604 Iter 1100, Minibatch Loss= 0.0066, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-17 18:18:44,510 Iter 1110, Minibatch Loss= 0.0053, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-17 18:18:54,433 Iter 1120, Minibatch Loss= 0.0084, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-17 18:19:04,071 Iter 1130, Minibatch Loss= 0.0096, Training Accuracy= 0.9953, Minibatch error= 0.5%
# 2017-07-17 18:19:12,993 Iter 1140, Minibatch Loss= 0.0156, Training Accuracy= 0.9954, Minibatch error= 0.5%
# 2017-07-17 18:19:21,148 Epoch 22, Average loss: 0.0191, learning rate: 0.0647
# 2017-07-17 18:19:21,487 Verification error= 0.2%, loss= 0.0073
# 2017-07-17 18:19:28,777 Iter 1150, Minibatch Loss= 0.0073, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-17 18:19:38,240 Iter 1160, Minibatch Loss= 0.0064, Training Accuracy= 0.9979, Minibatch error= 0.2%
# 2017-07-17 18:19:47,501 Iter 1170, Minibatch Loss= 0.0070, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2017-07-17 18:19:56,781 Iter 1180, Minibatch Loss= 0.0080, Training Accuracy= 0.9978, Minibatch error= 0.2%
# 2017-07-17 18:20:06,452 Iter 1190, Minibatch Loss= 0.0167, Training Accuracy= 0.9936, Minibatch error= 0.6%
# 2017-07-17 18:20:14,583 Epoch 23, Average loss: 0.0098, learning rate: 0.0615
# 2017-07-17 18:20:14,906 Verification error= 0.2%, loss= 0.0075
# 2017-07-17 18:20:21,662 Iter 1200, Minibatch Loss= 0.0100, Training Accuracy= 0.9966, Minibatch error= 0.3%
# 2017-07-17 18:20:31,466 Iter 1210, Minibatch Loss= 0.0097, Training Accuracy= 0.9985, Minibatch error= 0.2%
# 2017-07-17 18:20:40,840 Iter 1220, Minibatch Loss= 0.0087, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-17 18:20:50,342 Iter 1230, Minibatch Loss= 0.0061, Training Accuracy= 0.9977, Minibatch error= 0.2%
# 2017-07-17 18:20:59,560 Iter 1240, Minibatch Loss= 0.0076, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-17 18:21:07,955 Epoch 24, Average loss: 0.0097, learning rate: 0.0584
# 2017-07-17 18:21:08,300 Verification error= 0.2%, loss= 0.0066
# 2017-07-17 18:21:15,022 Iter 1250, Minibatch Loss= 0.0076, Training Accuracy= 0.9976, Minibatch error= 0.2%
# 2017-07-17 18:21:24,971 Iter 1260, Minibatch Loss= 0.0059, Training Accuracy= 0.9997, Minibatch error= 0.0%
# 2017-07-17 18:21:34,406 Iter 1270, Minibatch Loss= 0.0129, Training Accuracy= 0.9955, Minibatch error= 0.4%
# 2017-07-17 18:21:44,251 Iter 1280, Minibatch Loss= 0.0133, Training Accuracy= 0.9959, Minibatch error= 0.4%
# 2017-07-17 18:21:53,818 Iter 1290, Minibatch Loss= 0.0039, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-17 18:22:03,672 Epoch 25, Average loss: 0.0130, learning rate: 0.0555
# 2017-07-17 18:22:04,007 Verification error= 0.4%, loss= 0.0115
# 2017-07-17 18:22:11,605 Iter 1300, Minibatch Loss= 0.0099, Training Accuracy= 0.9965, Minibatch error= 0.4%
# 2017-07-17 18:22:23,757 Iter 1310, Minibatch Loss= 0.0081, Training Accuracy= 0.9976, Minibatch error= 0.2%
# 2017-07-17 18:22:33,313 Iter 1320, Minibatch Loss= 0.0117, Training Accuracy= 0.9959, Minibatch error= 0.4%
# 2017-07-17 18:22:42,750 Iter 1330, Minibatch Loss= 0.0116, Training Accuracy= 0.9950, Minibatch error= 0.5%
# 2017-07-17 18:22:52,652 Iter 1340, Minibatch Loss= 0.0053, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-17 18:23:00,946 Epoch 26, Average loss: 0.0112, learning rate: 0.0527
# 2017-07-17 18:23:01,273 Verification error= 0.2%, loss= 0.0068
# 2017-07-17 18:23:08,503 Iter 1350, Minibatch Loss= 0.0048, Training Accuracy= 0.9995, Minibatch error= 0.0%
# 2017-07-17 18:23:18,652 Iter 1360, Minibatch Loss= 0.0167, Training Accuracy= 0.9936, Minibatch error= 0.6%
# 2017-07-17 18:23:28,480 Iter 1370, Minibatch Loss= 0.0118, Training Accuracy= 0.9963, Minibatch error= 0.4%
# 2017-07-17 18:23:38,382 Iter 1380, Minibatch Loss= 0.0051, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2017-07-17 18:23:48,046 Iter 1390, Minibatch Loss= 0.0097, Training Accuracy= 0.9966, Minibatch error= 0.3%
# 2017-07-17 18:23:56,945 Epoch 27, Average loss: 0.0082, learning rate: 0.0501
# 2017-07-17 18:23:57,274 Verification error= 0.2%, loss= 0.0064
# 2017-07-17 18:24:03,711 Iter 1400, Minibatch Loss= 0.0026, Training Accuracy= 0.9997, Minibatch error= 0.0%
# 2017-07-17 18:24:14,208 Iter 1410, Minibatch Loss= 0.0059, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-17 18:24:24,203 Iter 1420, Minibatch Loss= 0.0073, Training Accuracy= 0.9968, Minibatch error= 0.3%
# 2017-07-17 18:24:34,112 Iter 1430, Minibatch Loss= 0.0074, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-17 18:24:43,846 Iter 1440, Minibatch Loss= 0.0105, Training Accuracy= 0.9959, Minibatch error= 0.4%
# 2017-07-17 18:24:52,571 Epoch 28, Average loss: 0.0086, learning rate: 0.0476
# 2017-07-17 18:24:52,897 Verification error= 0.2%, loss= 0.0064
# 2017-07-17 18:24:59,996 Iter 1450, Minibatch Loss= 0.0019, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2017-07-17 18:25:10,826 Iter 1460, Minibatch Loss= 0.0054, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-17 18:25:21,085 Iter 1470, Minibatch Loss= 0.0061, Training Accuracy= 0.9979, Minibatch error= 0.2%
# 2017-07-17 18:25:31,346 Iter 1480, Minibatch Loss= 0.0056, Training Accuracy= 0.9974, Minibatch error= 0.3%
# 2017-07-17 18:25:42,072 Iter 1490, Minibatch Loss= 0.0068, Training Accuracy= 0.9976, Minibatch error= 0.2%
# 2017-07-17 18:25:51,093 Epoch 29, Average loss: 0.0075, learning rate: 0.0452
# 2017-07-17 18:25:51,419 Verification error= 0.2%, loss= 0.0058
# 2017-07-17 18:25:58,525 Iter 1500, Minibatch Loss= 0.0088, Training Accuracy= 0.9966, Minibatch error= 0.3%
# 2017-07-17 18:26:09,038 Iter 1510, Minibatch Loss= 0.0081, Training Accuracy= 0.9978, Minibatch error= 0.2%
# 2017-07-17 18:26:19,344 Iter 1520, Minibatch Loss= 0.0090, Training Accuracy= 0.9952, Minibatch error= 0.5%
# 2017-07-17 18:26:29,833 Iter 1530, Minibatch Loss= 0.0044, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-17 18:26:40,588 Iter 1540, Minibatch Loss= 0.0054, Training Accuracy= 0.9979, Minibatch error= 0.2%
# 2017-07-17 18:26:49,831 Epoch 30, Average loss: 0.0095, learning rate: 0.0429
# 2017-07-17 18:26:50,158 Verification error= 0.2%, loss= 0.0055
# 2017-07-17 18:26:58,458 Iter 1550, Minibatch Loss= 0.0036, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2017-07-17 18:27:12,466 Iter 1560, Minibatch Loss= 0.0061, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-17 18:27:22,823 Iter 1570, Minibatch Loss= 0.0147, Training Accuracy= 0.9946, Minibatch error= 0.5%
# 2017-07-17 18:27:33,267 Iter 1580, Minibatch Loss= 0.0102, Training Accuracy= 0.9958, Minibatch error= 0.4%
# 2017-07-17 18:27:44,076 Iter 1590, Minibatch Loss= 0.0113, Training Accuracy= 0.9967, Minibatch error= 0.3%
# 2017-07-17 18:27:53,466 Epoch 31, Average loss: 0.0094, learning rate: 0.0408
# 2017-07-17 18:27:53,795 Verification error= 0.2%, loss= 0.0064
# 2017-07-17 18:28:02,428 Iter 1600, Minibatch Loss= 0.0038, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2017-07-17 18:28:14,168 Iter 1610, Minibatch Loss= 0.0031, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-17 18:28:24,690 Iter 1620, Minibatch Loss= 0.0026, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-17 18:28:35,293 Iter 1630, Minibatch Loss= 0.0061, Training Accuracy= 0.9972, Minibatch error= 0.3%
# 2017-07-17 18:28:46,308 Iter 1640, Minibatch Loss= 0.0102, Training Accuracy= 0.9968, Minibatch error= 0.3%
# 2017-07-17 18:28:55,867 Epoch 32, Average loss: 0.0083, learning rate: 0.0387
# 2017-07-17 18:28:56,194 Verification error= 0.3%, loss= 0.0067
# 2017-07-17 18:29:04,036 Iter 1650, Minibatch Loss= 0.0074, Training Accuracy= 0.9979, Minibatch error= 0.2%
# 2017-07-17 18:29:14,901 Iter 1660, Minibatch Loss= 0.0113, Training Accuracy= 0.9942, Minibatch error= 0.6%
# 2017-07-17 18:29:25,536 Iter 1670, Minibatch Loss= 0.0083, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2017-07-17 18:29:36,062 Iter 1680, Minibatch Loss= 0.0052, Training Accuracy= 0.9977, Minibatch error= 0.2%
# 2017-07-17 18:29:46,596 Iter 1690, Minibatch Loss= 0.0067, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2017-07-17 18:29:56,348 Epoch 33, Average loss: 0.0082, learning rate: 0.0368
# 2017-07-17 18:29:56,672 Verification error= 0.2%, loss= 0.0058
# 2017-07-17 18:30:04,591 Iter 1700, Minibatch Loss= 0.0035, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-17 18:30:17,747 Iter 1710, Minibatch Loss= 0.0115, Training Accuracy= 0.9945, Minibatch error= 0.6%
# 2017-07-17 18:30:28,604 Iter 1720, Minibatch Loss= 0.0069, Training Accuracy= 0.9979, Minibatch error= 0.2%
# 2017-07-17 18:30:39,609 Iter 1730, Minibatch Loss= 0.0062, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-17 18:30:50,157 Iter 1740, Minibatch Loss= 0.0018, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-17 18:30:59,727 Epoch 34, Average loss: 0.0088, learning rate: 0.0350
# 2017-07-17 18:31:00,050 Verification error= 0.2%, loss= 0.0057
# 2017-07-17 18:31:07,450 Iter 1750, Minibatch Loss= 0.0041, Training Accuracy= 0.9995, Minibatch error= 0.0%
# 2017-07-17 18:31:19,289 Iter 1760, Minibatch Loss= 0.0039, Training Accuracy= 0.9984, Minibatch error= 0.2%
# 2017-07-17 18:31:34,278 Iter 1770, Minibatch Loss= 0.0036, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-17 18:31:45,422 Iter 1780, Minibatch Loss= 0.0069, Training Accuracy= 0.9976, Minibatch error= 0.2%
# 2017-07-17 18:31:57,060 Iter 1790, Minibatch Loss= 0.0031, Training Accuracy= 0.9997, Minibatch error= 0.0%
# 2017-07-17 18:32:06,900 Epoch 35, Average loss: 0.0092, learning rate: 0.0332
# 2017-07-17 18:32:07,225 Verification error= 0.2%, loss= 0.0060
# 2017-07-17 18:32:15,247 Iter 1800, Minibatch Loss= 0.0105, Training Accuracy= 0.9963, Minibatch error= 0.4%
# 2017-07-17 18:32:26,333 Iter 1810, Minibatch Loss= 0.0055, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-17 18:32:37,409 Iter 1820, Minibatch Loss= 0.0085, Training Accuracy= 0.9964, Minibatch error= 0.4%
# 2017-07-17 18:32:48,880 Iter 1830, Minibatch Loss= 0.0092, Training Accuracy= 0.9959, Minibatch error= 0.4%
# 2017-07-17 18:32:59,908 Iter 1840, Minibatch Loss= 0.0050, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-17 18:33:09,936 Epoch 36, Average loss: 0.0077, learning rate: 0.0316
# 2017-07-17 18:33:10,259 Verification error= 0.2%, loss= 0.0058
# 2017-07-17 18:33:18,271 Iter 1850, Minibatch Loss= 0.0098, Training Accuracy= 0.9967, Minibatch error= 0.3%
# 2017-07-17 18:33:29,564 Iter 1860, Minibatch Loss= 0.0104, Training Accuracy= 0.9956, Minibatch error= 0.4%
# 2017-07-17 18:33:41,049 Iter 1870, Minibatch Loss= 0.0033, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2017-07-17 18:33:52,420 Iter 1880, Minibatch Loss= 0.0030, Training Accuracy= 0.9997, Minibatch error= 0.0%
# 2017-07-17 18:34:04,305 Iter 1890, Minibatch Loss= 0.0060, Training Accuracy= 0.9977, Minibatch error= 0.2%
# 2017-07-17 18:34:14,821 Epoch 37, Average loss: 0.0087, learning rate: 0.0300
# 2017-07-17 18:34:15,138 Verification error= 0.2%, loss= 0.0071
# 2017-07-17 18:34:22,917 Iter 1900, Minibatch Loss= 0.0099, Training Accuracy= 0.9967, Minibatch error= 0.3%
# 2017-07-17 18:34:34,559 Iter 1910, Minibatch Loss= 0.0074, Training Accuracy= 0.9975, Minibatch error= 0.3%
# 2017-07-17 18:34:45,759 Iter 1920, Minibatch Loss= 0.0034, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-17 18:34:57,021 Iter 1930, Minibatch Loss= 0.0130, Training Accuracy= 0.9940, Minibatch error= 0.6%
# 2017-07-17 18:35:08,436 Iter 1940, Minibatch Loss= 0.0032, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-17 18:35:18,473 Epoch 38, Average loss: 0.0082, learning rate: 0.0285
# 2017-07-17 18:35:18,790 Verification error= 0.2%, loss= 0.0055
# 2017-07-17 18:35:27,387 Iter 1950, Minibatch Loss= 0.0363, Training Accuracy= 0.9823, Minibatch error= 1.8%
# 2017-07-17 18:35:38,995 Iter 1960, Minibatch Loss= 0.0028, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-17 18:35:50,400 Iter 1970, Minibatch Loss= 0.0034, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2017-07-17 18:36:01,834 Iter 1980, Minibatch Loss= 0.0063, Training Accuracy= 0.9977, Minibatch error= 0.2%
# 2017-07-17 18:36:13,457 Iter 1990, Minibatch Loss= 0.0043, Training Accuracy= 0.9982, Minibatch error= 0.2%
# 2017-07-17 18:36:24,116 Epoch 39, Average loss: 0.0088, learning rate: 0.0271
# 2017-07-17 18:36:24,434 Verification error= 0.2%, loss= 0.0058
# 2017-07-17 18:36:32,532 Iter 2000, Minibatch Loss= 0.0112, Training Accuracy= 0.9960, Minibatch error= 0.4%
# 2017-07-17 18:36:44,397 Iter 2010, Minibatch Loss= 0.0020, Training Accuracy= 0.9995, Minibatch error= 0.0%
# 2017-07-17 18:36:56,458 Iter 2020, Minibatch Loss= 0.0088, Training Accuracy= 0.9968, Minibatch error= 0.3%
# 2017-07-17 18:37:08,768 Iter 2030, Minibatch Loss= 0.0090, Training Accuracy= 0.9967, Minibatch error= 0.3%
# 2017-07-17 18:37:20,263 Iter 2040, Minibatch Loss= 0.0033, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-17 18:37:31,530 Epoch 40, Average loss: 0.0066, learning rate: 0.0257
# 2017-07-17 18:37:31,844 Verification error= 0.2%, loss= 0.0056
# 2017-07-17 18:37:39,583 Iter 2050, Minibatch Loss= 0.0050, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-17 18:37:51,398 Iter 2060, Minibatch Loss= 0.0046, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2017-07-17 18:38:03,008 Iter 2070, Minibatch Loss= 0.0041, Training Accuracy= 0.9985, Minibatch error= 0.2%
# 2017-07-17 18:38:14,704 Iter 2080, Minibatch Loss= 0.0010, Training Accuracy= 0.9998, Minibatch error= 0.0%
# 2017-07-17 18:38:26,709 Iter 2090, Minibatch Loss= 0.0061, Training Accuracy= 0.9979, Minibatch error= 0.2%
# 2017-07-17 18:38:37,326 Epoch 41, Average loss: 0.0090, learning rate: 0.0244
# 2017-07-17 18:38:37,644 Verification error= 0.2%, loss= 0.0059
# 2017-07-17 18:38:46,067 Iter 2100, Minibatch Loss= 0.0049, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-17 18:38:57,995 Iter 2110, Minibatch Loss= 0.0029, Training Accuracy= 0.9997, Minibatch error= 0.0%
# 2017-07-17 18:39:10,646 Iter 2120, Minibatch Loss= 0.0080, Training Accuracy= 0.9965, Minibatch error= 0.3%
# 2017-07-17 18:39:22,515 Iter 2130, Minibatch Loss= 0.0033, Training Accuracy= 0.9995, Minibatch error= 0.0%
# 2017-07-17 18:39:34,480 Iter 2140, Minibatch Loss= 0.0084, Training Accuracy= 0.9962, Minibatch error= 0.4%
# 2017-07-17 18:39:45,050 Epoch 42, Average loss: 0.0087, learning rate: 0.0232
# 2017-07-17 18:39:45,368 Verification error= 0.2%, loss= 0.0052
# 2017-07-17 18:39:53,864 Iter 2150, Minibatch Loss= 0.0093, Training Accuracy= 0.9957, Minibatch error= 0.4%
# 2017-07-17 18:40:06,149 Iter 2160, Minibatch Loss= 0.0051, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-17 18:40:18,090 Iter 2170, Minibatch Loss= 0.0109, Training Accuracy= 0.9948, Minibatch error= 0.5%
# 2017-07-17 18:40:30,092 Iter 2180, Minibatch Loss= 0.0072, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-17 18:40:42,163 Iter 2190, Minibatch Loss= 0.0033, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-17 18:40:53,113 Epoch 43, Average loss: 0.0087, learning rate: 0.0220
# 2017-07-17 18:40:53,433 Verification error= 0.2%, loss= 0.0058
# 2017-07-17 18:41:01,551 Iter 2200, Minibatch Loss= 0.0033, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 18:41:14,025 Iter 2210, Minibatch Loss= 0.0036, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-17 18:41:26,309 Iter 2220, Minibatch Loss= 0.0044, Training Accuracy= 0.9984, Minibatch error= 0.2%
# 2017-07-17 18:41:38,733 Iter 2230, Minibatch Loss= 0.0381, Training Accuracy= 0.9815, Minibatch error= 1.9%
# 2017-07-17 18:41:51,213 Iter 2240, Minibatch Loss= 0.0089, Training Accuracy= 0.9960, Minibatch error= 0.4%
# 2017-07-17 18:42:02,496 Epoch 44, Average loss: 0.0087, learning rate: 0.0209
# 2017-07-17 18:42:02,811 Verification error= 0.2%, loss= 0.0056
# 2017-07-17 18:42:10,531 Iter 2250, Minibatch Loss= 0.0035, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-17 18:42:23,153 Iter 2260, Minibatch Loss= 0.0095, Training Accuracy= 0.9964, Minibatch error= 0.4%
# 2017-07-17 18:42:35,932 Iter 2270, Minibatch Loss= 0.0054, Training Accuracy= 0.9982, Minibatch error= 0.2%
# 2017-07-17 18:42:48,262 Iter 2280, Minibatch Loss= 0.0072, Training Accuracy= 0.9971, Minibatch error= 0.3%
# 2017-07-17 18:43:00,697 Iter 2290, Minibatch Loss= 0.0027, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 18:43:12,383 Epoch 45, Average loss: 0.0058, learning rate: 0.0199
# 2017-07-17 18:43:12,700 Verification error= 0.2%, loss= 0.0056
# 2017-07-17 18:43:20,413 Iter 2300, Minibatch Loss= 0.0038, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-17 18:43:35,064 Iter 2310, Minibatch Loss= 0.0085, Training Accuracy= 0.9962, Minibatch error= 0.4%
# 2017-07-17 18:43:56,533 Iter 2320, Minibatch Loss= 0.0015, Training Accuracy= 0.9995, Minibatch error= 0.0%
# 2017-07-17 18:44:09,182 Iter 2330, Minibatch Loss= 0.0090, Training Accuracy= 0.9959, Minibatch error= 0.4%
# 2017-07-17 18:44:22,117 Iter 2340, Minibatch Loss= 0.0057, Training Accuracy= 0.9978, Minibatch error= 0.2%
# 2017-07-17 18:44:33,943 Epoch 46, Average loss: 0.0077, learning rate: 0.0189
# 2017-07-17 18:44:34,257 Verification error= 0.2%, loss= 0.0055
# 2017-07-17 18:44:42,823 Iter 2350, Minibatch Loss= 0.0067, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2017-07-17 18:44:55,830 Iter 2360, Minibatch Loss= 0.0032, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-17 18:45:08,785 Iter 2370, Minibatch Loss= 0.0071, Training Accuracy= 0.9977, Minibatch error= 0.2%
# 2017-07-17 18:45:21,593 Iter 2380, Minibatch Loss= 0.0047, Training Accuracy= 0.9982, Minibatch error= 0.2%
# 2017-07-17 18:45:34,367 Iter 2390, Minibatch Loss= 0.0082, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2017-07-17 18:45:46,254 Epoch 47, Average loss: 0.0073, learning rate: 0.0179
# 2017-07-17 18:45:46,572 Verification error= 0.3%, loss= 0.0060
# 2017-07-17 18:45:55,516 Iter 2400, Minibatch Loss= 0.0098, Training Accuracy= 0.9957, Minibatch error= 0.4%
# 2017-07-17 18:46:08,993 Iter 2410, Minibatch Loss= 0.0032, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-17 18:46:21,740 Iter 2420, Minibatch Loss= 0.0444, Training Accuracy= 0.9799, Minibatch error= 2.0%
# 2017-07-17 18:46:34,737 Iter 2430, Minibatch Loss= 0.0112, Training Accuracy= 0.9947, Minibatch error= 0.5%
# 2017-07-17 18:46:47,650 Iter 2440, Minibatch Loss= 0.0067, Training Accuracy= 0.9974, Minibatch error= 0.3%
# 2017-07-17 18:46:59,257 Epoch 48, Average loss: 0.0084, learning rate: 0.0171
# 2017-07-17 18:46:59,578 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 18:47:07,942 Iter 2450, Minibatch Loss= 0.0058, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-17 18:47:21,440 Iter 2460, Minibatch Loss= 0.0053, Training Accuracy= 0.9979, Minibatch error= 0.2%
# 2017-07-17 18:47:34,893 Iter 2470, Minibatch Loss= 0.0111, Training Accuracy= 0.9953, Minibatch error= 0.5%
# 2017-07-17 18:47:47,798 Iter 2480, Minibatch Loss= 0.0012, Training Accuracy= 0.9996, Minibatch error= 0.0%
# 2017-07-17 18:48:01,036 Iter 2490, Minibatch Loss= 0.0073, Training Accuracy= 0.9967, Minibatch error= 0.3%
# 2017-07-17 18:48:12,677 Epoch 49, Average loss: 0.0075, learning rate: 0.0162
# 2017-07-17 18:48:12,994 Verification error= 0.2%, loss= 0.0055
# 2017-07-17 18:48:22,029 Iter 2500, Minibatch Loss= 0.0011, Training Accuracy= 0.9997, Minibatch error= 0.0%
# 2017-07-17 18:48:35,360 Iter 2510, Minibatch Loss= 0.0057, Training Accuracy= 0.9979, Minibatch error= 0.2%
# 2017-07-17 18:48:48,644 Iter 2520, Minibatch Loss= 0.0041, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2017-07-17 18:49:03,417 Iter 2530, Minibatch Loss= 0.0056, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-17 18:49:16,562 Iter 2540, Minibatch Loss= 0.0030, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-17 18:49:28,210 Epoch 50, Average loss: 0.0078, learning rate: 0.0154
# 2017-07-17 18:49:28,541 Verification error= 0.2%, loss= 0.0056
# 2017-07-17 18:49:38,206 Iter 2550, Minibatch Loss= 0.0067, Training Accuracy= 0.9971, Minibatch error= 0.3%
# 2017-07-17 18:49:51,752 Iter 2560, Minibatch Loss= 0.0034, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-17 18:50:05,031 Iter 2570, Minibatch Loss= 0.0062, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-17 18:50:18,597 Iter 2580, Minibatch Loss= 0.0045, Training Accuracy= 0.9984, Minibatch error= 0.2%
# 2017-07-17 18:50:31,973 Iter 2590, Minibatch Loss= 0.0052, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-17 18:50:43,784 Epoch 51, Average loss: 0.0065, learning rate: 0.0146
# 2017-07-17 18:50:44,100 Verification error= 0.2%, loss= 0.0055
# 2017-07-17 18:50:59,598 Iter 2600, Minibatch Loss= 0.0030, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 18:51:13,149 Iter 2610, Minibatch Loss= 0.0042, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-17 18:51:26,541 Iter 2620, Minibatch Loss= 0.0030, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-17 18:51:40,144 Iter 2630, Minibatch Loss= 0.0059, Training Accuracy= 0.9977, Minibatch error= 0.2%
# 2017-07-17 18:51:53,823 Iter 2640, Minibatch Loss= 0.0088, Training Accuracy= 0.9971, Minibatch error= 0.3%
# 2017-07-17 18:52:05,952 Epoch 52, Average loss: 0.0082, learning rate: 0.0139
# 2017-07-17 18:52:06,272 Verification error= 0.2%, loss= 0.0056
# 2017-07-17 18:52:16,685 Iter 2650, Minibatch Loss= 0.0396, Training Accuracy= 0.9820, Minibatch error= 1.8%
# 2017-07-17 18:52:30,819 Iter 2660, Minibatch Loss= 0.0049, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2017-07-17 18:52:44,816 Iter 2670, Minibatch Loss= 0.0074, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2017-07-17 18:52:58,300 Iter 2680, Minibatch Loss= 0.0051, Training Accuracy= 0.9974, Minibatch error= 0.3%
# 2017-07-17 18:53:12,100 Iter 2690, Minibatch Loss= 0.0037, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-17 18:53:24,288 Epoch 53, Average loss: 0.0077, learning rate: 0.0132
# 2017-07-17 18:53:24,609 Verification error= 0.2%, loss= 0.0054
# 2017-07-17 18:53:36,134 Iter 2700, Minibatch Loss= 0.0074, Training Accuracy= 0.9974, Minibatch error= 0.3%
# 2017-07-17 18:53:50,086 Iter 2710, Minibatch Loss= 0.0098, Training Accuracy= 0.9966, Minibatch error= 0.3%
# 2017-07-17 18:54:03,972 Iter 2720, Minibatch Loss= 0.0021, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 18:54:18,259 Iter 2730, Minibatch Loss= 0.0044, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-17 18:54:32,709 Iter 2740, Minibatch Loss= 0.0065, Training Accuracy= 0.9978, Minibatch error= 0.2%
# 2017-07-17 18:54:45,070 Epoch 54, Average loss: 0.0075, learning rate: 0.0125
# 2017-07-17 18:54:45,391 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 18:54:56,236 Iter 2750, Minibatch Loss= 0.0035, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-17 18:55:10,894 Iter 2760, Minibatch Loss= 0.0035, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2017-07-17 18:55:25,054 Iter 2770, Minibatch Loss= 0.0027, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-17 18:55:38,827 Iter 2780, Minibatch Loss= 0.0068, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2017-07-17 18:55:52,909 Iter 2790, Minibatch Loss= 0.0129, Training Accuracy= 0.9944, Minibatch error= 0.6%
# 2017-07-17 18:56:06,205 Epoch 55, Average loss: 0.0064, learning rate: 0.0119
# 2017-07-17 18:56:06,526 Verification error= 0.2%, loss= 0.0054
# 2017-07-17 18:56:18,238 Iter 2800, Minibatch Loss= 0.0077, Training Accuracy= 0.9968, Minibatch error= 0.3%
# 2017-07-17 18:56:32,555 Iter 2810, Minibatch Loss= 0.0052, Training Accuracy= 0.9985, Minibatch error= 0.2%
# 2017-07-17 18:56:47,208 Iter 2820, Minibatch Loss= 0.0062, Training Accuracy= 0.9984, Minibatch error= 0.2%
# 2017-07-17 18:57:01,290 Iter 2830, Minibatch Loss= 0.0094, Training Accuracy= 0.9957, Minibatch error= 0.4%
# 2017-07-17 18:57:15,755 Iter 2840, Minibatch Loss= 0.0034, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2017-07-17 18:57:28,509 Epoch 56, Average loss: 0.0062, learning rate: 0.0113
# 2017-07-17 18:57:28,825 Verification error= 0.2%, loss= 0.0055
# 2017-07-17 18:57:37,788 Iter 2850, Minibatch Loss= 0.0448, Training Accuracy= 0.9801, Minibatch error= 2.0%
# 2017-07-17 18:57:53,003 Iter 2860, Minibatch Loss= 0.0414, Training Accuracy= 0.9819, Minibatch error= 1.8%
# 2017-07-17 18:58:07,542 Iter 2870, Minibatch Loss= 0.0058, Training Accuracy= 0.9979, Minibatch error= 0.2%
# 2017-07-17 18:58:22,283 Iter 2880, Minibatch Loss= 0.0095, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2017-07-17 18:58:37,212 Iter 2890, Minibatch Loss= 0.0097, Training Accuracy= 0.9954, Minibatch error= 0.5%
# 2017-07-17 18:58:50,108 Epoch 57, Average loss: 0.0103, learning rate: 0.0107
# 2017-07-17 18:58:50,425 Verification error= 0.2%, loss= 0.0056
# 2017-07-17 18:58:59,972 Iter 2900, Minibatch Loss= 0.0101, Training Accuracy= 0.9965, Minibatch error= 0.4%
# 2017-07-17 18:59:14,916 Iter 2910, Minibatch Loss= 0.0133, Training Accuracy= 0.9946, Minibatch error= 0.5%
# 2017-07-17 18:59:29,773 Iter 2920, Minibatch Loss= 0.0104, Training Accuracy= 0.9958, Minibatch error= 0.4%
# 2017-07-17 18:59:44,613 Iter 2930, Minibatch Loss= 0.0075, Training Accuracy= 0.9967, Minibatch error= 0.3%
# 2017-07-17 18:59:59,120 Iter 2940, Minibatch Loss= 0.0060, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-17 19:00:12,311 Epoch 58, Average loss: 0.0085, learning rate: 0.0102
# 2017-07-17 19:00:12,634 Verification error= 0.2%, loss= 0.0054
# 2017-07-17 19:00:21,991 Iter 2950, Minibatch Loss= 0.0044, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-17 19:00:37,402 Iter 2960, Minibatch Loss= 0.0027, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-17 19:00:52,072 Iter 2970, Minibatch Loss= 0.0036, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 19:01:07,130 Iter 2980, Minibatch Loss= 0.0049, Training Accuracy= 0.9978, Minibatch error= 0.2%
# 2017-07-17 19:01:22,206 Iter 2990, Minibatch Loss= 0.0011, Training Accuracy= 0.9997, Minibatch error= 0.0%
# 2017-07-17 19:01:35,402 Epoch 59, Average loss: 0.0062, learning rate: 0.0097
# 2017-07-17 19:01:35,723 Verification error= 0.2%, loss= 0.0055
# 2017-07-17 19:01:48,134 Iter 3000, Minibatch Loss= 0.0151, Training Accuracy= 0.9930, Minibatch error= 0.7%
# 2017-07-17 19:02:03,529 Iter 3010, Minibatch Loss= 0.0058, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2017-07-17 19:02:19,193 Iter 3020, Minibatch Loss= 0.0023, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-17 19:02:34,229 Iter 3030, Minibatch Loss= 0.0100, Training Accuracy= 0.9952, Minibatch error= 0.5%
# 2017-07-17 19:02:50,007 Iter 3040, Minibatch Loss= 0.0132, Training Accuracy= 0.9936, Minibatch error= 0.6%
# 2017-07-17 19:03:03,525 Epoch 60, Average loss: 0.0093, learning rate: 0.0092
# 2017-07-17 19:03:03,842 Verification error= 0.2%, loss= 0.0056
# 2017-07-17 19:03:13,080 Iter 3050, Minibatch Loss= 0.0031, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 19:03:28,314 Iter 3060, Minibatch Loss= 0.0035, Training Accuracy= 0.9985, Minibatch error= 0.1%
# 2017-07-17 19:03:43,551 Iter 3070, Minibatch Loss= 0.0425, Training Accuracy= 0.9815, Minibatch error= 1.9%
# 2017-07-17 19:03:59,361 Iter 3080, Minibatch Loss= 0.0069, Training Accuracy= 0.9970, Minibatch error= 0.3%
# 2017-07-17 19:04:14,545 Iter 3090, Minibatch Loss= 0.0062, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2017-07-17 19:04:28,697 Epoch 61, Average loss: 0.0073, learning rate: 0.0088
# 2017-07-17 19:04:29,016 Verification error= 0.2%, loss= 0.0055
# 2017-07-17 19:04:40,088 Iter 3100, Minibatch Loss= 0.0046, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-17 19:04:55,791 Iter 3110, Minibatch Loss= 0.0024, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2017-07-17 19:05:11,112 Iter 3120, Minibatch Loss= 0.0059, Training Accuracy= 0.9978, Minibatch error= 0.2%
# 2017-07-17 19:05:26,680 Iter 3130, Minibatch Loss= 0.0053, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-17 19:05:42,383 Iter 3140, Minibatch Loss= 0.0061, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-17 19:05:56,106 Epoch 62, Average loss: 0.0066, learning rate: 0.0083
# 2017-07-17 19:05:56,425 Verification error= 0.2%, loss= 0.0057
# 2017-07-17 19:06:08,022 Iter 3150, Minibatch Loss= 0.0105, Training Accuracy= 0.9951, Minibatch error= 0.5%
# 2017-07-17 19:06:23,794 Iter 3160, Minibatch Loss= 0.0076, Training Accuracy= 0.9974, Minibatch error= 0.3%
# 2017-07-17 19:06:40,294 Iter 3170, Minibatch Loss= 0.0065, Training Accuracy= 0.9974, Minibatch error= 0.3%
# 2017-07-17 19:06:56,072 Iter 3180, Minibatch Loss= 0.0085, Training Accuracy= 0.9962, Minibatch error= 0.4%
# 2017-07-17 19:07:11,612 Iter 3190, Minibatch Loss= 0.0058, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2017-07-17 19:07:25,494 Epoch 63, Average loss: 0.0073, learning rate: 0.0079
# 2017-07-17 19:07:25,813 Verification error= 0.2%, loss= 0.0057
# 2017-07-17 19:07:37,888 Iter 3200, Minibatch Loss= 0.0073, Training Accuracy= 0.9970, Minibatch error= 0.3%
# 2017-07-17 19:07:54,490 Iter 3210, Minibatch Loss= 0.0027, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 19:08:10,094 Iter 3220, Minibatch Loss= 0.0059, Training Accuracy= 0.9972, Minibatch error= 0.3%
# 2017-07-17 19:08:25,672 Iter 3230, Minibatch Loss= 0.0126, Training Accuracy= 0.9947, Minibatch error= 0.5%
# 2017-07-17 19:08:41,164 Iter 3240, Minibatch Loss= 0.0057, Training Accuracy= 0.9978, Minibatch error= 0.2%
# 2017-07-17 19:08:55,259 Epoch 64, Average loss: 0.0079, learning rate: 0.0075
# 2017-07-17 19:08:55,666 Verification error= 0.2%, loss= 0.0057
# 2017-07-17 19:09:07,061 Iter 3250, Minibatch Loss= 0.0111, Training Accuracy= 0.9957, Minibatch error= 0.4%
# 2017-07-17 19:09:23,172 Iter 3260, Minibatch Loss= 0.0104, Training Accuracy= 0.9951, Minibatch error= 0.5%
# 2017-07-17 19:09:39,137 Iter 3270, Minibatch Loss= 0.0045, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-17 19:09:54,829 Iter 3280, Minibatch Loss= 0.0070, Training Accuracy= 0.9970, Minibatch error= 0.3%
# 2017-07-17 19:10:10,735 Iter 3290, Minibatch Loss= 0.0032, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-17 19:10:25,005 Epoch 65, Average loss: 0.0076, learning rate: 0.0071
# 2017-07-17 19:10:25,325 Verification error= 0.2%, loss= 0.0055
# 2017-07-17 19:10:37,697 Iter 3300, Minibatch Loss= 0.0094, Training Accuracy= 0.9956, Minibatch error= 0.4%
# 2017-07-17 19:10:54,215 Iter 3310, Minibatch Loss= 0.0072, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2017-07-17 19:11:09,932 Iter 3320, Minibatch Loss= 0.0029, Training Accuracy= 0.9995, Minibatch error= 0.0%
# 2017-07-17 19:11:26,023 Iter 3330, Minibatch Loss= 0.0057, Training Accuracy= 0.9972, Minibatch error= 0.3%
# 2017-07-17 19:11:42,083 Iter 3340, Minibatch Loss= 0.0032, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-17 19:11:56,044 Epoch 66, Average loss: 0.0069, learning rate: 0.0068
# 2017-07-17 19:11:56,365 Verification error= 0.2%, loss= 0.0054
# 2017-07-17 19:12:08,471 Iter 3350, Minibatch Loss= 0.0034, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 19:12:24,964 Iter 3360, Minibatch Loss= 0.0029, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2017-07-17 19:12:40,770 Iter 3370, Minibatch Loss= 0.0032, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-17 19:12:58,109 Iter 3380, Minibatch Loss= 0.0030, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2017-07-17 19:13:18,009 Iter 3390, Minibatch Loss= 0.0059, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2017-07-17 19:13:31,979 Epoch 67, Average loss: 0.0067, learning rate: 0.0064
# 2017-07-17 19:13:32,295 Verification error= 0.2%, loss= 0.0054
# 2017-07-17 19:13:43,299 Iter 3400, Minibatch Loss= 0.0041, Training Accuracy= 0.9982, Minibatch error= 0.2%
# 2017-07-17 19:13:59,532 Iter 3410, Minibatch Loss= 0.0093, Training Accuracy= 0.9966, Minibatch error= 0.3%
# 2017-07-17 19:14:16,037 Iter 3420, Minibatch Loss= 0.0026, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 19:14:32,163 Iter 3430, Minibatch Loss= 0.0066, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2017-07-17 19:14:48,377 Iter 3440, Minibatch Loss= 0.0106, Training Accuracy= 0.9951, Minibatch error= 0.5%
# 2017-07-17 19:15:02,819 Epoch 68, Average loss: 0.0085, learning rate: 0.0061
# 2017-07-17 19:15:03,140 Verification error= 0.2%, loss= 0.0052
# 2017-07-17 19:15:14,758 Iter 3450, Minibatch Loss= 0.0021, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-17 19:15:31,098 Iter 3460, Minibatch Loss= 0.0066, Training Accuracy= 0.9982, Minibatch error= 0.2%
# 2017-07-17 19:15:47,342 Iter 3470, Minibatch Loss= 0.0024, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 19:16:03,603 Iter 3480, Minibatch Loss= 0.0043, Training Accuracy= 0.9984, Minibatch error= 0.2%
# 2017-07-17 19:16:20,009 Iter 3490, Minibatch Loss= 0.0084, Training Accuracy= 0.9968, Minibatch error= 0.3%
# 2017-07-17 19:16:34,541 Epoch 69, Average loss: 0.0068, learning rate: 0.0058
# 2017-07-17 19:16:34,859 Verification error= 0.2%, loss= 0.0053
# ...
# 2017-07-17 21:19:02,426 Iter 6340, Minibatch Loss= 0.0054, Training Accuracy= 0.9980, Minibatch error= 0.2%
# 2017-07-17 21:19:26,508 Epoch 126, Average loss: 0.0067, learning rate: 0.0003
# 2017-07-17 21:19:26,842 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 21:19:51,967 Iter 6350, Minibatch Loss= 0.0072, Training Accuracy= 0.9969, Minibatch error= 0.3%
# 2017-07-17 21:20:19,323 Iter 6360, Minibatch Loss= 0.0054, Training Accuracy= 0.9975, Minibatch error= 0.2%
# 2017-07-17 21:20:45,622 Iter 6370, Minibatch Loss= 0.0049, Training Accuracy= 0.9985, Minibatch error= 0.2%
# 2017-07-17 21:21:13,253 Iter 6380, Minibatch Loss= 0.0086, Training Accuracy= 0.9961, Minibatch error= 0.4%
# 2017-07-17 21:21:42,093 Iter 6390, Minibatch Loss= 0.0033, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-17 21:22:07,013 Epoch 127, Average loss: 0.0069, learning rate: 0.0003
# 2017-07-17 21:22:07,331 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 21:22:34,499 Iter 6400, Minibatch Loss= 0.0070, Training Accuracy= 0.9972, Minibatch error= 0.3%
# 2017-07-17 21:23:02,967 Iter 6410, Minibatch Loss= 0.0089, Training Accuracy= 0.9958, Minibatch error= 0.4%
# 2017-07-17 21:23:30,199 Iter 6420, Minibatch Loss= 0.0063, Training Accuracy= 0.9974, Minibatch error= 0.3%
# 2017-07-17 21:23:57,378 Iter 6430, Minibatch Loss= 0.0045, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-17 21:24:24,121 Iter 6440, Minibatch Loss= 0.0024, Training Accuracy= 0.9990, Minibatch error= 0.1%
# 2017-07-17 21:24:48,199 Epoch 128, Average loss: 0.0074, learning rate: 0.0003
# 2017-07-17 21:24:48,513 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 21:25:11,625 Iter 6450, Minibatch Loss= 0.0052, Training Accuracy= 0.9985, Minibatch error= 0.2%
# 2017-07-17 21:25:38,902 Iter 6460, Minibatch Loss= 0.0077, Training Accuracy= 0.9966, Minibatch error= 0.3%
# 2017-07-17 21:26:06,778 Iter 6470, Minibatch Loss= 0.0015, Training Accuracy= 0.9995, Minibatch error= 0.0%
# 2017-07-17 21:26:34,118 Iter 6480, Minibatch Loss= 0.0033, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-17 21:27:02,460 Iter 6490, Minibatch Loss= 0.0013, Training Accuracy= 0.9997, Minibatch error= 0.0%
# 2017-07-17 21:27:27,955 Epoch 129, Average loss: 0.0085, learning rate: 0.0003
# 2017-07-17 21:27:28,274 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 21:27:55,113 Iter 6500, Minibatch Loss= 0.0065, Training Accuracy= 0.9972, Minibatch error= 0.3%
# 2017-07-17 21:28:22,748 Iter 6510, Minibatch Loss= 0.0010, Training Accuracy= 0.9997, Minibatch error= 0.0%
# 2017-07-17 21:28:50,000 Iter 6520, Minibatch Loss= 0.0033, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-17 21:29:19,507 Iter 6530, Minibatch Loss= 0.0049, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2017-07-17 21:29:47,507 Iter 6540, Minibatch Loss= 0.0033, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 21:30:12,714 Epoch 130, Average loss: 0.0080, learning rate: 0.0003
# 2017-07-17 21:30:13,037 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 21:30:37,105 Iter 6550, Minibatch Loss= 0.0052, Training Accuracy= 0.9985, Minibatch error= 0.2%
# 2017-07-17 21:31:05,045 Iter 6560, Minibatch Loss= 0.0050, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-17 21:31:32,706 Iter 6570, Minibatch Loss= 0.0083, Training Accuracy= 0.9972, Minibatch error= 0.3%
# 2017-07-17 21:32:03,480 Iter 6580, Minibatch Loss= 0.0027, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-17 21:32:32,186 Iter 6590, Minibatch Loss= 0.0034, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-17 21:32:58,154 Epoch 131, Average loss: 0.0073, learning rate: 0.0002
# 2017-07-17 21:32:58,476 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 21:33:24,403 Iter 6600, Minibatch Loss= 0.0030, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-17 21:33:53,523 Iter 6610, Minibatch Loss= 0.0147, Training Accuracy= 0.9937, Minibatch error= 0.6%
# 2017-07-17 21:34:22,719 Iter 6620, Minibatch Loss= 0.0071, Training Accuracy= 0.9967, Minibatch error= 0.3%
# 2017-07-17 21:34:51,926 Iter 6630, Minibatch Loss= 0.0271, Training Accuracy= 0.9891, Minibatch error= 1.1%
# 2017-07-17 21:35:21,660 Iter 6640, Minibatch Loss= 0.0041, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-17 21:35:47,414 Epoch 132, Average loss: 0.0080, learning rate: 0.0002
# 2017-07-17 21:35:47,736 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 21:36:08,730 Iter 6650, Minibatch Loss= 0.0028, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-17 21:36:37,335 Iter 6660, Minibatch Loss= 0.0035, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-17 21:37:06,966 Iter 6670, Minibatch Loss= 0.0057, Training Accuracy= 0.9974, Minibatch error= 0.3%
# 2017-07-17 21:37:36,199 Iter 6680, Minibatch Loss= 0.0097, Training Accuracy= 0.9955, Minibatch error= 0.5%
# 2017-07-17 21:38:05,969 Iter 6690, Minibatch Loss= 0.0050, Training Accuracy= 0.9978, Minibatch error= 0.2%
# 2017-07-17 21:38:31,549 Epoch 133, Average loss: 0.0065, learning rate: 0.0002
# 2017-07-17 21:38:31,870 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 21:38:55,028 Iter 6700, Minibatch Loss= 0.0023, Training Accuracy= 0.9995, Minibatch error= 0.1%
# 2017-07-17 21:39:23,085 Iter 6710, Minibatch Loss= 0.0062, Training Accuracy= 0.9974, Minibatch error= 0.3%
# 2017-07-17 21:39:53,058 Iter 6720, Minibatch Loss= 0.0029, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-17 21:40:27,267 Iter 6730, Minibatch Loss= 0.0067, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2017-07-17 21:41:02,028 Iter 6740, Minibatch Loss= 0.0046, Training Accuracy= 0.9979, Minibatch error= 0.2%
# 2017-07-17 21:41:33,698 Epoch 134, Average loss: 0.0126, learning rate: 0.0002
# 2017-07-17 21:41:34,024 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 21:41:57,603 Iter 6750, Minibatch Loss= 0.0077, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2017-07-17 21:42:27,629 Iter 6760, Minibatch Loss= 0.0047, Training Accuracy= 0.9985, Minibatch error= 0.1%
# 2017-07-17 21:42:55,769 Iter 6770, Minibatch Loss= 0.0050, Training Accuracy= 0.9979, Minibatch error= 0.2%
# 2017-07-17 21:43:23,488 Iter 6780, Minibatch Loss= 0.0059, Training Accuracy= 0.9978, Minibatch error= 0.2%
# 2017-07-17 21:43:53,621 Iter 6790, Minibatch Loss= 0.0076, Training Accuracy= 0.9976, Minibatch error= 0.2%
# 2017-07-17 21:44:20,583 Epoch 135, Average loss: 0.0068, learning rate: 0.0002
# 2017-07-17 21:44:20,905 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 21:44:51,501 Iter 6800, Minibatch Loss= 0.0040, Training Accuracy= 0.9985, Minibatch error= 0.1%
# 2017-07-17 21:45:21,085 Iter 6810, Minibatch Loss= 0.0038, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-17 21:45:50,498 Iter 6820, Minibatch Loss= 0.0076, Training Accuracy= 0.9974, Minibatch error= 0.3%
# 2017-07-17 21:46:19,514 Iter 6830, Minibatch Loss= 0.0110, Training Accuracy= 0.9953, Minibatch error= 0.5%
# 2017-07-17 21:46:50,129 Iter 6840, Minibatch Loss= 0.0082, Training Accuracy= 0.9964, Minibatch error= 0.4%
# 2017-07-17 21:47:17,093 Epoch 136, Average loss: 0.0081, learning rate: 0.0002
# 2017-07-17 21:47:17,413 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 21:47:42,174 Iter 6850, Minibatch Loss= 0.0047, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2017-07-17 21:48:12,519 Iter 6860, Minibatch Loss= 0.0046, Training Accuracy= 0.9994, Minibatch error= 0.1%
# 2017-07-17 21:48:41,053 Iter 6870, Minibatch Loss= 0.0031, Training Accuracy= 0.9992, Minibatch error= 0.1%
# 2017-07-17 21:49:09,782 Iter 6880, Minibatch Loss= 0.0032, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-17 21:49:41,272 Iter 6890, Minibatch Loss= 0.0453, Training Accuracy= 0.9800, Minibatch error= 2.0%
# 2017-07-17 21:50:09,363 Epoch 137, Average loss: 0.0065, learning rate: 0.0002
# 2017-07-17 21:50:09,704 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 21:50:37,489 Iter 6900, Minibatch Loss= 0.0041, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-17 21:51:07,748 Iter 6910, Minibatch Loss= 0.0034, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 21:51:36,996 Iter 6920, Minibatch Loss= 0.0489, Training Accuracy= 0.9798, Minibatch error= 2.0%
# 2017-07-17 21:52:05,949 Iter 6930, Minibatch Loss= 0.0044, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-17 21:52:35,725 Iter 6940, Minibatch Loss= 0.0039, Training Accuracy= 0.9986, Minibatch error= 0.1%
# 2017-07-17 21:53:01,320 Epoch 138, Average loss: 0.0091, learning rate: 0.0002
# 2017-07-17 21:53:01,642 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 21:53:28,723 Iter 6950, Minibatch Loss= 0.0015, Training Accuracy= 0.9997, Minibatch error= 0.0%
# 2017-07-17 21:53:57,288 Iter 6960, Minibatch Loss= 0.0031, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 21:54:25,620 Iter 6970, Minibatch Loss= 0.0079, Training Accuracy= 0.9966, Minibatch error= 0.3%
# 2017-07-17 21:54:54,999 Iter 6980, Minibatch Loss= 0.0092, Training Accuracy= 0.9957, Minibatch error= 0.4%
# 2017-07-17 21:55:25,084 Iter 6990, Minibatch Loss= 0.0031, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-17 21:55:51,639 Epoch 139, Average loss: 0.0069, learning rate: 0.0002
# 2017-07-17 21:55:51,959 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 21:56:18,046 Iter 7000, Minibatch Loss= 0.0013, Training Accuracy= 0.9997, Minibatch error= 0.0%
# 2017-07-17 21:56:47,633 Iter 7010, Minibatch Loss= 0.0042, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-17 21:57:17,321 Iter 7020, Minibatch Loss= 0.0032, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-17 21:57:47,114 Iter 7030, Minibatch Loss= 0.0038, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-17 21:58:17,650 Iter 7040, Minibatch Loss= 0.0049, Training Accuracy= 0.9985, Minibatch error= 0.1%
# 2017-07-17 21:58:44,285 Epoch 140, Average loss: 0.0080, learning rate: 0.0002
# 2017-07-17 21:58:44,603 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 21:59:06,456 Iter 7050, Minibatch Loss= 0.0038, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-17 21:59:36,331 Iter 7060, Minibatch Loss= 0.0107, Training Accuracy= 0.9967, Minibatch error= 0.3%
# 2017-07-17 22:00:07,505 Iter 7070, Minibatch Loss= 0.0078, Training Accuracy= 0.9966, Minibatch error= 0.3%
# 2017-07-17 22:00:37,241 Iter 7080, Minibatch Loss= 0.0055, Training Accuracy= 0.9976, Minibatch error= 0.2%
# 2017-07-17 22:01:07,817 Iter 7090, Minibatch Loss= 0.0065, Training Accuracy= 0.9970, Minibatch error= 0.3%
# 2017-07-17 22:01:35,368 Epoch 141, Average loss: 0.0074, learning rate: 0.0001
# 2017-07-17 22:01:35,698 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 22:02:00,247 Iter 7100, Minibatch Loss= 0.0093, Training Accuracy= 0.9970, Minibatch error= 0.3%
# 2017-07-17 22:02:30,610 Iter 7110, Minibatch Loss= 0.0060, Training Accuracy= 0.9982, Minibatch error= 0.2%
# 2017-07-17 22:03:00,891 Iter 7120, Minibatch Loss= 0.0074, Training Accuracy= 0.9967, Minibatch error= 0.3%
# 2017-07-17 22:03:32,110 Iter 7130, Minibatch Loss= 0.0035, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-17 22:04:03,176 Iter 7140, Minibatch Loss= 0.0053, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-17 22:04:30,397 Epoch 142, Average loss: 0.0079, learning rate: 0.0001
# 2017-07-17 22:04:30,752 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 22:04:50,432 Iter 7150, Minibatch Loss= 0.0047, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-17 22:05:20,965 Iter 7160, Minibatch Loss= 0.0442, Training Accuracy= 0.9808, Minibatch error= 1.9%
# 2017-07-17 22:05:50,255 Iter 7170, Minibatch Loss= 0.0059, Training Accuracy= 0.9976, Minibatch error= 0.2%
# 2017-07-17 22:06:21,219 Iter 7180, Minibatch Loss= 0.0052, Training Accuracy= 0.9982, Minibatch error= 0.2%
# 2017-07-17 22:06:51,738 Iter 7190, Minibatch Loss= 0.0027, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 22:07:19,756 Epoch 143, Average loss: 0.0069, learning rate: 0.0001
# 2017-07-17 22:07:20,079 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 22:07:46,588 Iter 7200, Minibatch Loss= 0.0027, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 22:08:16,957 Iter 7210, Minibatch Loss= 0.0046, Training Accuracy= 0.9979, Minibatch error= 0.2%
# 2017-07-17 22:08:46,048 Iter 7220, Minibatch Loss= 0.0069, Training Accuracy= 0.9981, Minibatch error= 0.2%
# 2017-07-17 22:09:16,111 Iter 7230, Minibatch Loss= 0.0030, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-17 22:09:47,858 Iter 7240, Minibatch Loss= 0.0082, Training Accuracy= 0.9964, Minibatch error= 0.4%
# 2017-07-17 22:10:15,628 Epoch 144, Average loss: 0.0063, learning rate: 0.0001
# 2017-07-17 22:10:15,952 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 22:10:39,111 Iter 7250, Minibatch Loss= 0.0064, Training Accuracy= 0.9976, Minibatch error= 0.2%
# 2017-07-17 22:11:09,933 Iter 7260, Minibatch Loss= 0.0429, Training Accuracy= 0.9814, Minibatch error= 1.9%
# 2017-07-17 22:11:40,973 Iter 7270, Minibatch Loss= 0.0070, Training Accuracy= 0.9969, Minibatch error= 0.3%
# 2017-07-17 22:12:12,303 Iter 7280, Minibatch Loss= 0.0051, Training Accuracy= 0.9983, Minibatch error= 0.2%
# 2017-07-17 22:12:43,421 Iter 7290, Minibatch Loss= 0.0161, Training Accuracy= 0.9928, Minibatch error= 0.7%
# 2017-07-17 22:13:11,974 Epoch 145, Average loss: 0.0078, learning rate: 0.0001
# 2017-07-17 22:13:12,291 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 22:13:34,089 Iter 7300, Minibatch Loss= 0.0038, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-17 22:14:05,968 Iter 7310, Minibatch Loss= 0.0047, Training Accuracy= 0.9985, Minibatch error= 0.2%
# 2017-07-17 22:14:36,338 Iter 7320, Minibatch Loss= 0.0027, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 22:15:08,089 Iter 7330, Minibatch Loss= 0.0030, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-17 22:15:37,720 Iter 7340, Minibatch Loss= 0.0076, Training Accuracy= 0.9972, Minibatch error= 0.3%
# 2017-07-17 22:16:05,430 Epoch 146, Average loss: 0.0057, learning rate: 0.0001
# 2017-07-17 22:16:05,758 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 22:16:43,373 Iter 7350, Minibatch Loss= 0.0081, Training Accuracy= 0.9974, Minibatch error= 0.3%
# 2017-07-17 22:17:14,983 Iter 7360, Minibatch Loss= 0.0025, Training Accuracy= 0.9991, Minibatch error= 0.1%
# 2017-07-17 22:17:45,471 Iter 7370, Minibatch Loss= 0.0037, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-17 22:18:16,370 Iter 7380, Minibatch Loss= 0.0055, Training Accuracy= 0.9987, Minibatch error= 0.1%
# 2017-07-17 22:18:48,373 Iter 7390, Minibatch Loss= 0.0059, Training Accuracy= 0.9973, Minibatch error= 0.3%
# 2017-07-17 22:19:15,709 Epoch 147, Average loss: 0.0086, learning rate: 0.0001
# 2017-07-17 22:19:16,033 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 22:19:36,535 Iter 7400, Minibatch Loss= 0.0120, Training Accuracy= 0.9952, Minibatch error= 0.5%
# 2017-07-17 22:20:06,982 Iter 7410, Minibatch Loss= 0.0081, Training Accuracy= 0.9964, Minibatch error= 0.4%
# 2017-07-17 22:20:36,783 Iter 7420, Minibatch Loss= 0.0079, Training Accuracy= 0.9964, Minibatch error= 0.4%
# 2017-07-17 22:21:07,616 Iter 7430, Minibatch Loss= 0.0027, Training Accuracy= 0.9993, Minibatch error= 0.1%
# 2017-07-17 22:21:37,306 Iter 7440, Minibatch Loss= 0.0132, Training Accuracy= 0.9946, Minibatch error= 0.5%
# 2017-07-17 22:22:05,246 Epoch 148, Average loss: 0.0064, learning rate: 0.0001
# 2017-07-17 22:22:05,566 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 22:22:27,975 Iter 7450, Minibatch Loss= 0.0075, Training Accuracy= 0.9967, Minibatch error= 0.3%
# 2017-07-17 22:22:59,255 Iter 7460, Minibatch Loss= 0.0031, Training Accuracy= 0.9989, Minibatch error= 0.1%
# 2017-07-17 22:23:30,012 Iter 7470, Minibatch Loss= 0.0037, Training Accuracy= 0.9988, Minibatch error= 0.1%
# 2017-07-17 22:24:01,609 Iter 7480, Minibatch Loss= 0.0084, Training Accuracy= 0.9963, Minibatch error= 0.4%
# 2017-07-17 22:24:33,219 Iter 7490, Minibatch Loss= 0.0085, Training Accuracy= 0.9962, Minibatch error= 0.4%
# 2017-07-17 22:25:02,334 Epoch 149, Average loss: 0.0056, learning rate: 0.0001
# 2017-07-17 22:25:02,667 Verification error= 0.2%, loss= 0.0053
# 2017-07-17 22:25:21,080 Optimization Finished!

# %%
prediction = net.predict("./unet_trained_2/model_2.cpkt", X_test)

# %%
err2 = error_rate(prediction,Y_test)
errors.append(err2)

# %%
err2
# Out:
# 0.2738189697265625

# %%
errors
# Out:
# [0.20687103271484375, 0.2738189697265625]

# %%
plot_prediction(x_test=X_test,y_test=Y_test,prediction=prediction,save=False)
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# ______

# %%
def create_conv_net_1(x, keep_prob, channels, n_class, layers=5, features_root=16, filter_size=3, pool_size=2, summaries=False):
    """
    Creates a new convolutional unet for the given parametrization.
    
    :param x: input tensor, shape [?,nx,ny,channels]
    :param keep_prob: dropout probability tensor
    :param channels: number of channels in the input image
    :param n_class: number of output labels
    :param layers: number of layers in the net
    :param features_root: number of features in the first layer
    :param filter_size: size of the convolution filter
    :param pool_size: size of the max pooling operation
    :param summaries: Flag if summaries should be created
    """
    
    logging.info("Layers {layers}, features {features}, filter size {filter_size}x{filter_size},pool size: {pool_size}x{pool_size}".format(layers=layers,
                                                                                                           features=features_root,
                                                                                                           filter_size=filter_size,
                                                                                                           pool_size=pool_size))
    # Placeholder for the input image
    nx = tf.shape(x)[1]
    ny = tf.shape(x)[2]
    x_image = tf.reshape(x, tf.stack([-1,nx,ny,channels]))
    in_node = x_image
    batch_size = tf.shape(x_image)[0]
 
    weights = []
    biases = []
    convs = []
    pools = OrderedDict()
    deconv = OrderedDict()
    dw_h_convs = OrderedDict()
    up_h_convs = OrderedDict()
    paddings=[[0,0],[1,1],[1,1],[0,0]]
    in_size = 1000
    size = in_size
    # down layers
    for layer in range(0, layers):
        features = 2**layer*features_root
        stddev = np.sqrt(2 / (filter_size**2 * features))
        if layer == 0:
            w1 = weight_variable([filter_size, filter_size, channels, features], stddev)
        else:
            w1 = weight_variable([filter_size, filter_size, features//2, features], stddev)
            
        w2 = weight_variable([filter_size, filter_size, features, features], stddev)
        b1 = bias_variable([features])
        b2 = bias_variable([features])
        
        in_node = tf.pad(in_node,paddings,"CONSTANT")
        conv1 = conv2d(in_node, w1, keep_prob)
        tmp_h_conv = tf.nn.relu(conv1 + b1)
        tmp_h_conv = tf.pad(tmp_h_conv,paddings,"CONSTANT")
        conv2 = conv2d(tmp_h_conv, w2, keep_prob)
        dw_h_convs[layer] = tf.nn.relu(conv2 + b2)
        
        weights.append((w1, w2))
        biases.append((b1, b2))
        convs.append((conv1, conv2))
        
        size -= 4
        if layer < layers-1:
            pools[layer] = max_pool(dw_h_convs[layer], pool_size)
            in_node = pools[layer]
            size /= 2
        
    in_node = dw_h_convs[layers-1]
        
    # up layers
    for layer in range(layers-2, -1, -1):
        
        features = 2**(layer+1)*features_root
        stddev = np.sqrt(2 / (filter_size**2 * features))
        
        wd = weight_variable_devonc([pool_size, pool_size, features//2, features], stddev)
        bd = bias_variable([features//2])
        h_deconv = tf.nn.relu(deconv2d(in_node, wd, pool_size) + bd)
        h_deconv_concat = crop_and_concat(dw_h_convs[layer], h_deconv)
        deconv[layer] = h_deconv_concat
        
        w1 = weight_variable([filter_size, filter_size, features, features//2], stddev)
        w2 = weight_variable([filter_size, filter_size, features//2, features//2], stddev)
        b1 = bias_variable([features//2])
        b2 = bias_variable([features//2])
        
        h_deconv_concat = tf.pad(h_deconv_concat,paddings,"CONSTANT")
        conv1 = conv2d(h_deconv_concat, w1, keep_prob)
        h_conv = tf.nn.relu(conv1 + b1)
        h_conv = tf.pad(h_conv,paddings,"CONSTANT")
        conv2 = conv2d(h_conv, w2, keep_prob)
        in_node = tf.nn.relu(conv2 + b2)
        up_h_convs[layer] = in_node

        weights.append((w1, w2))
        biases.append((b1, b2))
        convs.append((conv1, conv2))
        
        size *= 2
        size -= 4

    # Output Map
    weight = weight_variable([1, 1, features_root, n_class], stddev)
    bias = bias_variable([n_class])
    conv = conv2d(in_node, weight, tf.constant(1.0))
    output_map = tf.nn.relu(conv + bias)
    up_h_convs["out"] = output_map
    
    if summaries:
        for i, (c1, c2) in enumerate(convs):
            tf.summary.image('summary_conv_%02d_01'%i, get_image_summary(c1))
            tf.summary.image('summary_conv_%02d_02'%i, get_image_summary(c2))
            
        for k in pools.keys():
            tf.summary.image('summary_pool_%02d'%k, get_image_summary(pools[k]))
        
        for k in deconv.keys():
            tf.summary.image('summary_deconv_concat_%02d'%k, get_image_summary(deconv[k]))
            
        for k in dw_h_convs.keys():
            tf.summary.histogram("dw_convolution_%02d"%k + '/activations', dw_h_convs[k])

        for k in up_h_convs.keys():
            tf.summary.histogram("up_convolution_%s"%k + '/activations', up_h_convs[k])
            
    variables = []
    for w1,w2 in weights:
        variables.append(w1)
        variables.append(w2)
        
    for b1,b2 in biases:
        variables.append(b1)
        variables.append(b2)

    
    return output_map, variables, int(in_size - size)

# %%
class Unet(object):
    """
    A unet implementation
    
    :param channels: (optional) number of channels in the input image
    :param n_class: (optional) number of output labels
    :param cost: (optional) name of the cost function. Default is 'cross_entropy'
    :param cost_kwargs: (optional) kwargs passed to the cost function. See Unet._get_cost for more options
    """
    
    def __init__(self, channels=1, n_class=2, cost="cross_entropy", cost_kwargs={}, **kwargs):
        tf.reset_default_graph()
        
        self.n_class = n_class
        self.summaries = kwargs.get("summaries", True)
        
        self.x = tf.placeholder("float", shape=[None, None, None, channels])
        self.y = tf.placeholder("float", shape=[None, None, None, n_class])
        self.keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)
        
        logits, self.variables, self.offset = create_conv_net_1(self.x, self.keep_prob, channels, n_class, **kwargs)
        
        self.cost = self._get_cost(logits, cost, cost_kwargs)
        
        self.gradients_node = tf.gradients(self.cost, self.variables)
         
        self.cross_entropy = tf.reduce_mean(cross_entropy(tf.reshape(self.y, [-1, n_class]),
                                                          tf.reshape(pixel_wise_softmax_2(logits), [-1, n_class])))
        
        self.predicter = pixel_wise_softmax_2(logits)
        self.correct_pred = tf.equal(tf.argmax(self.predicter, 3), tf.argmax(self.y, 3))
        self.accuracy = tf.reduce_mean(tf.cast(self.correct_pred, tf.float32))
        
    def _get_cost(self, logits, cost_name, cost_kwargs):
        """
        Constructs the cost function, either cross_entropy, weighted cross_entropy or dice_coefficient.
        Optional arguments are: 
        class_weights: weights for the different classes in case of multi-class imbalance
        regularizer: power of the L2 regularizers added to the loss function
        """
        
        flat_logits = tf.reshape(logits, [-1, self.n_class])
        flat_labels = tf.reshape(self.y, [-1, self.n_class])
        if cost_name == "cross_entropy":
            class_weights = cost_kwargs.pop("class_weights", None)
            
            if class_weights is not None:
                class_weights = tf.constant(np.array(class_weights, dtype=np.float32))
        
                weight_map = tf.multiply(flat_labels, class_weights)
                weight_map = tf.reduce_sum(weight_map, axis=1)
        
                loss_map = tf.nn.softmax_cross_entropy_with_logits(flat_logits, flat_labels)
                weighted_loss = tf.multiply(loss_map, weight_map)
        
                loss = tf.reduce_mean(weighted_loss)
                
            else:
                loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=flat_logits, 
                                                                              labels=flat_labels))
        elif cost_name == "dice_coefficient":
            eps = 1e-5
            prediction = pixel_wise_softmax_2(logits)
            intersection = tf.reduce_sum(prediction * self.y)
            union =  eps + tf.reduce_sum(prediction) + tf.reduce_sum(self.y)
            loss = -(2 * intersection/ (union))
            
        else:
            raise ValueError("Unknown cost function: "%cost_name)

        regularizer = cost_kwargs.pop("regularizer", None)
        if regularizer is not None:
            regularizers = sum([tf.nn.l2_loss(variable) for variable in self.variables])
            loss += (regularizer * regularizers)
            
        return loss

    def predict(self, model_path, x_test):
        """
        Uses the model to create a prediction for the given data
        
        :param model_path: path to the model checkpoint to restore
        :param x_test: Data to predict on. Shape [n, nx, ny, channels]
        :returns prediction: The unet prediction Shape [n, px, py, labels] (px=nx-self.offset/2) 
        """
        
        init = tf.global_variables_initializer()
        with tf.Session(config=config) as sess:
            # Initialize variables
            sess.run(init)
        
            # Restore model weights from previously saved model
            self.restore(sess, model_path)
            
            y_dummy = np.empty((x_test.shape[0], x_test.shape[1], x_test.shape[2], self.n_class))
            prediction = sess.run(self.predicter, feed_dict={self.x: x_test, self.y: y_dummy, self.keep_prob: 1.})
            
        return prediction
    
    def save(self, sess, model_path):
        """
        Saves the current session to a checkpoint
        
        :param sess: current session
        :param model_path: path to file system location
        """
        
        saver = tf.train.Saver()
        save_path = saver.save(sess, model_path)
        return save_path
    
    def restore(self, sess, model_path):
        """
        Restores a session from a checkpoint
        
        :param sess: current session instance
        :param model_path: path to file system checkpoint location
        """
        
        saver = tf.train.Saver()
        saver.restore(sess, model_path)
        logging.info("Model restored from file: %s" % model_path)

# %%
class Trainer(object):
    """
    Trains a unet instance
    
    :param net: the unet instance to train
    :param batch_size: size of training batch
    :param optimizer: (optional) name of the optimizer to use (momentum or adam)
    :param opt_kwargs: (optional) kwargs passed to the learning rate (momentum opt) and to the optimizer
    """
    
    prediction_path = "prediction_model1"    ### to channge this before running......give number at the end.
    verification_batch_size = 4
    
    def __init__(self, net, batch_size=1, optimizer="momentum", opt_kwargs={}):
        self.net = net
        self.batch_size = batch_size
        self.optimizer = optimizer
        self.opt_kwargs = opt_kwargs
        
    def _get_optimizer(self, training_iters, global_step):
        if self.optimizer == "momentum":
            learning_rate = self.opt_kwargs.pop("learning_rate", 0.2)
            decay_rate = self.opt_kwargs.pop("decay_rate", 0.95)
            momentum = self.opt_kwargs.pop("momentum", 0.2)
            
            self.learning_rate_node = tf.train.exponential_decay(learning_rate=learning_rate, 
                                                        global_step=global_step, 
                                                        decay_steps=training_iters,  
                                                        decay_rate=decay_rate, 
                                                        staircase=True)
            
            optimizer = tf.train.MomentumOptimizer(learning_rate=self.learning_rate_node, momentum=momentum,
                                                   **self.opt_kwargs).minimize(self.net.cost, 
                                                                                global_step=global_step)
        elif self.optimizer == "adam":
            learning_rate = self.opt_kwargs.pop("learning_rate", 0.001)
            self.learning_rate_node = tf.Variable(learning_rate)
            
            optimizer = tf.train.AdamOptimizer(learning_rate=self.learning_rate_node, 
                                               **self.opt_kwargs).minimize(self.net.cost,
                                                                     global_step=global_step)
        
        return optimizer
        
    def _initialize(self, training_iters, output_path, restore):
        global_step = tf.Variable(0)
        
        self.norm_gradients_node = tf.Variable(tf.constant(0.0, shape=[len(self.net.gradients_node)]))
        
        if self.net.summaries:
            tf.summary.histogram('norm_grads', self.norm_gradients_node)

        tf.summary.scalar('loss', self.net.cost)
        tf.summary.scalar('cross_entropy', self.net.cross_entropy)
        tf.summary.scalar('accuracy', self.net.accuracy)

        self.optimizer = self._get_optimizer(training_iters, global_step)
        tf.summary.scalar('learning_rate', self.learning_rate_node)

        self.summary_op = tf.summary.merge_all()        
        init = tf.global_variables_initializer()
        
        prediction_path = os.path.abspath(self.prediction_path)
        output_path = os.path.abspath(output_path)
        
        if not restore:
            logging.info("Removing '{:}'".format(prediction_path))
            shutil.rmtree(prediction_path, ignore_errors=True)
            logging.info("Removing '{:}'".format(output_path))
            shutil.rmtree(output_path, ignore_errors=True)
        
        if not os.path.exists(prediction_path):
            logging.info("Allocating '{:}'".format(prediction_path))
            os.makedirs(prediction_path)
        
        if not os.path.exists(output_path):
            logging.info("Allocating '{:}'".format(output_path))
            os.makedirs(output_path)
        
        return init

    def train(self, data_provider, output_path, training_iters=10, epochs=100, dropout=0.75, display_step=1, restore=False, write_graph=False):
        """
        Lauches the training process
        
        :param data_provider: callable returning training and verification data
        :param output_path: path where to store checkpoints
        :param training_iters: number of training mini batch iteration
        :param epochs: number of epochs
        :param dropout: dropout probability
        :param display_step: number of steps till outputting stats
        :param restore: Flag if previous model should be restored 
        :param write_graph: Flag if the computation graph should be written as protobuf file to the output path
        """
        save_path = os.path.join(output_path, "model_1.cpkt")  ## ////..change the save path before running if you want to be in same path..////
        if epochs == 0:
            return save_path
        
        init = self._initialize(training_iters, output_path, restore)
        
        with tf.Session(config=config) as sess:
            if write_graph:
                tf.train.write_graph(sess.graph_def, output_path, "graph.pb", False)
            
            sess.run(init)
            
            if restore:
                ckpt = tf.train.get_checkpoint_state(output_path)
                if ckpt and ckpt.model_checkpoint_path:
                    self.net.restore(sess, ckpt.model_checkpoint_path)
            
            test_x, test_y = data_provider(self.verification_batch_size)
            pred_shape = self.store_prediction(sess, test_x, test_y, "_init")
            nuksaan = []
            
            summary_writer = tf.summary.FileWriter(output_path, graph=sess.graph)
            logging.info("Start optimization")
            
            avg_gradients = None
            for epoch in range(epochs):
                total_loss = 0
                for step in range((epoch*training_iters), ((epoch+1)*training_iters)):
                    batch_x, batch_y = data_provider(self.batch_size)
                     
                    # Run optimization op (backprop)
                    _, loss, lr, gradients = sess.run((self.optimizer, self.net.cost, self.learning_rate_node, self.net.gradients_node), 
                                                      feed_dict={self.net.x: batch_x,
                                                                 self.net.y: crop_to_shape(batch_y, pred_shape),
                                                                 self.net.keep_prob: dropout})

                    if avg_gradients is None:
                        avg_gradients = [np.zeros_like(gradient) for gradient in gradients]
                    for i in range(len(gradients)):
                        avg_gradients[i] = (avg_gradients[i] * (1.0 - (1.0 / (step+1)))) + (gradients[i] / (step+1))
                        
                    norm_gradients = [np.linalg.norm(gradient) for gradient in avg_gradients]
                    self.norm_gradients_node.assign(norm_gradients).eval()
                    
                    if step % display_step == 0:
                        self.output_minibatch_stats(sess, summary_writer, step, batch_x, crop_to_shape(batch_y, pred_shape))
                        
                    total_loss += loss
                    nuksaan.append(total_loss)

                self.output_epoch_stats(epoch, total_loss, training_iters, lr)
                self.store_prediction(sess, test_x, test_y, "epoch_%s"%epoch)
                    
                save_path = self.net.save(sess, save_path)
            logging.info("Optimization Finished!")
            
            return save_path, nuksaan
        
    def store_prediction(self, sess, batch_x, batch_y, name):
        prediction = sess.run(self.net.predicter, feed_dict={self.net.x: batch_x,self.net.y: batch_y,self.net.keep_prob:1.})
        pred_shape = prediction.shape
        
        loss = sess.run(self.net.cost, feed_dict={self.net.x: batch_x, 
                                                       self.net.y: crop_to_shape(batch_y, pred_shape), 
                                                       self.net.keep_prob: 1.})
        
        logging.info("Verification error= {:.1f}%, loss= {:.4f}".format(error_rate(prediction,
                                                                          crop_to_shape(batch_y,
                                                                                             prediction.shape)),
                                                                          loss))
              
        img = combine_img_prediction(batch_x, batch_y, prediction)
        save_image(img, "%s/%s.jpg"%(self.prediction_path, name))
        
        return pred_shape
    
    def output_epoch_stats(self, epoch, total_loss, training_iters, lr):
        logging.info("Epoch {:}, Average loss: {:.4f}, learning rate: {:.4f}".format(epoch, (total_loss / training_iters), lr))
    
    def output_minibatch_stats(self, sess, summary_writer, step, batch_x, batch_y):
        # Calculate batch loss and accuracy
        summary_str, loss, acc, predictions = sess.run([self.summary_op, 
                                                            self.net.cost, 
                                                            self.net.accuracy, 
                                                            self.net.predicter], 
                                                           feed_dict={self.net.x: batch_x,
                                                                      self.net.y: batch_y,
                                                                      self.net.keep_prob: 1.})
        summary_writer.add_summary(summary_str, step)
        summary_writer.flush()
        logging.info("Iter {:}, Minibatch Loss= {:.4f}, Training Accuracy= {:.4f}, Minibatch error= {:.1f}%".format(step,
                                                                                                            loss,
                                                                                                            acc,
                                                                                                            error_rate(predictions, batch_y)))

# %%
net = Unet(channels=mydata.channels, n_class=mydata.n_class, layers=5, features_root=16)

# %%
trainer = Trainer(net, optimizer="momentum", opt_kwargs=dict(momentum=0.2))

# %%
output_path = "./unet_trained_1"

# %%
path, nuksaan1 = trainer.train(mydata, output_path=output_path, training_iters=50, epochs=150, display_step=10)

# %%
prediction = net.predict("./unet_trained_1/model_1.cpkt", X_test)

# %%
err3 = error_rate(prediction,Y_test)
errors.append(err3)

# %% [markdown]
# ______
# ## **```Visualization```**

# %% [markdown]
# > Plotting **```loss```** values varying with **```epocs```** for different models

# %%
import pandas as pd
losss = {'iter' : range (1,7501), 'model_7_248' : nuksaan2, 'model_7_222' : nuksaan2, 'model_5_222' : nuksaan2}
losss = pd.DataFrame(data = losss)
losss.head()
# Out:
#    iter  model_5_222  model_7_222  model_7_248
# 0     1     0.698448     0.698448     0.698448
# 1     2     1.206523     1.206523     1.206523
# 2     3     1.570095     1.570095     1.570095
# 3     4     1.793534     1.793534     1.793534
# 4     5     1.904322     1.904322     1.904322

# %%
import matplotlib.pyplot as plt  
import pandas as pd  
      
# Read the data into a pandas DataFrame.    
gender_degree_data = losss    
      
# These are the "Tableau 20" colors as RGB.    
tableau20 = [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),    
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),    
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),    
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),    
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]    
  
# Scale the RGB values to the [0, 1] range, which is the format matplotlib accepts.    
for i in range(len(tableau20)):    
    r, g, b = tableau20[i]    
    tableau20[i] = (r / 255., g / 255., b / 255.)    

# You typically want your plot to be ~1.33x wider than tall. This plot is a rare    
# exception because of the number of lines being plotted on it.    
# Common sizes: (10, 7.5) and (12, 9)    
plt.figure(figsize=(12, 12))    
  
# Remove the plot frame lines. They are unnecessary chartjunk.    
ax = plt.subplot(111)    
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(True)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(True)    
  
# Ensure that the axis ticks only show up on the bottom and left of the plot.    
# Ticks on the right and top of the plot are generally unnecessary chartjunk.    
ax.get_xaxis().tick_bottom()    
ax.get_yaxis().tick_left()    
  
# Limit the range of the plot to only where the data is.    
# Avoid unnecessary whitespace.    
plt.ylim(0, 1)    
plt.xlim(0, 7501)    ## epocs

a= [0, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1.0]
# Make sure your axis ticks are large enough to be easily read.    
# You don't want your viewers squinting to read your plot.    
plt.yticks(a, [str(x) for x in a], fontsize=14)    
plt.xticks(fontsize=14)    
  
# Provide tick lines across the plot to help your viewers trace along    
# the axis ticks. Make sure that the lines are light and small so they    
# don't obscure the primary data lines.    
for y in a:    
    plt.plot(range(0, 7501), [y] * len(range(0, 7501)), "--", lw=0.5, color="black", alpha=0.5)    

# Remove the tick marks; they are unnecessary with the tick lines we just plotted.    
plt.tick_params(axis="both", which="both", bottom="off", top="off",    
                labelbottom="on", left="off", right="off", labelleft="on")    
    
majors = ['model_5_222', 'model_7_222', 'model_7_248']    
  
for rank, column in enumerate(majors):    
    # Plot each line separately with its own color, using the Tableau 20    
    # color set in order.    
    plt.plot(losss.iter.values,    
            losss[column.replace("\n", " ")].values,    
            lw=2.5, color=tableau20[rank])    
  
    # Add a text label to the right end of every line. Most of the code below    
    # is adding specific offsets y position because some labels overlapped.    
    y_pos = losss[column.replace("\n", " ")].values[-1] - 0.5    
    if column == "model_5_222":    
        y_pos += 0.5  
    elif column == "model_7_222":    
        y_pos += 0.5   
    elif column == "model_7_248":    
        y_pos += 0.5
   
    plt.text(7500, y_pos, column, fontsize=14, color=tableau20[rank])    


plt.title("Plot of Training loss vs Epocs/Iterations", fontsize=17)    

plt.savefig("loss-vs-Epocs_150.png", bbox_inches="tight")

# %% [markdown]
# ______

# %% [markdown]
# ______
# # **```Thank You :)```**
